# %%
# ------------------------- IMPORTACIONES -------------------------
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('HDHI Admission data.csv', sep=',')

# %%
# Fechas convertidas a datetime
df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
df['D.O.A'] = df['D.O.A_manual']
df.drop(columns='D.O.A_manual', inplace=True)

# Verificar cuántas fechas nulas hay en cada una
nulos_doa = df['D.O.A'].isna().sum()

# Rango de fechas disponibles
min_doa = df['D.O.A'].min()
max_doa = df['D.O.A'].max()

duration_col = 'DURATION OF STAY'

# Ver estadísticas generales
duration_stats = df[duration_col].describe()

# Verificar valores negativos o inconsistentes
invalid_duration = df[df[duration_col] < 0]

duration_stats, invalid_duration.shape[0]
# Out:
# /var/folders/tm/_mcsvvpd5ml8xhw8l_7314j80000gn/T/ipykernel_49213/1322510359.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
# (count    15757.000000
#  mean         6.415054
#  std          5.011421
#  min          1.000000
#  25%          3.000000
#  50%          5.000000
#  75%          8.000000
#  max         98.000000
#  Name: DURATION OF STAY, dtype: float64,
#  0)

# %%
df = df.sort_values(by='D.O.A')

# %%
df['HB'] = pd.to_numeric(df['HB'], errors='coerce')
conteo = (df['HB'] < 9).sum()

print(f"Número de registros con HB < 9: {conteo}")
# Out:
# Número de registros con HB < 9: 1339

# %%
# Convertir columnas relevantes a numérico, manejando valores no numéricos
numeric_cols = ['HB', 'DURATION OF STAY', 'duration of intensive unit stay', 'CREATININE', 'UREA', 'PLATELETS', 'BNP', 'EF']
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Crear la variable proxy para transfusión
def create_transfusion_proxy(row):
    # Criterio principal: Hemoglobina baja (<8 g/dL) o anemia severa
    hb_condition = row['HB'] < 8 if pd.notna(row['HB']) else False
    severe_anemia_condition = row['SEVERE ANAEMIA'] == 1 if 'SEVERE ANAEMIA' in row else False
    
    # condiciones de gravedad que podrían requerir transfusión
    cva_bleed = row['CVA BLEED'] == 1 if 'CVA BLEED' in row else False
    stemi = row['STEMI'] == 1 if 'STEMI' in row else False
    cardiogenic_shock = row['CARDIOGENIC SHOCK'] == 1 if 'CARDIOGENIC SHOCK' in row else False
    shock = row['SHOCK'] == 1 if 'SHOCK' in row else False
    pulmonary_embolism = row['PULMONARY EMBOLISM'] == 1 if 'PULMONARY EMBOLISM' in row else False
    ckd = row['CKD'] == 1 if 'CKD' in row else False
    emergencia = row['TYPE OF ADMISSION-EMERGENCY/OPD']=='E' if 'TYPE OF ADMISSION-EMERGENCY/OPD' in row else False
    
    # Duración de la estancia (>7 días) o estancia en UCI (>1 días)
    long_stay = row['DURATION OF STAY'] > 7 if pd.notna(row['DURATION OF STAY']) else False
    icu_stay = row['duration of intensive unit stay'] > 1 if pd.notna(row['duration of intensive unit stay']) else False
    
    # Lógica para la variable proxy:
    # Necesita transfusión si:
    # HB < 9 o SEVERE ANAEMIA == 1
    # si hay condiciones graves (CVA BLEED, STEMI, SHOCK) con HB < 10
    # si hay CKD con HB < 9
    if (hb_condition or severe_anemia_condition or
        (row['HB'] < 10 and pd.notna(row['HB']) and (cva_bleed or stemi or cardiogenic_shock or shock or pulmonary_embolism)) or
        (ckd and row['HB'] < 9 and pd.notna(row['HB'])) or 
        (emergencia) or
        (long_stay and icu_stay and row['HB'] < 10 and pd.notna(row['HB']))):
        return 1
    return 0

# Aplicar la función para crear la columna 'needs_transfusion'
df['needs_transfusion'] = df.apply(create_transfusion_proxy, axis=1)

# %%
# Asignar Blood Type
np.random.seed(42)

# Asignar tipos de sangre con distribución ajustada para India
blood_types = ['A+', 'A-', 'B+', 'B-', 'O+', 'O-', 'AB+', 'AB-']
probabilities = [0.21, 0.02, 0.33, 0.02, 0.32, 0.02, 0.07, 0.01]

df['Blood Type'] = np.random.choice(blood_types, size=len(df), p=probabilities)

# Verificar la distribución de los tipos de sangre generados
print("Distribución de tipos de sangre en el dataset (%):")
print(df['Blood Type'].value_counts(normalize=True).sort_index() * 100)
# Out:
# Distribución de tipos de sangre en el dataset (%):
# Blood Type
# A+     21.349242
# A-      1.980072
# AB+     7.044488
# AB-     0.913880
# B+     33.375643
# B-      1.935648
# O+     31.611347
# O-      1.789681
# Name: proportion, dtype: float64

# %%
# Elimino variables para trabajar con un conjunto de datos con los datos relevantes para este trabajo
cols_utiles = ['D.O.A', 'DURATION OF STAY', 'needs_transfusion', 'Blood Type']

# Filtrar el DataFrame conservando solo esas columnas
df = df[cols_utiles].copy()

# %%
# Ahora realizaré un análisis para saber que tipo de comportamiento tiene needs_transfusion en el tiempo
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Función para seleccionar rango denso de fechas
def detectar_rango_denso(df_org, date_col='D.O.A', min_por_semana=10, buffer_semanas=2):
    df_tmp = df_org.copy()
    df_tmp[date_col] = pd.to_datetime(df_tmp[date_col], errors='coerce')
    weekly_counts = df_tmp.groupby(df_tmp[date_col].dt.to_period('W').apply(lambda r: r.start_time)).size()
    weeks_valid = weekly_counts[weekly_counts >= min_por_semana]
    if weeks_valid.empty:
        return None  # No hay rango denso suficiente
    start = weeks_valid.index.min() - pd.Timedelta(weeks=buffer_semanas)
    end = weeks_valid.index.max() + pd.Timedelta(weeks=buffer_semanas)
    return start, end

rango = detectar_rango_denso(df, min_por_semana=20)

# Aplicar filtro al dataframe original si hay rango válido
if rango:
    df_filtrado = df[
        (df['D.O.A'] > rango[0]) &
        (df['D.O.A'] <= rango[1])
    ]
else:
    df_filtrado = pd.DataFrame()  # sin datos útiles

df = df_filtrado.copy()
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Agrupo por semana y tipo de sangre
df = df[df['needs_transfusion'] == 1]
weekly_demand = df.groupby([df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time), 'Blood Type'])['needs_transfusion'].sum().unstack().fillna(0)

# %%
serie = weekly_demand['A-']
adf_result = adfuller(serie)

# Graficar ACF y PACF
fig, axes = plt.subplots(2, 1, figsize=(10, 8))
plot_acf(serie, lags=20, ax=axes[0])
axes[0].set_title("ACF - A-")

plot_pacf(serie, lags=20, ax=axes[1], method='ywm')
axes[1].set_title("PACF - A-")

plt.tight_layout()
plt.show()

# Resultado ADF
adf_output = {
    "ADF Statistic": adf_result[0],
    "p-value": adf_result[1],
    "Lags Used": adf_result[2],
    "Observations": adf_result[3],
    "Critical Values": adf_result[4]
}

adf_output
# Out:
# {'ADF Statistic': -9.071647156122967,
#  'p-value': 4.286199031337527e-15,
#  'Lags Used': 0,
#  'Observations': 117,
#  'Critical Values': {'1%': -3.487517288664615,
#   '5%': -2.8865777180380032,
#   '10%': -2.5801239192052012}}

# %%
# ------------------------- MODELO LSTM -------------------------

    
def entrenar_lstm(X_lstm, y_lstm, epochs=800):
    model = Sequential([
        LSTM(128, activation='tanh', return_sequences=True, input_shape=(X_lstm.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.3),
        
        LSTM(64, activation='tanh', return_sequences=True),
        BatchNormalization(),
        Dropout(0.2),

        LSTM(32, activation='tanh'),
        Dropout(0.3),
        
        Dense(64, activation='relu'),
        Dense(1)  # Última capa sin activación porque es una regresión
        ])
    learning_rate = 0.001 
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=MeanSquaredError(),
        
    )
   
    history = model.fit(
        X_lstm, y_lstm,
        epochs=epochs,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )
  
    return model, history


# ------------------------- STACKING REGRESSOR -------------------------

def entrenar_stacking(X_train, y_train):
    
    estimators = [
        ('xgb', XGBRegressor(max_depth=3, n_estimators=400, learning_rate=0.08, random_state=42, verbosity=0)),
        ('lgb', LGBMRegressor(max_depth=3, n_estimators=400, learning_rate=0.07, random_state=42, verbose=-1)),
        ('cat', CatBoostRegressor(depth=3, iterations=400, learning_rate=0.065, random_state=42, verbose=False))
    ]
    modelo_ensamble = StackingRegressor(
            estimators=estimators,
            final_estimator=Ridge(alpha=1.0),
            n_jobs=-1
        )
    modelo_ensamble.fit(X_train, y_train.ravel())
    return modelo_ensamble

# %%
weekly_demand['Lag_A-_1'] = serie.shift(1)
weekly_demand['Lag_A-_2'] = serie.shift(2)
weekly_demand['Lag_A-_3'] = serie.shift(3)
weekly_demand['Lag_A-_4'] = serie.shift(4)
weekly_demand['Rolling_Mean_4_A-'] = serie.rolling(window=4).mean()
weekly_demand['Rolling_Mean_8_A-'] = serie.rolling(window=8).mean()
weekly_demand['Rolling_STD_4_A-'] = serie.rolling(window=4).std()
weekly_demand['Diff_1_A-'] = serie.diff(1)

df = weekly_demand.copy()
df['Lag_A-_1'] = df['A-'].shift(1)
df['Lag_A-_2'] = df['A-'].shift(2)
df['Lag_A-_3'] = df['A-'].shift(3)
df['Lag_A-_4'] = df['A-'].shift(4)
df['Rolling_Mean_4_A-'] = df['A-'].rolling(window=4).mean()

df.columns.values[0] = 'Date'
df = df.reset_index()
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

df['Week'] = df['Date'].dt.isocalendar().week
df['Month'] = df['Date'].dt.month
df['Quarter'] = df['Date'].dt.quarter
df.dropna(inplace=True)

# %%
################# Datos para LSTM A- ################# 

features = ['Lag_A-_1', 'Lag_A-_2', 'Lag_A-_3', 'Lag_A-_4', 'Rolling_Mean_4_A-']
target = 'A-'
X = df[features]
y = df[[target]]

# Escalado robusto
from sklearn.preprocessing import RobustScaler
scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Separo entrenamiento y test (sin barajar porque es una serie temporal)
split_index = int(len(X_scaled) * 0.8)
X_train = X_scaled[:split_index]
X_test = X_scaled[split_index:]
y_lstm = y_scaled[:split_index]
y_test = y_scaled[split_index:]

# Reformatear para LSTM
X_lstm = X_train.reshape((X_train.shape[0], len(features), 1))
X_test_lstm = X_test.reshape((X_test.shape[0], len(features), 1))

# %%
# LSTM

modelo_lstm, history = entrenar_lstm(X_lstm, y_lstm)
y_pred_lstm = modelo_lstm.predict(X_test_lstm)

# Desescalar
y_pred_lstm = scaler_y.inverse_transform(y_pred_lstm)
y_real_lstm = scaler_y.inverse_transform(y_test)
# Out:
# 2025-07-15 15:04:34.893071: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-07-15 15:04:34.893339: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-07-15 15:04:34.893357: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-07-15 15:04:34.893931: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-15 15:04:34.894201: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/800
# 2025-07-15 15:04:36.943779: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 0.6459 - val_loss: 1.4669
# Epoch 2/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.4171 - val_loss: 1.4309
# Epoch 3/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4880 - val_loss: 1.4046
# Epoch 4/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5642 - val_loss: 1.3754
# Epoch 5/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4711 - val_loss: 1.3539
# Epoch 6/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4869 - val_loss: 1.3434
# Epoch 7/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5278 - val_loss: 1.3332
# Epoch 8/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4737 - val_loss: 1.3254
# Epoch 9/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4478 - val_loss: 1.3159
# Epoch 10/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4675 - val_loss: 1.3051
# Epoch 11/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5251 - val_loss: 1.2912
# Epoch 12/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5251 - val_loss: 1.2851
# Epoch 13/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4962 - val_loss: 1.2818
# Epoch 14/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4300 - val_loss: 1.2816
# Epoch 15/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4602 - val_loss: 1.2865
# Epoch 16/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4477 - val_loss: 1.2956
# Epoch 17/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4706 - val_loss: 1.2986
# Epoch 18/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5280 - val_loss: 1.2999
# Epoch 19/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4176 - val_loss: 1.3055
# Epoch 20/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5236 - val_loss: 1.3061
# Epoch 21/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5181 - val_loss: 1.2999
# Epoch 22/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4609 - val_loss: 1.2964
# Epoch 23/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4160 - val_loss: 1.2918
# Epoch 24/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4212 - val_loss: 1.2829
# Epoch 25/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4730 - val_loss: 1.2708
# Epoch 26/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4667 - val_loss: 1.2589
# Epoch 27/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3922 - val_loss: 1.2491
# Epoch 28/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5129 - val_loss: 1.2398
# Epoch 29/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4221 - val_loss: 1.2346
# Epoch 30/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4026 - val_loss: 1.2263
# Epoch 31/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4398 - val_loss: 1.2220
# Epoch 32/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4256 - val_loss: 1.2206
# Epoch 33/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4589 - val_loss: 1.2226
# Epoch 34/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3833 - val_loss: 1.2314
# Epoch 35/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3691 - val_loss: 1.2306
# Epoch 36/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4117 - val_loss: 1.2240
# Epoch 37/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3549 - val_loss: 1.2219
# Epoch 38/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3652 - val_loss: 1.2208
# Epoch 39/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3129 - val_loss: 1.2124
# Epoch 40/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4812 - val_loss: 1.2005
# Epoch 41/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4264 - val_loss: 1.1937
# Epoch 42/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3447 - val_loss: 1.1898
# Epoch 43/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3222 - val_loss: 1.1921
# Epoch 44/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3813 - val_loss: 1.1930
# Epoch 45/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3937 - val_loss: 1.1966
# Epoch 46/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4029 - val_loss: 1.2001
# Epoch 47/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3959 - val_loss: 1.1900
# Epoch 48/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3728 - val_loss: 1.1802
# Epoch 49/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3058 - val_loss: 1.1798
# Epoch 50/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2289 - val_loss: 1.1782
# Epoch 51/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3548 - val_loss: 1.1665
# Epoch 52/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2861 - val_loss: 1.1607
# Epoch 53/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2837 - val_loss: 1.1556
# Epoch 54/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2558 - val_loss: 1.1491
# Epoch 55/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1888 - val_loss: 1.1423
# Epoch 56/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2122 - val_loss: 1.1358
# Epoch 57/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2279 - val_loss: 1.1321
# Epoch 58/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2560 - val_loss: 1.1273
# Epoch 59/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2708 - val_loss: 1.1255
# Epoch 60/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2046 - val_loss: 1.1252
# Epoch 61/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2286 - val_loss: 1.1147
# Epoch 62/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2109 - val_loss: 1.0901
# Epoch 63/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1904 - val_loss: 1.0706
# Epoch 64/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2346 - val_loss: 1.0521
# Epoch 65/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1565 - val_loss: 1.0419
# Epoch 66/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1856 - val_loss: 1.0405
# Epoch 67/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1552 - val_loss: 1.0423
# Epoch 68/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1655 - val_loss: 1.0420
# Epoch 69/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1764 - val_loss: 1.0351
# Epoch 70/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1636 - val_loss: 1.0209
# Epoch 71/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1307 - val_loss: 1.0053
# Epoch 72/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1576 - val_loss: 0.9979
# Epoch 73/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1797 - val_loss: 0.9938
# Epoch 74/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1405 - val_loss: 1.0126
# Epoch 75/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1088 - val_loss: 1.0313
# Epoch 76/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1492 - val_loss: 1.0382
# Epoch 77/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1177 - val_loss: 1.0285
# Epoch 78/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1529 - val_loss: 1.0055
# Epoch 79/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1243 - val_loss: 0.9906
# Epoch 80/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0959 - val_loss: 0.9774
# Epoch 81/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1048 - val_loss: 0.9688
# Epoch 82/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0925 - val_loss: 0.9568
# Epoch 83/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1532 - val_loss: 0.9520
# Epoch 84/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0950 - val_loss: 0.9590
# Epoch 85/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1551 - val_loss: 0.9698
# Epoch 86/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0966 - val_loss: 0.9742
# Epoch 87/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0982 - val_loss: 0.9805
# Epoch 88/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1314 - val_loss: 0.9775
# Epoch 89/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0951 - val_loss: 0.9856
# Epoch 90/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0932 - val_loss: 0.9855
# Epoch 91/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1289 - val_loss: 0.9734
# Epoch 92/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1081 - val_loss: 0.9718
# Epoch 93/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1227 - val_loss: 0.9707
# Epoch 94/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0917 - val_loss: 0.9662
# Epoch 95/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1206 - val_loss: 0.9417
# Epoch 96/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1260 - val_loss: 0.9186
# Epoch 97/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0723 - val_loss: 0.8965
# Epoch 98/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1372 - val_loss: 0.8701
# Epoch 99/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1349 - val_loss: 0.8464
# Epoch 100/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0909 - val_loss: 0.8398
# Epoch 101/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1086 - val_loss: 0.8458
# Epoch 102/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1013 - val_loss: 0.9049
# Epoch 103/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1400 - val_loss: 0.9271
# Epoch 104/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1215 - val_loss: 0.9138
# Epoch 105/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1417 - val_loss: 0.8450
# Epoch 106/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1088 - val_loss: 0.7824
# Epoch 107/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1338 - val_loss: 0.7623
# Epoch 108/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1293 - val_loss: 0.7622
# Epoch 109/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1706 - val_loss: 0.7876
# Epoch 110/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0608 - val_loss: 0.8235
# Epoch 111/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1466 - val_loss: 0.8314
# Epoch 112/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1085 - val_loss: 0.7961
# Epoch 113/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1299 - val_loss: 0.7629
# Epoch 114/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0834 - val_loss: 0.7367
# Epoch 115/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0922 - val_loss: 0.7359
# Epoch 116/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0652 - val_loss: 0.7482
# Epoch 117/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1423 - val_loss: 0.7612
# Epoch 118/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1510 - val_loss: 0.7823
# Epoch 119/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1286 - val_loss: 0.7943
# Epoch 120/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1018 - val_loss: 0.7687
# Epoch 121/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0766 - val_loss: 0.7298
# Epoch 122/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1138 - val_loss: 0.7077
# Epoch 123/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0803 - val_loss: 0.7014
# Epoch 124/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1224 - val_loss: 0.6993
# Epoch 125/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0795 - val_loss: 0.7115
# Epoch 126/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0535 - val_loss: 0.7232
# Epoch 127/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0897 - val_loss: 0.7244
# Epoch 128/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0522 - val_loss: 0.7134
# Epoch 129/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1141 - val_loss: 0.6907
# Epoch 130/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0847 - val_loss: 0.6845
# Epoch 131/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0742 - val_loss: 0.6733
# Epoch 132/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0719 - val_loss: 0.6591
# Epoch 133/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0761 - val_loss: 0.6502
# Epoch 134/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0766 - val_loss: 0.6339
# Epoch 135/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0627 - val_loss: 0.6511
# Epoch 136/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1287 - val_loss: 0.6891
# Epoch 137/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1063 - val_loss: 0.6809
# Epoch 138/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0578 - val_loss: 0.6328
# Epoch 139/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0934 - val_loss: 0.5817
# Epoch 140/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0834 - val_loss: 0.5588
# Epoch 141/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0917 - val_loss: 0.5805
# Epoch 142/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0662 - val_loss: 0.6307
# Epoch 143/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0684 - val_loss: 0.6543
# Epoch 144/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0689 - val_loss: 0.6394
# Epoch 145/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0670 - val_loss: 0.5930
# Epoch 146/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0538 - val_loss: 0.5384
# Epoch 147/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0713 - val_loss: 0.5271
# Epoch 148/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0761 - val_loss: 0.5341
# Epoch 149/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0750 - val_loss: 0.5414
# Epoch 150/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0821 - val_loss: 0.5697
# Epoch 151/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0742 - val_loss: 0.5913
# Epoch 152/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0862 - val_loss: 0.5499
# Epoch 153/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0741 - val_loss: 0.5269
# Epoch 154/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0910 - val_loss: 0.5170
# Epoch 155/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0672 - val_loss: 0.5157
# Epoch 156/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0783 - val_loss: 0.5306
# Epoch 157/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0873 - val_loss: 0.5546
# Epoch 158/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0920 - val_loss: 0.5827
# Epoch 159/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0672 - val_loss: 0.5555
# Epoch 160/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0726 - val_loss: 0.5321
# Epoch 161/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0711 - val_loss: 0.5156
# Epoch 162/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0879 - val_loss: 0.5156
# Epoch 163/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0957 - val_loss: 0.5193
# Epoch 164/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0709 - val_loss: 0.5117
# Epoch 165/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0696 - val_loss: 0.4906
# Epoch 166/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0843 - val_loss: 0.4750
# Epoch 167/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0485 - val_loss: 0.4656
# Epoch 168/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0893 - val_loss: 0.4806
# Epoch 169/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0486 - val_loss: 0.4920
# Epoch 170/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0882 - val_loss: 0.5185
# Epoch 171/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0619 - val_loss: 0.5564
# Epoch 172/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0735 - val_loss: 0.5559
# Epoch 173/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0958 - val_loss: 0.5795
# Epoch 174/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0763 - val_loss: 0.5811
# Epoch 175/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0792 - val_loss: 0.5472
# Epoch 176/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0806 - val_loss: 0.5144
# Epoch 177/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0800 - val_loss: 0.5049
# Epoch 178/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0646 - val_loss: 0.4969
# Epoch 179/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0636 - val_loss: 0.5156
# Epoch 180/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0576 - val_loss: 0.5240
# Epoch 181/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0552 - val_loss: 0.5094
# Epoch 182/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1040 - val_loss: 0.4891
# Epoch 183/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0547 - val_loss: 0.4783
# Epoch 184/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0491 - val_loss: 0.5016
# Epoch 185/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0564 - val_loss: 0.5122
# Epoch 186/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0690 - val_loss: 0.4733
# Epoch 187/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0558 - val_loss: 0.3876
# Epoch 188/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1100 - val_loss: 0.3564
# Epoch 189/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0774 - val_loss: 0.3559
# Epoch 190/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0498 - val_loss: 0.3847
# Epoch 191/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0596 - val_loss: 0.4286
# Epoch 192/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0811 - val_loss: 0.4848
# Epoch 193/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0615 - val_loss: 0.5012
# Epoch 194/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0645 - val_loss: 0.4500
# Epoch 195/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0863 - val_loss: 0.3614
# Epoch 196/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0913 - val_loss: 0.3390
# Epoch 197/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0677 - val_loss: 0.3281
# Epoch 198/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0912 - val_loss: 0.3396
# Epoch 199/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0745 - val_loss: 0.3851
# Epoch 200/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0639 - val_loss: 0.3953
# Epoch 201/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0511 - val_loss: 0.3885
# Epoch 202/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0913 - val_loss: 0.3782
# Epoch 203/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0427 - val_loss: 0.3632
# Epoch 204/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0654 - val_loss: 0.3537
# Epoch 205/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0558 - val_loss: 0.3152
# Epoch 206/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1570 - val_loss: 0.3077
# Epoch 207/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0898 - val_loss: 0.3365
# Epoch 208/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0781 - val_loss: 0.3776
# Epoch 209/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0444 - val_loss: 0.4392
# Epoch 210/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0581 - val_loss: 0.4618
# Epoch 211/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0608 - val_loss: 0.4026
# Epoch 212/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0638 - val_loss: 0.3371
# Epoch 213/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0745 - val_loss: 0.2988
# Epoch 214/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0499 - val_loss: 0.2852
# Epoch 215/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0520 - val_loss: 0.2950
# Epoch 216/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0531 - val_loss: 0.2984
# Epoch 217/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0469 - val_loss: 0.2998
# Epoch 218/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0619 - val_loss: 0.2896
# Epoch 219/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0518 - val_loss: 0.2937
# Epoch 220/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0565 - val_loss: 0.3064
# Epoch 221/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0477 - val_loss: 0.2834
# Epoch 222/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0577 - val_loss: 0.2660
# Epoch 223/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0536 - val_loss: 0.2563
# Epoch 224/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0506 - val_loss: 0.2501
# Epoch 225/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0824 - val_loss: 0.2661
# Epoch 226/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0538 - val_loss: 0.3023
# Epoch 227/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0580 - val_loss: 0.3292
# Epoch 228/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0565 - val_loss: 0.3321
# Epoch 229/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0694 - val_loss: 0.2854
# Epoch 230/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0556 - val_loss: 0.2203
# Epoch 231/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0704 - val_loss: 0.2072
# Epoch 232/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0737 - val_loss: 0.2141
# Epoch 233/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0767 - val_loss: 0.2188
# Epoch 234/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0457 - val_loss: 0.2526
# Epoch 235/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0763 - val_loss: 0.2608
# Epoch 236/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0866 - val_loss: 0.2324
# Epoch 237/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0445 - val_loss: 0.2489
# Epoch 238/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0623 - val_loss: 0.2604
# Epoch 239/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0433 - val_loss: 0.2491
# Epoch 240/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0533 - val_loss: 0.2383
# Epoch 241/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0353 - val_loss: 0.2372
# Epoch 242/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0729 - val_loss: 0.2469
# Epoch 243/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0475 - val_loss: 0.2884
# Epoch 244/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0550 - val_loss: 0.3265
# Epoch 245/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0539 - val_loss: 0.3401
# Epoch 246/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0459 - val_loss: 0.3282
# Epoch 247/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0701 - val_loss: 0.2970
# Epoch 248/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0553 - val_loss: 0.2668
# Epoch 249/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0561 - val_loss: 0.2327
# Epoch 250/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0631 - val_loss: 0.2156
# Epoch 251/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0709 - val_loss: 0.2120
# Epoch 252/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0606 - val_loss: 0.2131
# Epoch 253/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0736 - val_loss: 0.2658
# Epoch 254/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0761 - val_loss: 0.2868
# Epoch 255/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0734 - val_loss: 0.2706
# Epoch 256/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0469 - val_loss: 0.2262
# Epoch 257/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0530 - val_loss: 0.1931
# Epoch 258/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0635 - val_loss: 0.1982
# Epoch 259/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0618 - val_loss: 0.2007
# Epoch 260/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0586 - val_loss: 0.1876
# Epoch 261/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0406 - val_loss: 0.2081
# Epoch 262/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0499 - val_loss: 0.2528
# Epoch 263/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0442 - val_loss: 0.2601
# Epoch 264/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0481 - val_loss: 0.2378
# Epoch 265/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0521 - val_loss: 0.2336
# Epoch 266/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0623 - val_loss: 0.2448
# Epoch 267/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0698 - val_loss: 0.2635
# Epoch 268/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0512 - val_loss: 0.2480
# Epoch 269/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0550 - val_loss: 0.2425
# Epoch 270/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0518 - val_loss: 0.2668
# Epoch 271/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0476 - val_loss: 0.2737
# Epoch 272/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0444 - val_loss: 0.2446
# Epoch 273/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0311 - val_loss: 0.2072
# Epoch 274/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0539 - val_loss: 0.1895
# Epoch 275/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0397 - val_loss: 0.1874
# Epoch 276/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0482 - val_loss: 0.2398
# Epoch 277/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0454 - val_loss: 0.3082
# Epoch 278/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0529 - val_loss: 0.3081
# Epoch 279/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0650 - val_loss: 0.2807
# Epoch 280/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0591 - val_loss: 0.2328
# Epoch 281/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0338 - val_loss: 0.2026
# Epoch 282/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0373 - val_loss: 0.1960
# Epoch 283/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0668 - val_loss: 0.2024
# Epoch 284/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0604 - val_loss: 0.2191
# Epoch 285/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0731 - val_loss: 0.2123
# Epoch 286/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0429 - val_loss: 0.2017
# Epoch 287/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0466 - val_loss: 0.1719
# Epoch 288/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0473 - val_loss: 0.1617
# Epoch 289/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0797 - val_loss: 0.1603
# Epoch 290/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0505 - val_loss: 0.1650
# Epoch 291/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0358 - val_loss: 0.1739
# Epoch 292/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0634 - val_loss: 0.1784
# Epoch 293/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0446 - val_loss: 0.2043
# Epoch 294/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0569 - val_loss: 0.2419
# Epoch 295/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0396 - val_loss: 0.2435
# Epoch 296/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0490 - val_loss: 0.1989
# Epoch 297/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0411 - val_loss: 0.1582
# Epoch 298/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0586 - val_loss: 0.1628
# Epoch 299/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.
800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0259 - val_loss: 0.1815
# Epoch 759/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0235 - val_loss: 0.1980
# Epoch 760/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0305 - val_loss: 0.2048
# Epoch 761/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0293 - val_loss: 0.2103
# Epoch 762/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0239 - val_loss: 0.2016
# Epoch 763/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0136 - val_loss: 0.1891
# Epoch 764/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0375 - val_loss: 0.1644
# Epoch 765/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0253 - val_loss: 0.1440
# Epoch 766/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0240 - val_loss: 0.1549
# Epoch 767/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0242 - val_loss: 0.2451
# Epoch 768/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0144 - val_loss: 0.2804
# Epoch 769/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0278 - val_loss: 0.2775
# Epoch 770/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0400 - val_loss: 0.2677
# Epoch 771/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0204 - val_loss: 0.2180
# Epoch 772/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0428 - val_loss: 0.1879
# Epoch 773/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0245 - val_loss: 0.1775
# Epoch 774/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0367 - val_loss: 0.1889
# Epoch 775/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0253 - val_loss: 0.2222
# Epoch 776/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0303 - val_loss: 0.2204
# Epoch 777/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0227 - val_loss: 0.2294
# Epoch 778/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0192 - val_loss: 0.2432
# Epoch 779/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0257 - val_loss: 0.2464
# Epoch 780/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0166 - val_loss: 0.2476
# Epoch 781/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0331 - val_loss: 0.2331
# Epoch 782/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0191 - val_loss: 0.2131
# Epoch 783/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0205 - val_loss: 0.1779
# Epoch 784/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0199 - val_loss: 0.1635
# Epoch 785/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0335 - val_loss: 0.1581
# Epoch 786/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0235 - val_loss: 0.1623
# Epoch 787/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0253 - val_loss: 0.1870
# Epoch 788/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0235 - val_loss: 0.1946
# Epoch 789/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0190 - val_loss: 0.2076
# Epoch 790/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0314 - val_loss: 0.2178
# Epoch 791/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0247 - val_loss: 0.2175
# Epoch 792/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0207 - val_loss: 0.2021
# Epoch 793/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0244 - val_loss: 0.2062
# Epoch 794/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0259 - val_loss: 0.2185
# Epoch 795/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0185 - val_loss: 0.2384
# Epoch 796/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0403 - val_loss: 0.2548
# Epoch 797/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0236 - val_loss: 0.2743
# Epoch 798/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0346 - val_loss: 0.2453
# Epoch 799/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0272 - val_loss: 0.2252
# Epoch 800/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0204 - val_loss: 0.1986
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step

# %%
################# Datos para stackingregressor #################


# Características temporales enriquecidas

df['Rolling_Mean_8_A-'] = df['A-'].rolling(8).mean()
df['Rolling_STD_4_A-'] = df['A-'].rolling(4).std()
df['Diff_1_A-'] = df['A-'].diff(1)


# Eliminar nulos generados por los lags/rolling
df.dropna(inplace=True)
# Definir features y target para stackingregressor
features_stk = [col for col in df.columns if col.startswith('Lag_A-') or 'Rolling_Mean_8_A-' in col or 'Rolling_STD_4_A-' in col or 'Diff_1_A-' in col or col in ['Week', 'Month','Quarter']]

X_stk = df[features_stk]
y = df[target]

scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X_stk)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1)).flatten()
X_scaled = pd.DataFrame(X_scaled, columns=X_stk.columns)
X_train_stk, X_test_stk, y_train_stk, y_test_stk = train_test_split(X_scaled, y_scaled, shuffle=False, test_size=0.2)

# %%
# StackingRegressor

modelo_stk = entrenar_stacking(X_train_stk, y_train_stk)
y_pred_stk = modelo_stk.predict(X_test_stk)
y_pred_stk = scaler_y.inverse_transform(y_pred_stk.reshape(-1, 1))
y_real_stk = scaler_y.inverse_transform(y_test_stk.reshape(-1, 1))

# %%
# ------------------------- MÉTRICAS PARA A- -------------------------

print("* MÉTRICAS LSTM PARA A-")
print(f"MAE: {mean_absolute_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"RMSE: {mean_squared_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"R²: {r2_score(y_real_lstm, y_pred_lstm):.2f}")

print("\n* MÉTRICAS STACKING PARA A-")
print(f"MAE: {mean_absolute_error(y_real_stk, y_pred_stk):.2f}")
print(f"RMSE: {mean_squared_error(y_real_stk, y_pred_stk):.2f}")
print(f"R²: {r2_score(y_real_stk, y_pred_stk):.2f}")
# Out:
# * MÉTRICAS LSTM PARA A-
# MAE: 0.39
# RMSE: 0.21
# R²: 0.75
#
# * MÉTRICAS STACKING PARA A-
# MAE: 0.20
# RMSE: 0.06
# R²: 0.91

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_real_stk), len(y_pred_stk))

# Convertir todo a 1D por seguridad
y_test_plot = y_test[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_real_plot = y_real_lstm[:min_len].reshape(-1)

# Plot
plt.figure(figsize=(12, 5))
plt.plot(np.arange(min_len), y_real_stk[:min_len], label="Real", color='black')
plt.plot(np.arange(min_len), y_pred_stk[:min_len], label="StackingRegressor", linestyle='--')
plt.plot(np.arange(min_len), y_pred_lstm[:min_len], label="LSTM", linestyle=':')
plt.title("Comparación de Predicciones: LSTM vs StackingRegressor (Demanda A-)")
plt.xlabel("Semanas")
plt.ylabel("Demanda")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_pred_stk))
y_real_plot = y_real_lstm[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
fig.suptitle("Comparación de Series y Análisis ACF/PACF", fontsize=16)

# Serie real
axes[0, 0].plot(y_real_plot, color='black')
axes[0, 0].set_title("Serie real A- ")
axes[0, 0].grid(True)

# ACF real
plot_acf(y_real_plot, lags=min(20, len(y_real_plot)//2 - 1), ax=axes[0, 1])
axes[0, 1].set_title("ACF A- - Real")

# LSTM predicción
axes[1, 0].plot(y_pred_lstm_plot, color='blue')
axes[1, 0].set_title("Predicción A-  LSTM")
axes[1, 0].grid(True)

# ACF LSTM
plot_acf(y_pred_lstm_plot, lags=min(20, len(y_pred_lstm_plot)//2 - 1), ax=axes[1, 1])
axes[1, 1].set_title("ACF A-  - LSTM")

# Stacking predicción
axes[2, 0].plot(y_pred_stk_plot, color='green')
axes[2, 0].set_title("Predicción A-  Stacking")
axes[2, 0].grid(True)

# ACF Stacking
plot_acf(y_pred_stk_plot, lags=min(20, len(y_pred_stk_plot)//2 - 1), ax=axes[2, 1])
axes[2, 1].set_title("ACF A-  - Stacking")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig("comparativa_modelos_acf.png", dpi=300)
plt.show()
