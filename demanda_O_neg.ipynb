# %%
# ------------------------- IMPORTACIONES -------------------------
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('HDHI Admission data.csv', sep=',')

# %%
# Fechas convertidas a datetime
df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
df['D.O.A'] = df['D.O.A_manual']
df.drop(columns='D.O.A_manual', inplace=True)

# Verificar cuántas fechas nulas hay en cada una
nulos_doa = df['D.O.A'].isna().sum()

# Rango de fechas disponibles
min_doa = df['D.O.A'].min()
max_doa = df['D.O.A'].max()

duration_col = 'DURATION OF STAY'

# Ver estadísticas generales
duration_stats = df[duration_col].describe()

# Verificar valores negativos o inconsistentes
invalid_duration = df[df[duration_col] < 0]

duration_stats, invalid_duration.shape[0]
# Out:
# /var/folders/tm/_mcsvvpd5ml8xhw8l_7314j80000gn/T/ipykernel_48300/1322510359.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
# (count    15757.000000
#  mean         6.415054
#  std          5.011421
#  min          1.000000
#  25%          3.000000
#  50%          5.000000
#  75%          8.000000
#  max         98.000000
#  Name: DURATION OF STAY, dtype: float64,
#  0)

# %%
df = df.sort_values(by='D.O.A')

# %%
df['HB'] = pd.to_numeric(df['HB'], errors='coerce')
conteo = (df['HB'] < 9).sum()

print(f"Número de registros con HB < 9: {conteo}")
# Out:
# Número de registros con HB < 9: 1339

# %%
# Convertir columnas relevantes a numérico, manejando valores no numéricos
numeric_cols = ['HB', 'DURATION OF STAY', 'duration of intensive unit stay', 'CREATININE', 'UREA', 'PLATELETS', 'BNP', 'EF']
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Crear la variable proxy para transfusión
def create_transfusion_proxy(row):
    # Criterio principal: Hemoglobina baja (<8 g/dL) o anemia severa
    hb_condition = row['HB'] < 8 if pd.notna(row['HB']) else False
    severe_anemia_condition = row['SEVERE ANAEMIA'] == 1 if 'SEVERE ANAEMIA' in row else False
    
    # condiciones de gravedad que podrían requerir transfusión
    cva_bleed = row['CVA BLEED'] == 1 if 'CVA BLEED' in row else False
    stemi = row['STEMI'] == 1 if 'STEMI' in row else False
    cardiogenic_shock = row['CARDIOGENIC SHOCK'] == 1 if 'CARDIOGENIC SHOCK' in row else False
    shock = row['SHOCK'] == 1 if 'SHOCK' in row else False
    pulmonary_embolism = row['PULMONARY EMBOLISM'] == 1 if 'PULMONARY EMBOLISM' in row else False
    ckd = row['CKD'] == 1 if 'CKD' in row else False
    emergencia = row['TYPE OF ADMISSION-EMERGENCY/OPD']=='E' if 'TYPE OF ADMISSION-EMERGENCY/OPD' in row else False
    
    # Duración de la estancia (>7 días) o estancia en UCI (>1 días)
    long_stay = row['DURATION OF STAY'] > 7 if pd.notna(row['DURATION OF STAY']) else False
    icu_stay = row['duration of intensive unit stay'] > 1 if pd.notna(row['duration of intensive unit stay']) else False
    
    # Lógica para la variable proxy:
    # Necesita transfusión si:
    # HB < 9 o SEVERE ANAEMIA == 1
    # si hay condiciones graves (CVA BLEED, STEMI, SHOCK) con HB < 10
    # si hay CKD con HB < 9
    if (hb_condition or severe_anemia_condition or
        (row['HB'] < 10 and pd.notna(row['HB']) and (cva_bleed or stemi or cardiogenic_shock or shock or pulmonary_embolism)) or
        (ckd and row['HB'] < 9 and pd.notna(row['HB'])) or 
        (emergencia) or
        (long_stay and icu_stay and row['HB'] < 10 and pd.notna(row['HB']))):
        return 1
    return 0

# Aplicar la función para crear la columna 'needs_transfusion'
df['needs_transfusion'] = df.apply(create_transfusion_proxy, axis=1)

# %%
# Asignar Blood Type
np.random.seed(42)

# Asignar tipos de sangre con distribución ajustada para India
blood_types = ['A+', 'A-', 'B+', 'B-', 'O+', 'O-', 'AB+', 'AB-']
probabilities = [0.21, 0.02, 0.33, 0.02, 0.32, 0.02, 0.07, 0.01]
         
df['Blood Type'] = np.random.choice(blood_types, size=len(df), p=probabilities)

# Verificar la distribución de los tipos de sangre generados
print("Distribución de tipos de sangre en el dataset (%):")
print(df['Blood Type'].value_counts(normalize=True).sort_index() * 100)
# Out:
# Distribución de tipos de sangre en el dataset (%):
# Blood Type
# A+     21.349242
# A-      1.980072
# AB+     7.044488
# AB-     0.913880
# B+     33.375643
# B-      1.935648
# O+     31.611347
# O-      1.789681
# Name: proportion, dtype: float64

# %%
# Elimino variables para trabajar con un conjunto de datos con los datos relevantes para este trabajo
cols_utiles = ['D.O.A', 'DURATION OF STAY', 'needs_transfusion', 'Blood Type']

# Filtrar el DataFrame conservando solo esas columnas
df = df[cols_utiles].copy()

# %%
# Ahora realizaré un análisis para saber que tipo de comportamiento tiene needs_transfusion en el tiempo
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Función para seleccionar rango denso de fechas
def detectar_rango_denso(df_org, date_col='D.O.A', min_por_semana=10, buffer_semanas=2):
    df_tmp = df_org.copy()
    df_tmp[date_col] = pd.to_datetime(df_tmp[date_col], errors='coerce')
    weekly_counts = df_tmp.groupby(df_tmp[date_col].dt.to_period('W').apply(lambda r: r.start_time)).size()
    weeks_valid = weekly_counts[weekly_counts >= min_por_semana]
    if weeks_valid.empty:
        return None  # No hay rango denso suficiente
    start = weeks_valid.index.min() - pd.Timedelta(weeks=buffer_semanas)
    end = weeks_valid.index.max() + pd.Timedelta(weeks=buffer_semanas)
    return start, end

rango = detectar_rango_denso(df, min_por_semana=20)

# Aplicar filtro al dataframe original si hay rango válido
if rango:
    df_filtrado = df[
        (df['D.O.A'] > rango[0]) &
        (df['D.O.A'] <= rango[1])
    ]
else:
    df_filtrado = pd.DataFrame()  # sin datos útiles

df = df_filtrado.copy()
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Agrupo por semana y tipo de sangre
df = df[df['needs_transfusion'] == 1]
weekly_demand = df.groupby([df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time), 'Blood Type'])['needs_transfusion'].sum().unstack().fillna(0)

# %%
serie = weekly_demand['O-']
adf_result = adfuller(serie)

# Graficar ACF y PACF
fig, axes = plt.subplots(2, 1, figsize=(10, 8))
plot_acf(serie, lags=20, ax=axes[0])
axes[0].set_title("ACF - O-")

plot_pacf(serie, lags=20, ax=axes[1], method='ywm')
axes[1].set_title("PACF - O-")

plt.tight_layout()
plt.show()

# Resultado ADF
adf_output = {
    "ADF Statistic": adf_result[0],
    "p-value": adf_result[1],
    "Lags Used": adf_result[2],
    "Observations": adf_result[3],
    "Critical Values": adf_result[4]
}

adf_output
# Out:
# {'ADF Statistic': -8.783144320876946,
#  'p-value': 2.3470075472901986e-14,
#  'Lags Used': 0,
#  'Observations': 117,
#  'Critical Values': {'1%': -3.487517288664615,
#   '5%': -2.8865777180380032,
#   '10%': -2.5801239192052012}}

# %%
# ------------------------- MODELO LSTM -------------------------

    
def entrenar_lstm(X_lstm, y_lstm, epochs=800):
    model = Sequential([
        LSTM(128, activation='tanh', return_sequences=True, input_shape=(X_lstm.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.3),
        
        LSTM(64, activation='tanh', return_sequences=True),
        BatchNormalization(),
        Dropout(0.2),

        LSTM(32, activation='tanh'),
        Dropout(0.3),
        
        Dense(64, activation='relu'),
        Dense(1)  # Última capa sin activación porque es una regresión
        ])
    learning_rate = 0.001 
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=MeanSquaredError(),
        
    )
  
    history = model.fit(
        X_lstm, y_lstm,
        epochs=epochs,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )
  
    return model, history


# ------------------------- STACKING REGRESSOR -------------------------

def entrenar_stacking(X_train, y_train):
    
    estimators = [
        ('xgb', XGBRegressor(max_depth=3, n_estimators=300, learning_rate=0.08, random_state=42, verbosity=0)),
        ('lgb', LGBMRegressor(max_depth=3, n_estimators=300, learning_rate=0.06, random_state=42, verbose=-1)),
        ('cat', CatBoostRegressor(depth=3, iterations=300, learning_rate=0.06, random_state=42, verbose=False))
    ]
    modelo_ensamble = StackingRegressor(
            estimators=estimators,
            final_estimator=Ridge(alpha=1.0),
            n_jobs=-1
        )
    modelo_ensamble.fit(X_train, y_train.ravel())
    return modelo_ensamble

# %%
weekly_demand['Lag_O-_1'] = serie.shift(1)
weekly_demand['Lag_O-_2'] = serie.shift(2)
weekly_demand['Lag_O-_3'] = serie.shift(3)
weekly_demand['Lag_O-_4'] = serie.shift(4)
weekly_demand['Rolling_Mean_4_O-'] = serie.rolling(window=4).mean()
weekly_demand['Rolling_Mean_8_O-'] = serie.rolling(window=8).mean()
weekly_demand['Rolling_STD_4_O-'] = serie.rolling(window=4).std()
weekly_demand['Diff_1_O-'] = serie.diff(1)

df = weekly_demand.copy()
df['Lag_O-_1'] = df['O-'].shift(1)
df['Lag_O-_2'] = df['O-'].shift(2)
df['Lag_O-_3'] = df['O-'].shift(3)
df['Lag_O-_4'] = df['O-'].shift(4)
df['Rolling_Mean_4_O-'] = df['O-'].rolling(window=4).mean()

df.columns.values[0] = 'Date'
df = df.reset_index()
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

df['Week'] = df['Date'].dt.isocalendar().week
df['Month'] = df['Date'].dt.month
df['Quarter'] = df['Date'].dt.quarter
df.dropna(inplace=True)

# %%
################# Datos para LSTM O- ################# 

features = ['Lag_O-_1', 'Lag_O-_2', 'Lag_O-_3', 'Lag_O-_4', 'Rolling_Mean_4_O-']
target = 'O-'
X = df[features]
y = df[[target]]

# Escalado robusto
from sklearn.preprocessing import RobustScaler
scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Separo entrenamiento y test (sin barajar porque es una serie temporal)
split_index = int(len(X_scaled) * 0.8)
X_train = X_scaled[:split_index]
X_test = X_scaled[split_index:]
y_lstm = y_scaled[:split_index]
y_test = y_scaled[split_index:]

# Reformatear para LSTM
X_lstm = X_train.reshape((X_train.shape[0], len(features), 1))
X_test_lstm = X_test.reshape((X_test.shape[0], len(features), 1))

# %%
# LSTM

modelo_lstm, history = entrenar_lstm(X_lstm, y_lstm)
y_pred_lstm = modelo_lstm.predict(X_test_lstm)

# Desescalar
y_pred_lstm = scaler_y.inverse_transform(y_pred_lstm)
y_real_lstm = scaler_y.inverse_transform(y_test)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 364ms/step - loss: 0.5853 - val_loss: 0.8992
# Epoch 2/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4441 - val_loss: 0.8924
# Epoch 3/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4630 - val_loss: 0.8897
# Epoch 4/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4954 - val_loss: 0.8897
# Epoch 5/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4531 - val_loss: 0.8897
# Epoch 6/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4452 - val_loss: 0.8912
# Epoch 7/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4729 - val_loss: 0.8931
# Epoch 8/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4306 - val_loss: 0.8950
# Epoch 9/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4471 - val_loss: 0.8985
# Epoch 10/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5004 - val_loss: 0.9017
# Epoch 11/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4584 - val_loss: 0.9035
# Epoch 12/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4536 - val_loss: 0.9043
# Epoch 13/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4047 - val_loss: 0.9054
# Epoch 14/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4409 - val_loss: 0.9069
# Epoch 15/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4469 - val_loss: 0.9081
# Epoch 16/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4510 - val_loss: 0.9084
# Epoch 17/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4612 - val_loss: 0.9097
# Epoch 18/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4258 - val_loss: 0.9104
# Epoch 19/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4614 - val_loss: 0.9090
# Epoch 20/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4263 - val_loss: 0.9072
# Epoch 21/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4144 - val_loss: 0.9073
# Epoch 22/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5196 - val_loss: 0.9107
# Epoch 23/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4327 - val_loss: 0.9143
# Epoch 24/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3918 - val_loss: 0.9175
# Epoch 25/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4344 - val_loss: 0.9200
# Epoch 26/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4560 - val_loss: 0.9237
# Epoch 27/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4248 - val_loss: 0.9302
# Epoch 28/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4615 - val_loss: 0.9353
# Epoch 29/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4204 - val_loss: 0.9364
# Epoch 30/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3919 - val_loss: 0.9337
# Epoch 31/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4215 - val_loss: 0.9305
# Epoch 32/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4417 - val_loss: 0.9294
# Epoch 33/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4509 - val_loss: 0.9308
# Epoch 34/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4179 - val_loss: 0.9326
# Epoch 35/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4796 - val_loss: 0.9356
# Epoch 36/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4449 - val_loss: 0.9380
# Epoch 37/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3951 - val_loss: 0.9392
# Epoch 38/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4431 - val_loss: 0.9390
# Epoch 39/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4322 - val_loss: 0.9432
# Epoch 40/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4711 - val_loss: 0.9446
# Epoch 41/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4055 - val_loss: 0.9451
# Epoch 42/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3871 - val_loss: 0.9460
# Epoch 43/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4507 - val_loss: 0.9434
# Epoch 44/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4114 - val_loss: 0.9440
# Epoch 45/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3682 - val_loss: 0.9482
# Epoch 46/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4463 - val_loss: 0.9563
# Epoch 47/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3648 - val_loss: 0.9658
# Epoch 48/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4016 - val_loss: 0.9744
# Epoch 49/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3912 - val_loss: 0.9840
# Epoch 50/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3741 - val_loss: 0.9930
# Epoch 51/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4179 - val_loss: 0.9997
# Epoch 52/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3333 - val_loss: 1.0009
# Epoch 53/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3575 - val_loss: 0.9981
# Epoch 54/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3747 - val_loss: 0.9915
# Epoch 55/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3158 - val_loss: 0.9910
# Epoch 56/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3321 - val_loss: 0.9953
# Epoch 57/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3761 - val_loss: 1.0026
# Epoch 58/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3396 - val_loss: 1.0176
# Epoch 59/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3375 - val_loss: 1.0325
# Epoch 60/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2966 - val_loss: 1.0486
# Epoch 61/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2981 - val_loss: 1.0675
# Epoch 62/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3114 - val_loss: 1.0786
# Epoch 63/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2106 - val_loss: 1.0863
# Epoch 64/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2085 - val_loss: 1.0811
# Epoch 65/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1948 - val_loss: 1.0766
# Epoch 66/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2507 - val_loss: 1.0734
# Epoch 67/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2142 - val_loss: 1.0729
# Epoch 68/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1706 - val_loss: 1.0889
# Epoch 69/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1944 - val_loss: 1.1094
# Epoch 70/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1873 - val_loss: 1.1187
# Epoch 71/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2244 - val_loss: 1.1232
# Epoch 72/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1623 - val_loss: 1.1199
# Epoch 73/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2091 - val_loss: 1.1385
# Epoch 74/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1741 - val_loss: 1.1698
# Epoch 75/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2036 - val_loss: 1.2035
# Epoch 76/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1715 - val_loss: 1.2467
# Epoch 77/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1590 - val_loss: 1.2731
# Epoch 78/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1639 - val_loss: 1.2603
# Epoch 79/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1667 - val_loss: 1.2258
# Epoch 80/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1322 - val_loss: 1.1904
# Epoch 81/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1614 - val_loss: 1.1904
# Epoch 82/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1639 - val_loss: 1.1934
# Epoch 83/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2010 - val_loss: 1.2007
# Epoch 84/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2056 - val_loss: 1.2170
# Epoch 85/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1733 - val_loss: 1.2413
# Epoch 86/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1642 - val_loss: 1.2306
# Epoch 87/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1413 - val_loss: 1.2198
# Epoch 88/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1461 - val_loss: 1.2263
# Epoch 89/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1530 - val_loss: 1.1891
# Epoch 90/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1549 - val_loss: 1.1153
# Epoch 91/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1008 - val_loss: 1.0594
# Epoch 92/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0987 - val_loss: 1.0269
# Epoch 93/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1573 - val_loss: 1.0250
# Epoch 94/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1645 - val_loss: 1.0343
# Epoch 95/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1015 - val_loss: 1.0320
# Epoch 96/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1192 - val_loss: 1.0616
# Epoch 97/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0986 - val_loss: 1.0950
# Epoch 98/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1521 - val_loss: 1.1008
# Epoch 99/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1203 - val_loss: 1.0646
# Epoch 100/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0937 - val_loss: 1.0286
# Epoch 101/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1018 - val_loss: 1.0140
# Epoch 102/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1589 - val_loss: 1.0090
# Epoch 103/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1033 - val_loss: 1.0006
# Epoch 104/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0873 - val_loss: 1.0014
# Epoch 105/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0910 - val_loss: 1.0304
# Epoch 106/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1192 - val_loss: 1.0813
# Epoch 107/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0645 - val_loss: 1.1126
# Epoch 108/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1142 - val_loss: 1.0913
# Epoch 109/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1467 - val_loss: 0.9981
# Epoch 110/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0904 - val_loss: 0.9247
# Epoch 111/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1162 - val_loss: 0.8905
# Epoch 112/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1086 - val_loss: 0.8832
# Epoch 113/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1682 - val_loss: 0.9202
# Epoch 114/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0859 - val_loss: 0.9590
# Epoch 115/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1172 - val_loss: 0.9848
# Epoch 116/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0865 - val_loss: 0.9805
# Epoch 117/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0721 - val_loss: 0.9594
# Epoch 118/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1109 - val_loss: 0.9146
# Epoch 119/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1415 - val_loss: 0.8846
# Epoch 120/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0761 - val_loss: 0.8724
# Epoch 121/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1002 - val_loss: 0.8788
# Epoch 122/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0748 - val_loss: 0.9140
# Epoch 123/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0731 - val_loss: 0.9708
# Epoch 124/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0837 - val_loss: 0.9726
# Epoch 125/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0986 - val_loss: 0.9020
# Epoch 126/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0898 - val_loss: 0.8102
# Epoch 127/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0774 - val_loss: 0.7340
# Epoch 128/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0794 - val_loss: 0.7160
# Epoch 129/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0840 - val_loss: 0.7544
# Epoch 130/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0848 - val_loss: 0.8265
# Epoch 131/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1175 - val_loss: 0.8880
# Epoch 132/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1037 - val_loss: 0.8655
# Epoch 133/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0903 - val_loss: 0.7899
# Epoch 134/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0945 - val_loss: 0.7600
# Epoch 135/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0723 - val_loss: 0.7334
# Epoch 136/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1147 - val_loss: 0.7212
# Epoch 137/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1183 - val_loss: 0.6984
# Epoch 138/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0717 - val_loss: 0.6532
# Epoch 139/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1219 - val_loss: 0.6389
# Epoch 140/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0932 - val_loss: 0.6371
# Epoch 141/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0875 - val_loss: 0.6590
# Epoch 142/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1045 - val_loss: 0.6601
# Epoch 143/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0642 - val_loss: 0.6651
# Epoch 144/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0829 - val_loss: 0.6681
# Epoch 145/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0719 - val_loss: 0.6749
# Epoch 146/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0702 - val_loss: 0.7122
# Epoch 147/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0748 - val_loss: 0.7170
# Epoch 148/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0756 - val_loss: 0.6712
# Epoch 149/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0805 - val_loss: 0.6120
# Epoch 150/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0970 - val_loss: 0.5922
# Epoch 151/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0862 - val_loss: 0.5899
# Epoch 152/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0740 - val_loss: 0.5921
# Epoch 153/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0842 - val_loss: 0.5957
# Epoch 154/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0654 - val_loss: 0.6030
# Epoch 155/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0673 - val_loss: 0.6327
# Epoch 156/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0836 - val_loss: 0.6802
# Epoch 157/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0836 - val_loss: 0.6912
# Epoch 158/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0902 - val_loss: 0.5886
# Epoch 159/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0631 - val_loss: 0.5035
# Epoch 160/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0674 - val_loss: 0.4073
# Epoch 161/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0693 - val_loss: 0.3569
# Epoch 162/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1013 - val_loss: 0.3902
# Epoch 163/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1364 - val_loss: 0.4375
# Epoch 164/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1093 - val_loss: 0.4771
# Epoch 165/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0860 - val_loss: 0.4881
# Epoch 166/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0920 - val_loss: 0.4946
# Epoch 167/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0738 - val_loss: 0.4951
# Epoch 168/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0810 - val_loss: 0.4969
# Epoch 169/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0803 - val_loss: 0.5054
# Epoch 170/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0780 - val_loss: 0.5047
# Epoch 171/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0715 - val_loss: 0.4930
# Epoch 172/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0822 - val_loss: 0.4531
# Epoch 173/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0596 - val_loss: 0.4340
# Epoch 174/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0611 - val_loss: 0.4297
# Epoch 175/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0640 - val_loss: 0.4578
# Epoch 176/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0546 - val_loss: 0.4691
# Epoch 177/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0821 - val_loss: 0.4222
# Epoch 178/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0871 - val_loss: 0.3643
# Epoch 179/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0897 - val_loss: 0.3571
# Epoch 180/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0660 - val_loss: 0.3970
# Epoch 181/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0750 - val_loss: 0.4702
# Epoch 182/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0960 - val_loss: 0.4820
# Epoch 183/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0861 - val_loss: 0.4390
# Epoch 184/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0866 - val_loss: 0.4101
# Epoch 185/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0634 - val_loss: 0.3865
# Epoch 186/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0703 - val_loss: 0.3791
# Epoch 187/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0584 - val_loss: 0.4152
# Epoch 188/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0678 - val_loss: 0.3941
# Epoch 189/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0543 - val_loss: 0.3524
# Epoch 190/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0706 - val_loss: 0.3060
# Epoch 191/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0712 - val_loss: 0.2826
# Epoch 192/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0558 - val_loss: 0.2688
# Epoch 193/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0961 - val_loss: 0.2699
# Epoch 194/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0877 - val_loss: 0.3084
# Epoch 195/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0608 - val_loss: 0.3691
# Epoch 196/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0780 - val_loss: 0.4491
# Epoch 197/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0520 - val_loss: 0.5495
# Epoch 198/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0716 - val_loss: 0.6084
# Epoch 199/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0638 - val_loss: 0.5453
# Epoch 200/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0531 - val_loss: 0.4093
# Epoch 201/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0369 - val_loss: 0.3248
# Epoch 202/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0622 - val_loss: 0.2797
# Epoch 203/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0554 - val_loss: 0.2665
# Epoch 204/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0489 - val_loss: 0.2528
# Epoch 205/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0660 - val_loss: 0.2553
# Epoch 206/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0444 - val_loss: 0.2562
# Epoch 207/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0477 - val_loss: 0.2529
# Epoch 208/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0566 - val_loss: 0.2906
# Epoch 209/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0719 - val_loss: 0.2527
# Epoch 210/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0834 - val_loss: 0.2029
# Epoch 211/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0558 - val_loss: 0.2109
# Epoch 212/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0826 - val_loss: 0.2233
# Epoch 213/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0785 - val_loss: 0.2284
# Epoch 214/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0483 - val_loss: 0.2418
# Epoch 215/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0600 - val_loss: 0.2721
# Epoch 216/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0728 - val_loss: 0.3248
# Epoch 217/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0547 - val_loss: 0.3475
# Epoch 218/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0701 - val_loss: 0.3382
# Epoch 219/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0569 - val_loss: 0.3017
# Epoch 220/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0707 - val_loss: 0.2738
# Epoch 221/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0584 - val_loss: 0.2380
# Epoch 222/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0609 - val_loss: 0.2252
# Epoch 223/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0436 - val_loss: 0.2204
# Epoch 224/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0496 - val_loss: 0.2281
# Epoch 225/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0429 - val_loss: 0.2413
# Epoch 226/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0755 - val_loss: 0.2390
# Epoch 227/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0486 - val_loss: 0.1978
# Epoch 228/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0482 - val_loss: 0.1733
# Epoch 229/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0511 - val_loss: 0.1628
# Epoch 230/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0422 - val_loss: 0.1685
# Epoch 231/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0633 - val_loss: 0.1847
# Epoch 232/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0454 - val_loss: 0.1957
# Epoch 233/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0662 - val_loss: 0.1768
# Epoch 234/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0693 - val_loss: 0.1833
# Epoch 235/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0715 - val_loss: 0.1929
# Epoch 236/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0412 - val_loss: 0.1962
# Epoch 237/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0697 - val_loss: 0.2122
# Epoch 238/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0493 - val_loss: 0.2296
# Epoch 239/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0830 - val_loss: 0.1865
# Epoch 240/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0541 - val_loss: 0.1754
# Epoch 241/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0682 - val_loss: 0.1768
# Epoch 242/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0686 - val_loss: 0.1890
# Epoch 243/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0594 - val_loss: 0.2244
# Epoch 244/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0705 - val_loss: 0.2612
# Epoch 245/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0440 - val_loss: 0.2846
# Epoch 246/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0463 - val_loss: 0.2731
# Epoch 247/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0551 - val_loss: 0.2497
# Epoch 248/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0742 - val_loss: 0.2165
# Epoch 249/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0430 - val_loss: 0.1899
# Epoch 250/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0735 - val_loss: 0.1744
# Epoch 251/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0499 - val_loss: 0.1635
# Epoch 252/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0539 - val_loss: 0.1637
# Epoch 253/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0694 - val_loss: 0.1729
# Epoch 254/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0699 - val_loss: 0.1878
# Epoch 255/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0469 - val_loss: 0.2074
# Epoch 256/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0474 - val_loss: 0.2010
# Epoch 257/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0654 - val_loss: 0.1677
# Epoch 258/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0519 - val_loss: 0.1442
# Epoch 259/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0629 - val_loss: 0.1611
# Epoch 260/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0594 - val_loss: 0.1642
# Epoch 261/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0613 - val_loss: 0.1747
# Epoch 262/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0345 - val_loss: 0.2048
# Epoch 263/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0538 - val_loss: 0.2137
# Epoch 264/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0474 - val_loss: 0.2255
# Epoch 265/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0646 - val_loss: 0.2438
# Epoch 266/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0560 - val_loss: 0.2339
# Epoch 267/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0549 - val_loss: 0.2107
# Epoch 268/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0411 - val_loss: 0.1742
# Epoch 269/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0507 - val_loss: 0.1650
# Epoch 270/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0479 - val_loss: 0.1695
# Epoch 271/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0292 - val_loss: 0.1823
# Epoch 272/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0628 - val_loss: 0.1963
# Epoch 273/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0499 - val_loss: 0.2079
# Epoch 274/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0525 - val_loss: 0.2052
# Epoch 275/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0421 - val_loss: 0.1928
# Epoch 276/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0373 - val_loss: 0.1952
# Epoch 277/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0520 - val_loss: 0.2046
# Epoch 278/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0497 - val_loss: 0.2092
# Epoch 279/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0477 - val_loss: 0.2020
# Epoch 280/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0425 - val_loss: 0.1927
# Epoch 281/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0801 - val_loss: 0.2000
# Epoch 282/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0493 - val_loss: 0.2144
# Epoch 283/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0393 - val_loss: 0.2174
# Epoch 284/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0517 - val_loss: 0.2104
# Epoch 285/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0403 - val_loss: 0.1993
# Epoch 286/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0483 - val_loss: 0.1932
# Epoch 287/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0454 - val_loss: 0.2031
# Epoch 288/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0602 - val_loss: 0.1867
# Epoch 289/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0481 - val_loss: 0.1758
# Epoch 290/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0612 - val_loss: 0.1778
# Epoch 291/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0475 - val_loss: 0.1987
# Epoch 292/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0383 - val_loss: 0.2334
# Epoch 293/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0433 - val_loss: 0.2391
# Epoch 294/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0598 - val_loss: 0.2088
# Epoch 295/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0426 - val_loss: 0.2156
# Epoch 296/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0475 - val_loss: 0.2132
# Epoch 297/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0560 - val_loss: 0.1960
# Epoch 298/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0538 - val_loss: 0.1924
# Epoch 299/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0421 - val_loss: 0.1883
# Epoch 300/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0638 - val_loss: 0.1737
# Epoch 301/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0463 - val_loss: 0.1764
# Epoch 302/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0454 - val_loss: 0.2413
# Epoch 303/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0695 - val_loss: 0.2801
# Epoch 304/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0598 - val_loss: 0.2695
# Epoch 305/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0536 - val_loss: 0.2226
# Epoch 306/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0444 - val_loss: 0.1890
# Epoch 307/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0437 - val_loss: 0.1703
# Epoch 308/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0485 - val_loss: 0.1573
# Epoch 309/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0392 - val_loss: 0.1480
# Epoch 310/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0318 - val_loss: 0.1391
# Epoch 311/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0491 - val_loss: 0.1332
# Epoch 312/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0427 - val_loss: 0.1409
# Epoch 313/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0392 - val_loss: 0.1436
# Epoch 314/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0397 - val_loss: 0.1472
# Epoch 315/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0431 - val_loss: 0.1425
# Epoch 316/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0425 - val_loss: 0.1498
# Epoch 317/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0479 - val_loss: 0.1615
# Epoch 318/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0520 - val_loss: 0.1679
# Epoch 319/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0577 - val_loss: 0.1676
# Epoch 320/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0542 - val_loss: 0.1761
# Epoch 321/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0862 - val_loss: 0.1714
# Epoch 322/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0575 - val_loss: 0.1928
# Epoch 323/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0401 - val_loss: 0.2287
# Epoch 324/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0485 - val_loss: 0.2536
# Epoch 325/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0592 - val_loss: 0.2169
# Epoch 326/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0421 - val_loss: 0.1888
# Epoch 327/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0634 - val_loss: 0.1874
# Epoch 328/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0607 - val_loss: 0.1964
# Epoch 329/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0426 - val_loss: 0.2165
# Epoch 330/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0405 - val_loss: 0.2316
# Epoch 331/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0417 - val_loss: 0.2425
# Epoch 332/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0400 - val_loss: 0.2488
# Epoch 333/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0449 - val_loss: 0.2584
# Epoch 334/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0467 - val_loss: 0.2580
# Epoch 335/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0463 - val_loss: 0.2449
# Epoch 336/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0350 - val_loss: 0.2365
# Epoch 337/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0445 - val_loss: 0.2349
# Epoch 338/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0370 - val_loss: 0.2308
# Epoch 339/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0306 - val_loss: 0.2039
# Epoch 340/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0427 - val_loss: 0.1937
# Epoch 341/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0511 - val_loss: 0.1894
# Epoch 342/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0672 - val_loss: 0.1888
# Epoch 343/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0595 - val_loss: 0.2063
# Epoch 344/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0331 - val_loss: 0.2274
# Epoch 345/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0445 - val_loss: 0.2533
# Epoch 346/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0570 - val_loss: 0.2487
# Epoch 347/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0543 - val_loss: 0.2255
# Epoch 348/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0463 - val_loss: 0.2054
# Epoch 349/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0304 - val_loss: 0.1913
# Epoch 350/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0388 - val_loss: 0.1763
# Epoch 351/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0328 - val_loss: 0.1603
# Epoch 352/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0434 - val_loss: 0.1523
# Epoch 353/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0546 - val_loss: 0.1618
# Epoch 354/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0464 - val_loss: 0.1664
# Epoch 355/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0605 - val_loss: 0.1664
# Epoch 356/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0348 - val_loss: 0.1834
# Epoch 357/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0422 - val_loss: 0.1981
# Epoch 358/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0400 - val_loss: 0.2001
# Epoch 359/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0364 - val_loss: 0.1989
# Epoch 360/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0408 - val_loss: 0.2037
# Epoch 361/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0407 - val_loss: 0.2075
# Epoch 362/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0297 - val_loss: 0.2313
# Epoch 363/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0555 - val_loss: 0.2343
# Epoch 364/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0288 - val_loss: 0.2482
# Epoch 365/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0563 - val_loss: 0.2496
# Epoch 366/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0428 - val_loss: 0.2342
# Epoch 367/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0485 - val_loss: 0.2208
# Epoch 368/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0442 - val_loss: 0.1946
# Epoch 369/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0428 - val_loss: 0.1754
# Epoch 370/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0312 - val_loss: 0.1821
# Epoch 371/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0330 - val_loss: 0.1877
# Epoch 372/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0319 - val_loss: 0.1874
# Epoch 373/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0337 - val_loss: 0.1956
# Epoch 374/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0430 - val_loss: 0.1968
# Epoch 375/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0472 - val_loss: 0.1873
# Epoch 376/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0323 - val_loss: 0.1846
# Epoch 377/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0379 - val_loss: 0.1761
# Epoch 378/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0520 - val_loss: 0.1641
# Epoch 379/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0337 - val_loss: 0.1405
# Epoch 380/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0308 - val_loss: 0.1255
# Epoch 381/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0364 - val_loss: 0.1211
# Epoch 382/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0388 - val_loss: 0.1255
# Epoch 383/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0465 - val_loss: 0.1329
# Epoch 384/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0428 - val_loss: 0.1480
# Epoch 385/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0465 - val_loss: 0.1654
# Epoch 386/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0342 - val_loss: 0.1510
# Epoch 387/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0384 - val_loss: 0.1363
# Epoch 388/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0525 - val_loss: 0.1399
# Epoch 389/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0496 - val_loss: 0.1418
# Epoch 390/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0340 - val_loss: 0.1522
# Epoch 391/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0387 - val_loss: 0.1586
# Epoch 392/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0274 - val_loss: 0.1535
# Epoch 393/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0468 - val_loss: 0.1404
# Epoch 394/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0353 - val_loss: 0.1363
# Epoch 395/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0282 - val_loss: 0.1332
# Epoch 396/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0398 - val_loss: 0.1439
# Epoch 397/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0401 - val_loss: 0.1568
# Epoch 398/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0380 - val_loss: 0.1536
# Epoch 399/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0342 - val_loss: 0.1480
# Epoch 400/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0338 - val_loss: 0.1464
# Epoch 401/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0331 - val_loss: 0.1467
# Epoch 402/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0431 - val_loss: 0.1622
# Epoch 403/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0266 - val_loss: 0.1699
# Epoch 404/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0432 - val_loss: 0.1612
# Epoch 405/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0288 - val_loss: 0.1535
# Epoch 406/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0406 - val_loss: 0.1456
# Epoch 407/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0214 - val_loss: 0.1392
# Epoch 408/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0315 - val_loss: 0.1388
# Epoch 409/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0361 - val_loss: 0.1496
# Epoch 410/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0377 - val_loss: 0.1604
# Epoch 411/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0368 - val_loss: 0.1498
# Epoch 412/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0337 - val_loss: 0.1429
# Epoch 413/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0310 - val_loss: 0.1413
# Epoch 414/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0459 - val_loss: 0.1327
# Epoch 415/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0355 - val_loss: 0.1305
# Epoch 416/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0394 - val_loss: 0.1510
# Epoch 417/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0288 - val_loss: 0.1567
# Epoch 418/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0525 - val_loss: 0.1564
# Epoch 419/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0328 - val_loss: 0.1550
# Epoch 420/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0395 - val_loss: 0.1651
# Epoch 421/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0564 - val_loss: 0.1705
# Epoch 422/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0288 - val_loss: 0.1713
# Epoch 423/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0415 - val_loss: 0.1687
# Epoch 424/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0300 - val_loss: 0.1788
# Epoch 425/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0448 - val_loss: 0.1971
# Epoch 426/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0320 - val_loss: 0.1965
# Epoch 427/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0393 - val_loss: 0.1630
# Epoch 428/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0340 - val_loss: 0.1331
# Epoch 429/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0284 - val_loss: 0.1259
# Epoch 430/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0350 - val_loss: 0.1255
# Epoch 431/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0400 - val_loss: 0.1267
# Epoch 432/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0328 - val_loss: 0.1452
# Epoch 433/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0418 - val_loss: 0.1953
# Epoch 434/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0401 - val_loss: 0.2304
# Epoch 435/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0346 - val_loss: 0.2285
# Epoch 436/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0375 - val_loss: 0.1876
# Epoch 437/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0307 - val_loss: 0.1627
# Epoch 438/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0291 - val_loss: 0.1445
# Epoch 439/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0312 - val_loss: 0.1377
# Epoch 440/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0532 - val_loss: 0.1372
# Epoch 441/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0288 - val_loss: 0.1519
# Epoch 442/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0400 - val_loss: 0.1792
# Epoch 443/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0364 - val_loss: 0.2034
# Epoch 444/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0351 - val_loss: 0.2162
# Epoch 445/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0316 - val_loss: 0.1976
# Epoch 446/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0351 - val_loss: 0.1655
# Epoch 447/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0299 - val_loss: 0.1513
# Epoch 448/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0233 - val_loss: 0.1498
# Epoch 449/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0331 - val_loss: 0.1538
# Epoch 450/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0362 - val_loss: 0.1566
# Epoch 451/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0370 - val_loss: 0.1569
# Epoch 452/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0313 - val_loss: 0.1561
# Epoch 453/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0382 - val_loss: 0.1540
# Epoch 454/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0349 - val_loss: 0.1528
# Epoch 455/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0440 - val_loss: 0.1534
# Epoch 456/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0352 - val_loss: 0.1762
# Epoch 457/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0286 - val_loss: 0.2131
# Epoch 458/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0486 - val_loss: 0.2126
# Epoch 459/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0355 - val_loss: 0.1946
# Epoch 460/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0439 - val_loss: 0.1752
# Epoch 461/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0343 - val_loss: 0.1732
# Epoch 462/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0381 - val_loss: 0.1770
# Epoch 463/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0393 - val_loss: 0.1897
# Epoch 464/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0306 - val_loss: 0.1788
# Epoch 465/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0271 - val_loss: 0.1686
# Epoch 466/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0354 - val_loss: 0.1624
# Epoch 467/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0325 - val_loss: 0.1570
# Epoch 468/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0405 - val_loss: 0.1593
# Epoch 469/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0355 - val_loss: 0.1639
# Epoch 470/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0252 - val_loss: 0.1707
# Epoch 471/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0295 - val_loss: 0.1775
# Epoch 472/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0279 - val_loss: 0.2004
# Epoch 473/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0326 - val_loss: 0.2185
# Epoch 474/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0296 - val_loss: 0.2127
# Epoch 475/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0421 - val_loss: 0.1905
# Epoch 476/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0247 - val_loss: 0.1712
# Epoch 477/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0211 - val_loss: 0.1599
# Epoch 478/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0314 - val_loss: 0.1540
# Epoch 479/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0239 - val_loss: 0.1558
# Epoch 480/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0261 - val_loss: 0.1674
# Epoch 481/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0400 - val_loss: 0.1743
# Epoch 482/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0223 - val_loss: 0.1791
# Epoch 483/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0259 - val_loss: 0.1819
# Epoch 484/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0244 - val_loss: 0.1785
# Epoch 485/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0283 - val_loss: 0.1716
# Epoch 486/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0301 - val_loss: 0.1649
# Epoch 487/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0247 - val_loss: 0.1704
# Epoch 488/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0258 - val_loss: 0.1765
# Epoch 489/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0299 - val_loss: 0.1890
# Epoch 490/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0294 - val_loss: 0.1928
# Epoch 491/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0262 - val_loss: 0.1723
# Epoch 492/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0289 - val_loss: 0.1650
# Epoch 493/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0325 - val_loss: 0.1585
# Epoch 494/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0285 - val_loss: 0.1582
# Epoch 495/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0298 - val_loss: 0.1664
# Epoch 496/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0374 - val_loss: 0.2075
# Epoch 497/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0297 - val_loss: 0.2454
# Epoch 498/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0330 - val_loss: 0.2518
# Epoch 499/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0291 - val_loss: 0.2408
# Epoch 500/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0303 - val_loss: 0.2161
# Epoch 501/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0299 - val_loss: 0.1977
# Epoch 502/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0488 - val_loss: 0.1840
# Epoch 503/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0243 - val_loss: 0.1764
# Epoch 504/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0415 - val_loss: 0.1759
# Epoch 505/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0271 - val_loss: 0.1774
# Epoch 506/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0274 - val_loss: 0.1820
# Epoch 507/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0367 - val_loss: 0.1865
# Epoch 508/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0301 - val_loss: 0.2008
# Epoch 509/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0268 - val_loss: 0.2110
# Epoch 510/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0271 - val_loss: 0.2067
# Epoch 511/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0453 - val_loss: 0.1874
# Epoch 512/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0390 - val_loss: 0.1825
# Epoch 513/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0328 - val_loss: 0.1760
# Epoch 514/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0536 - val_loss: 0.1755
# Epoch 515/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0486 - val_loss: 0.1767
# Epoch 516/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0249 - val_loss: 0.1944
# Epoch 517/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0444 - val_loss: 0.1895
# Epoch 518/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0447 - val_loss: 0.1799
# Epoch 519/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0276 - val_loss: 0.1838
# Epoch 520/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0347 - val_loss: 0.1875
# Epoch 521/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0404 - val_loss: 0.1799
# Epoch 522/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0370 - val_loss: 0.1931
# Epoch 523/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0385 - val_loss: 0.2109
# Epoch 524/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0499 - val_loss: 0.2102
# Epoch 525/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0416 - val_loss: 0.1992
# Epoch 526/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0300 - val_loss: 0.1986
# Epoch 527/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0338 - val_loss: 0.2077
# Epoch 528/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0273 - val_loss: 0.2096
# Epoch 529/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0309 - val_loss: 0.2030
# Epoch 530/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0282 - val_loss: 0.2054
# Epoch 531/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0341 - val_loss: 0.2091
# Epoch 532/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0302 - val_loss: 0.2104
# Epoch 533/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0306 - val_loss: 0.2101
# Epoch 534/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0380 - val_loss: 0.2272
# Epoch 535/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0269 - val_loss: 0.2719
# Epoch 536/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0364 - val_loss: 0.3058
# Epoch 537/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0378 - val_loss: 0.2956
# Epoch 538/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0308 - val_loss: 0.2706
# Epoch 539/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0390 - val_loss: 0.2503
# Epoch 540/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0261 - val_loss: 0.2329
# Epoch 541/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0333 - val_loss: 0.2295
# Epoch 542/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0315 - val_loss: 0.2234
# Epoch 543/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0239 - val_loss: 0.2004
# Epoch 544/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0326 - val_loss: 0.1760
# Epoch 545/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0314 - val_loss: 0.1675
# Epoch 546/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0416 - val_loss: 0.1668
# Epoch 547/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0191 - val_loss: 0.1644
# Epoch 548/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0257 - val_loss: 0.1654
# Epoch 549/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0256 - val_loss: 0.1701
# Epoch 550/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0240 - val_loss: 0.1637
# Epoch 551/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0325 - val_loss: 0.1548
# Epoch 552/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0320 - val_loss: 0.1534
# Epoch 553/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0269 - val_loss: 0.1558
# Epoch 554/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0328 - val_loss: 0.1550
# Epoch 555/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0264 - val_loss: 0.1605
# Epoch 556/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0320 - val_loss: 0.1680
# ...
# Epoch 616/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0184 - val_loss: 0.1730
# Epoch 617/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0283 - val_loss: 0.1681
# Epoch 618/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0304 - val_loss: 0.1688
# Epoch 619/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0269 - val_loss: 0.1708
# Epoch 620/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0226 - val_loss: 0.1793
# Epoch 621/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0228 - val_loss: 0.1654
# Epoch 622/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0238 - val_loss: 0.1552
# Epoch 623/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0283 - val_loss: 0.1644
# Epoch 624/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0334 - val_loss: 0.1649
# Epoch 625/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0184 - val_loss: 0.1756
# Epoch 626/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0279 - val_loss: 0.1944
# Epoch 627/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0272 - val_loss: 0.2145
# Epoch 628/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0273 - val_loss: 0.2234
# Epoch 629/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0238 - val_loss: 0.2186
# Epoch 630/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0234 - val_loss: 0.2075
# Epoch 631/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0252 - val_loss: 0.2018
# Epoch 632/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0241 - val_loss: 0.1978
# Epoch 633/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0209 - val_loss: 0.1969
# Epoch 634/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0314 - val_loss: 0.2053
# Epoch 635/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0237 - val_loss: 0.2244
# Epoch 636/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0357 - val_loss: 0.2307
# Epoch 637/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0337 - val_loss: 0.2332
# Epoch 638/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0233 - val_loss: 0.2226
# Epoch 639/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0326 - val_loss: 0.2033
# Epoch 640/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0317 - val_loss: 0.1954
# Epoch 641/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0286 - val_loss: 0.1906
# Epoch 642/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0262 - val_loss: 0.1866
# Epoch 643/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0326 - val_loss: 0.1863
# Epoch 644/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0220 - val_loss: 0.1825
# Epoch 645/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0201 - val_loss: 0.1780
# Epoch 646/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0221 - val_loss: 0.1768
# Epoch 647/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0230 - val_loss: 0.1847
# Epoch 648/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0227 - val_loss: 0.1991
# Epoch 649/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0195 - val_loss: 0.2203
# Epoch 650/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0204 - val_loss: 0.2366
# Epoch 651/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0210 - val_loss: 0.2358
# Epoch 652/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0238 - val_loss: 0.2129
# Epoch 653/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0421 - val_loss: 0.1965
# Epoch 654/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0358 - val_loss: 0.1897
# Epoch 655/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0169 - val_loss: 0.1880
# Epoch 656/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0297 - val_loss: 0.1842
# Epoch 657/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0228 - val_loss: 0.1819
# Epoch 658/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0281 - val_loss: 0.1835
# Epoch 659/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0242 - val_loss: 0.1734
# Epoch 660/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0254 - val_loss: 0.1801
# Epoch 661/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0279 - val_loss: 0.1973
# Epoch 662/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0282 - val_loss: 0.2097
# Epoch 663/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0251 - val_loss: 0.2183
# Epoch 664/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0291 - val_loss: 0.2160
# Epoch 665/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0191 - val_loss: 0.2055
# Epoch 666/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0210 - val_loss: 0.1907
# Epoch 667/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0250 - val_loss: 0.1815
# Epoch 668/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0184 - val_loss: 0.1764
# Epoch 669/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0198 - val_loss: 0.1752
# Epoch 670/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0268 - val_loss: 0.1778
# Epoch 671/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0296 - val_loss: 0.1827
# Epoch 672/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0255 - val_loss: 0.1847
# Epoch 673/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0209 - val_loss: 0.1868
# Epoch 674/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0224 - val_loss: 0.1879
# Epoch 675/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0261 - val_loss: 0.1882
# Epoch 676/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0216 - val_loss: 0.1891
# Epoch 677/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0125 - val_loss: 0.1980
# Epoch 678/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0259 - val_loss: 0.1979
# Epoch 679/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0202 - val_loss: 0.1879
# Epoch 680/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0243 - val_loss: 0.1831
# Epoch 681/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0298 - val_loss: 0.1956
# Epoch 682/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0191 - val_loss: 0.2186
# Epoch 683/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0274 - val_loss: 0.2249
# Epoch 684/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0280 - val_loss: 0.2029
# Epoch 685/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0177 - val_loss: 0.1828
# Epoch 686/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0229 - val_loss: 0.1718
# Epoch 687/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0180 - val_loss: 0.1679
# Epoch 688/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0273 - val_loss: 0.1653
# Epoch 689/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0231 - val_loss: 0.1636
# Epoch 690/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0434 - val_loss: 0.1709
# Epoch 691/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0284 - val_loss: 0.1862
# Epoch 692/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0239 - val_loss: 0.1934
# Epoch 693/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0292 - val_loss: 0.1878
# Epoch 694/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0219 - val_loss: 0.1798
# Epoch 695/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0192 - val_loss: 0.1746
# Epoch 696/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0241 - val_loss: 0.1748
# Epoch 697/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187 - val_loss: 0.1868
# Epoch 698/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0198 - val_loss: 0.2049
# Epoch 699/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0253 - val_loss: 0.2180
# Epoch 700/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0231 - val_loss: 0.2154
# Epoch 701/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0185 - val_loss: 0.2205
# Epoch 702/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0241 - val_loss: 0.2077
# Epoch 703/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0228 - val_loss: 0.1915
# Epoch 704/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0163 - val_loss: 0.1851
# Epoch 705/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0242 - val_loss: 0.1920
# Epoch 706/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0335 - val_loss: 0.2212
# Epoch 707/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0236 - val_loss: 0.2590
# Epoch 708/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0250 - val_loss: 0.2808
# Epoch 709/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0313 - val_loss: 0.2616
# Epoch 710/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0244 - val_loss: 0.2411
# Epoch 711/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0328 - val_loss: 0.2168
# Epoch 712/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0263 - val_loss: 0.2028
# Epoch 713/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0246 - val_loss: 0.1963
# Epoch 714/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0237 - val_loss: 0.2201
# Epoch 715/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0293 - val_loss: 0.2226
# Epoch 716/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0307 - val_loss: 0.2034
# Epoch 717/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0244 - val_loss: 0.1886
# Epoch 718/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0267 - val_loss: 0.1805
# Epoch 719/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0231 - val_loss: 0.1773
# Epoch 720/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0272 - val_loss: 0.1804
# Epoch 721/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0362 - val_loss: 0.1846
# Epoch 722/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0326 - val_loss: 0.1898
# Epoch 723/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0263 - val_loss: 0.1998
# Epoch 724/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0186 - val_loss: 0.1956
# Epoch 725/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0313 - val_loss: 0.1871
# Epoch 726/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0282 - val_loss: 0.1841
# Epoch 727/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0254 - val_loss: 0.1923
# Epoch 728/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0261 - val_loss: 0.1937
# Epoch 729/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0239 - val_loss: 0.1922
# Epoch 730/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0258 - val_loss: 0.1918
# Epoch 731/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0308 - val_loss: 0.1921
# Epoch 732/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0255 - val_loss: 0.1968
# Epoch 733/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0256 - val_loss: 0.1884
# Epoch 734/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0407 - val_loss: 0.1803
# Epoch 735/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0237 - val_loss: 0.1796
# Epoch 736/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0283 - val_loss: 0.1810
# Epoch 737/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0189 - val_loss: 0.1765
# Epoch 738/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0248 - val_loss: 0.1759
# Epoch 739/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0178 - val_loss: 0.1724
# Epoch 740/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0251 - val_loss: 0.1681
# Epoch 741/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0351 - val_loss: 0.1659
# Epoch 742/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0208 - val_loss: 0.1692
# Epoch 743/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0168 - val_loss: 0.1796
# Epoch 744/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0228 - val_loss: 0.2023
# Epoch 745/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0237 - val_loss: 0.2174
# Epoch 746/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0218 - val_loss: 0.2120
# Epoch 747/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0219 - val_loss: 0.1929
# Epoch 748/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0251 - val_loss: 0.1853
# Epoch 749/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0191 - val_loss: 0.1958
# Epoch 750/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0205 - val_loss: 0.2025
# Epoch 751/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0317 - val_loss: 0.2110
# Epoch 752/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0202 - val_loss: 0.2130
# Epoch 753/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0321 - val_loss: 0.2038
# Epoch 754/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0213 - val_loss: 0.1984
# Epoch 755/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0231 - val_loss: 0.1884
# Epoch 756/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0241 - val_loss: 0.1846
# Epoch 757/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0185 - val_loss: 0.1840
# Epoch 758/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0225 - val_loss: 0.1862
# Epoch 759/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0301 - val_loss: 0.1798
# Epoch 760/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0377 - val_loss: 0.1749
# Epoch 761/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0275 - val_loss: 0.1702
# Epoch 762/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0184 - val_loss: 0.1659
# Epoch 763/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0194 - val_loss: 0.1679
# Epoch 764/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0183 - val_loss: 0.1690
# Epoch 765/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0341 - val_loss: 0.1706
# Epoch 766/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0235 - val_loss: 0.1776
# Epoch 767/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0228 - val_loss: 0.1832
# Epoch 768/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0169 - val_loss: 0.1892
# Epoch 769/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0180 - val_loss: 0.1947
# Epoch 770/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0189 - val_loss: 0.1903
# Epoch 771/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0215 - val_loss: 0.1967
# Epoch 772/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0221 - val_loss: 0.2138
# Epoch 773/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0293 - val_loss: 0.2209
# Epoch 774/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0274 - val_loss: 0.2201
# Epoch 775/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0214 - val_loss: 0.2141
# Epoch 776/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0146 - val_loss: 0.2061
# Epoch 777/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0307 - val_loss: 0.2010
# Epoch 778/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0276 - val_loss: 0.2046
# Epoch 779/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0163 - val_loss: 0.2161
# Epoch 780/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0260 - val_loss: 0.2031
# Epoch 781/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0258 - val_loss: 0.1869
# Epoch 782/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0238 - val_loss: 0.1754
# Epoch 783/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0260 - val_loss: 0.1855
# Epoch 784/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0256 - val_loss: 0.2027
# Epoch 785/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0167 - val_loss: 0.2083
# Epoch 786/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0142 - val_loss: 0.2011
# Epoch 787/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0205 - val_loss: 0.1925
# Epoch 788/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0197 - val_loss: 0.1968
# Epoch 789/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0235 - val_loss: 0.2048
# Epoch 790/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0257 - val_loss: 0.1877
# Epoch 791/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0314 - val_loss: 0.1913
# Epoch 792/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0347 - val_loss: 0.2008
# Epoch 793/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0296 - val_loss: 0.1874
# Epoch 794/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0359 - val_loss: 0.1819
# Epoch 795/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0291 - val_loss: 0.1925
# Epoch 796/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0223 - val_loss: 0.1897
# Epoch 797/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0339 - val_loss: 0.1963
# Epoch 798/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0257 - val_loss: 0.2137
# Epoch 799/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0229 - val_loss: 0.2311
# Epoch 800/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0248 - val_loss: 0.2352
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step

# %%
################# Datos para stackingregressor #################


# Características temporales enriquecidas

df['Rolling_Mean_8_O-'] = df['O-'].rolling(8).mean()
df['Rolling_STD_4_O-'] = df['O-'].rolling(4).std()
df['Diff_1_O-'] = df['O-'].diff(1)


# Eliminar nulos generados por los lags/rolling
df.dropna(inplace=True)
# Definir features y target para stackingregressor
features_stk = [col for col in df.columns if col.startswith('Lag_O-') or 'Rolling_Mean_8_O-' in col or 'Rolling_STD_4_O-' in col or 'Diff_1_O-' in col or col in ['Week', 'Month','Quarter']]

X_stk = df[features_stk]
y = df[target]

scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X_stk)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1)).flatten()
X_scaled = pd.DataFrame(X_scaled, columns=X_stk.columns)
X_train_stk, X_test_stk, y_train_stk, y_test_stk = train_test_split(X_scaled, y_scaled, shuffle=False, test_size=0.2)

# %%
# StackingRegressor

modelo_stk = entrenar_stacking(X_train_stk, y_train_stk)
y_pred_stk = modelo_stk.predict(X_test_stk)
y_pred_stk = scaler_y.inverse_transform(y_pred_stk.reshape(-1, 1))
y_real_stk = scaler_y.inverse_transform(y_test_stk.reshape(-1, 1))

# %%
# ------------------------- MÉTRICAS PARA O- -------------------------

print("* MÉTRICAS LSTM PARA O-")
print(f"MAE: {mean_absolute_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"RMSE: {mean_squared_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"R²: {r2_score(y_real_lstm, y_pred_lstm):.2f}")

print("\n* MÉTRICAS STACKING PARA O-")
print(f"MAE: {mean_absolute_error(y_real_stk, y_pred_stk):.2f}")
print(f"RMSE: {mean_squared_error(y_real_stk, y_pred_stk):.2f}")
print(f"R²: {r2_score(y_real_stk, y_pred_stk):.2f}")
# Out:
# * MÉTRICAS LSTM PARA O-
# MAE: 17.31
# RMSE: 385.90
# R²: -0.50
#
# * MÉTRICAS STACKING PARA O-
# MAE: 8.74
# RMSE: 125.81
# R²: 0.42

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_real_stk), len(y_pred_stk))

# Convertir todo a 1D por seguridad
y_test_plot = y_test[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_real_plot = y_real_lstm[:min_len].reshape(-1)

# Plot
plt.figure(figsize=(12, 5))
plt.plot(np.arange(min_len), y_real_stk[:min_len], label="Real", color='black')
plt.plot(np.arange(min_len), y_pred_stk[:min_len], label="StackingRegressor", linestyle='--')
plt.plot(np.arange(min_len), y_pred_lstm[:min_len], label="LSTM", linestyle=':')
plt.title("Comparación de Predicciones: LSTM vs StackingRegressor (Demanda O-)")
plt.xlabel("Semanas")
plt.ylabel("Demanda")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_pred_stk))
y_real_plot = y_real_lstm[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
fig.suptitle("Comparación de Series y Análisis ACF/PACF", fontsize=16)

# Serie real
axes[0, 0].plot(y_real_plot, color='black')
axes[0, 0].set_title("Serie real O- ")
axes[0, 0].grid(True)

# ACF real
plot_acf(y_real_plot, lags=min(20, len(y_real_plot)//2 - 1), ax=axes[0, 1])
axes[0, 1].set_title("ACF O- - Real")

# LSTM predicción
axes[1, 0].plot(y_pred_lstm_plot, color='blue')
axes[1, 0].set_title("Predicción O-  LSTM")
axes[1, 0].grid(True)

# ACF LSTM
plot_acf(y_pred_lstm_plot, lags=min(20, len(y_pred_lstm_plot)//2 - 1), ax=axes[1, 1])
axes[1, 1].set_title("ACF O-  - LSTM")

# Stacking predicción
axes[2, 0].plot(y_pred_stk_plot, color='green')
axes[2, 0].set_title("Predicción O-  Stacking")
axes[2, 0].grid(True)

# ACF Stacking
plot_acf(y_pred_stk_plot, lags=min(20, len(y_pred_stk_plot)//2 - 1), ax=axes[2, 1])
axes[2, 1].set_title("ACF O-  - Stacking")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig("comparativa_modelos_acf.png", dpi=300)
plt.show()
