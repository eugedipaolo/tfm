# %%
# ------------------------- IMPORTACIONES -------------------------
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('HDHI Admission data.csv', sep=',')

# %%
# Fechas convertidas a datetime
df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
df['D.O.A'] = df['D.O.A_manual']
df.drop(columns='D.O.A_manual', inplace=True)

# Verificar cuántas fechas nulas hay en cada una
nulos_doa = df['D.O.A'].isna().sum()

# Rango de fechas disponibles
min_doa = df['D.O.A'].min()
max_doa = df['D.O.A'].max()

duration_col = 'DURATION OF STAY'

# Ver estadísticas generales
duration_stats = df[duration_col].describe()

# Verificar valores negativos o inconsistentes
invalid_duration = df[df[duration_col] < 0]

duration_stats, invalid_duration.shape[0]
# Out:
# /var/folders/tm/_mcsvvpd5ml8xhw8l_7314j80000gn/T/ipykernel_47009/1322510359.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
# (count    15757.000000
#  mean         6.415054
#  std          5.011421
#  min          1.000000
#  25%          3.000000
#  50%          5.000000
#  75%          8.000000
#  max         98.000000
#  Name: DURATION OF STAY, dtype: float64,
#  0)

# %%
df = df.sort_values(by='D.O.A')

# %%
df['HB'] = pd.to_numeric(df['HB'], errors='coerce')
conteo = (df['HB'] < 9).sum()

print(f"Número de registros con HB < 9: {conteo}")
# Out:
# Número de registros con HB < 9: 1339

# %%
# Convertir columnas relevantes a numérico, manejando valores no numéricos
numeric_cols = ['HB', 'DURATION OF STAY', 'duration of intensive unit stay', 'CREATININE', 'UREA', 'PLATELETS', 'BNP', 'EF']
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Crear la variable proxy para transfusión
def create_transfusion_proxy(row):
    # Criterio principal: Hemoglobina baja (<8 g/dL) o anemia severa
    hb_condition = row['HB'] < 8 if pd.notna(row['HB']) else False
    severe_anemia_condition = row['SEVERE ANAEMIA'] == 1 if 'SEVERE ANAEMIA' in row else False
    
    # condiciones de gravedad que podrían requerir transfusión
    cva_bleed = row['CVA BLEED'] == 1 if 'CVA BLEED' in row else False
    stemi = row['STEMI'] == 1 if 'STEMI' in row else False
    cardiogenic_shock = row['CARDIOGENIC SHOCK'] == 1 if 'CARDIOGENIC SHOCK' in row else False
    shock = row['SHOCK'] == 1 if 'SHOCK' in row else False
    pulmonary_embolism = row['PULMONARY EMBOLISM'] == 1 if 'PULMONARY EMBOLISM' in row else False
    ckd = row['CKD'] == 1 if 'CKD' in row else False
    emergencia = row['TYPE OF ADMISSION-EMERGENCY/OPD']=='E' if 'TYPE OF ADMISSION-EMERGENCY/OPD' in row else False
    
    # Duración de la estancia (>7 días) o estancia en UCI (>1 días)
    long_stay = row['DURATION OF STAY'] > 7 if pd.notna(row['DURATION OF STAY']) else False
    icu_stay = row['duration of intensive unit stay'] > 1 if pd.notna(row['duration of intensive unit stay']) else False
    
    # Lógica para la variable proxy:
    # Necesita transfusión si:
    # HB < 9 o SEVERE ANAEMIA == 1
    # si hay condiciones graves (CVA BLEED, STEMI, SHOCK) con HB < 10
    # si hay CKD con HB < 9
    if (hb_condition or severe_anemia_condition or
        (row['HB'] < 10 and pd.notna(row['HB']) and (cva_bleed or stemi or cardiogenic_shock or shock or pulmonary_embolism)) or
        (ckd and row['HB'] < 9 and pd.notna(row['HB'])) or 
        (emergencia) or
        (long_stay and icu_stay and row['HB'] < 10 and pd.notna(row['HB']))):
        return 1
    return 0

# Aplicar la función para crear la columna 'needs_transfusion'
df['needs_transfusion'] = df.apply(create_transfusion_proxy, axis=1)

# %%
# Asignar Blood Type
np.random.seed(42)

# Asignar tipos de sangre con distribución ajustada para India
blood_types = ['A+', 'A-', 'B+', 'B-', 'O+', 'O-', 'AB+', 'AB-']
probabilities = [0.21, 0.02, 0.33, 0.02, 0.32, 0.02, 0.07, 0.01]
         
df['Blood Type'] = np.random.choice(blood_types, size=len(df), p=probabilities)

# Verificar la distribución de los tipos de sangre generados
print("Distribución de tipos de sangre en el dataset (%):")
print(df['Blood Type'].value_counts(normalize=True).sort_index() * 100)
# Out:
# Distribución de tipos de sangre en el dataset (%):
# Blood Type
# A+     21.349242
# A-      1.980072
# AB+     7.044488
# AB-     0.913880
# B+     33.375643
# B-      1.935648
# O+     31.611347
# O-      1.789681
# Name: proportion, dtype: float64

# %%
# Elimino variables para trabajar con un conjunto de datos con los datos relevantes para este trabajo
cols_utiles = ['D.O.A', 'DURATION OF STAY', 'needs_transfusion', 'Blood Type']

# Filtrar el DataFrame conservando solo esas columnas
df = df[cols_utiles].copy()

# %%
# Ahora realizaré un análisis para saber que tipo de comportamiento tiene needs_transfusion en el tiempo
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Función para seleccionar rango denso de fechas
def detectar_rango_denso(df_org, date_col='D.O.A', min_por_semana=10, buffer_semanas=2):
    df_tmp = df_org.copy()
    df_tmp[date_col] = pd.to_datetime(df_tmp[date_col], errors='coerce')
    weekly_counts = df_tmp.groupby(df_tmp[date_col].dt.to_period('W').apply(lambda r: r.start_time)).size()
    weeks_valid = weekly_counts[weekly_counts >= min_por_semana]
    if weeks_valid.empty:
        return None  # No hay rango denso suficiente
    start = weeks_valid.index.min() - pd.Timedelta(weeks=buffer_semanas)
    end = weeks_valid.index.max() + pd.Timedelta(weeks=buffer_semanas)
    return start, end

rango = detectar_rango_denso(df, min_por_semana=20)

# Aplicar filtro al dataframe original si hay rango válido
if rango:
    df_filtrado = df[
        (df['D.O.A'] > rango[0]) &
        (df['D.O.A'] <= rango[1])
    ]
else:
    df_filtrado = pd.DataFrame()  # sin datos útiles

df = df_filtrado.copy()
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Agrupo por semana y tipo de sangre
df = df[df['needs_transfusion'] == 1]
weekly_demand = df.groupby([df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time), 'Blood Type'])['needs_transfusion'].sum().unstack().fillna(0)

# %%
serie_o_plus = weekly_demand['O+']
adf_result = adfuller(serie_o_plus)

# Graficar ACF y PACF
fig, axes = plt.subplots(2, 1, figsize=(10, 8))
plot_acf(serie_o_plus, lags=20, ax=axes[0])
axes[0].set_title("ACF - O+")

plot_pacf(serie_o_plus, lags=20, ax=axes[1], method='ywm')
axes[1].set_title("PACF - O+")

plt.tight_layout()
plt.show()

# Resultado ADF
adf_output = {
    "ADF Statistic": adf_result[0],
    "p-value": adf_result[1],
    "Lags Used": adf_result[2],
    "Observations": adf_result[3],
    "Critical Values": adf_result[4]
}

adf_output
# Out:
# {'ADF Statistic': -0.3509923345883333,
#  'p-value': 0.9179653674818277,
#  'Lags Used': 8,
#  'Observations': 109,
#  'Critical Values': {'1%': -3.49181775886872,
#   '5%': -2.8884437992971588,
#   '10%': -2.5811201893779985}}

# %%
# ------------------------- MODELO LSTM -------------------------

    
def entrenar_lstm(X_lstm, y_lstm, epochs=800):
    model = Sequential([
        LSTM(128, activation='tanh', return_sequences=True, input_shape=(X_lstm.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.3),
        
        LSTM(64, activation='tanh', return_sequences=True),
        BatchNormalization(),
        Dropout(0.2),

        LSTM(32, activation='tanh'),
        Dropout(0.3),
        
        Dense(64, activation='relu'),
        Dense(1)  # Última capa sin activación porque es una regresión
        ])
    learning_rate = 0.001 
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=MeanSquaredError()
        
    )

    history = model.fit(
        X_lstm, y_lstm,
        epochs=epochs,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )
  
    return model, history


# ------------------------- STACKING REGRESSOR -------------------------

def entrenar_stacking(X_train, y_train):
    
    estimators = [
        ('xgb', XGBRegressor(max_depth=3, n_estimators=400, learning_rate=0.08, random_state=42, verbosity=0)),
        ('lgb', LGBMRegressor(max_depth=3, n_estimators=300, learning_rate=0.07, random_state=42, verbose=-1)),
        ('cat', CatBoostRegressor(depth=3, iterations=300, learning_rate=0.06, random_state=42, verbose=False))
    ]
    modelo_ensamble = StackingRegressor(
            estimators=estimators,
            final_estimator=Ridge(alpha=1.0),
            n_jobs=-1
        )
    modelo_ensamble.fit(X_train, y_train.ravel())
    return modelo_ensamble

# %%
weekly_demand['Lag_O+_1'] = serie_o_plus.shift(1)
weekly_demand['Lag_O+_2'] = serie_o_plus.shift(2)
weekly_demand['Lag_O+_3'] = serie_o_plus.shift(3)
weekly_demand['Lag_O+_4'] = serie_o_plus.shift(4)
weekly_demand['Rolling_Mean_4_O+'] = serie_o_plus.rolling(window=4).mean()
weekly_demand['Rolling_Mean_8_O+'] = serie_o_plus.rolling(window=8).mean()
weekly_demand['Rolling_STD_4_O+'] = serie_o_plus.rolling(window=4).std()
weekly_demand['Diff_1_O+'] = serie_o_plus.diff(1)

df_o_plus = weekly_demand.copy()
df_o_plus['Lag_O+_1'] = df_o_plus['O+'].shift(1)
df_o_plus['Lag_O+_2'] = df_o_plus['O+'].shift(2)
df_o_plus['Lag_O+_3'] = df_o_plus['O+'].shift(3)
df_o_plus['Lag_O+_4'] = df_o_plus['O+'].shift(4)
df_o_plus['Rolling_Mean_4_O+'] = df_o_plus['O+'].rolling(window=4).mean()

df_o_plus.columns.values[0] = 'Date'
df_o_plus = df_o_plus.reset_index()
df_o_plus['Date'] = pd.to_datetime(df_o_plus['Date'], errors='coerce')

df_o_plus['Week'] = df_o_plus['Date'].dt.isocalendar().week
df_o_plus['Month'] = df_o_plus['Date'].dt.month
df_o_plus['Quarter'] = df_o_plus['Date'].dt.quarter
df_o_plus.dropna(inplace=True)

# %%
################# Datos para LSTM O+ ################# 

features = ['Lag_O+_1', 'Lag_O+_2', 'Lag_O+_3', 'Lag_O+_4', 'Rolling_Mean_4_O+']
target = 'O+'
X = df_o_plus[features]
y = df_o_plus[[target]]

# Escalado robusto
from sklearn.preprocessing import RobustScaler
scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Separo entrenamiento y test (sin barajar porque es una serie temporal)
split_index = int(len(X_scaled) * 0.8)
X_train = X_scaled[:split_index]
X_test = X_scaled[split_index:]
y_lstm = y_scaled[:split_index]
y_test = y_scaled[split_index:]

# Reformatear para LSTM
X_lstm = X_train.reshape((X_train.shape[0], len(features), 1))
X_test_lstm = X_test.reshape((X_test.shape[0], len(features), 1))

# %%
# LSTM

modelo_lstm, history = entrenar_lstm(X_lstm, y_lstm)
y_pred_lstm = modelo_lstm.predict(X_test_lstm)

# Desescalar
y_pred_lstm = scaler_y.inverse_transform(y_pred_lstm)
y_real_lstm = scaler_y.inverse_transform(y_test)
# Out:
# Epoch 1/800
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 491ms/step - loss: 0.3758 - val_loss: 0.6704
# Epoch 2/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.3956 - val_loss: 0.6643
# Epoch 3/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.4309 - val_loss: 0.6596
# Epoch 4/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.3320 - val_loss: 0.6578
# Epoch 5/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3253 - val_loss: 0.6560
# Epoch 6/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3387 - val_loss: 0.6564
# Epoch 7/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3570 - val_loss: 0.6580
# Epoch 8/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3269 - val_loss: 0.6588
# Epoch 9/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3677 - val_loss: 0.6589
# Epoch 10/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4260 - val_loss: 0.6568
# Epoch 11/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3652 - val_loss: 0.6532
# Epoch 12/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3392 - val_loss: 0.6501
# Epoch 13/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3988 - val_loss: 0.6481
# Epoch 14/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3509 - val_loss: 0.6467
# Epoch 15/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3070 - val_loss: 0.6460
# Epoch 16/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3608 - val_loss: 0.6454
# Epoch 17/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3270 - val_loss: 0.6479
# Epoch 18/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3307 - val_loss: 0.6517
# Epoch 19/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3309 - val_loss: 0.6550
# Epoch 20/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2947 - val_loss: 0.6583
# Epoch 21/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2975 - val_loss: 0.6599
# Epoch 22/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2771 - val_loss: 0.6607
# Epoch 23/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3007 - val_loss: 0.6588
# Epoch 24/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3621 - val_loss: 0.6576
# Epoch 25/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3232 - val_loss: 0.6538
# Epoch 26/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3195 - val_loss: 0.6512
# Epoch 27/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3240 - val_loss: 0.6491
# Epoch 28/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3592 - val_loss: 0.6484
# Epoch 29/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3539 - val_loss: 0.6496
# Epoch 30/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3212 - val_loss: 0.6513
# Epoch 31/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3083 - val_loss: 0.6522
# Epoch 32/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3380 - val_loss: 0.6541
# Epoch 33/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3316 - val_loss: 0.6556
# Epoch 34/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2920 - val_loss: 0.6569
# Epoch 35/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2954 - val_loss: 0.6596
# Epoch 36/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2651 - val_loss: 0.6637
# Epoch 37/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2788 - val_loss: 0.6692
# Epoch 38/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2715 - val_loss: 0.6710
# Epoch 39/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2939 - val_loss: 0.6699
# Epoch 40/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2711 - val_loss: 0.6646
# Epoch 41/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3178 - val_loss: 0.6573
# Epoch 42/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2694 - val_loss: 0.6493
# Epoch 43/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2795 - val_loss: 0.6442
# Epoch 44/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2855 - val_loss: 0.6401
# Epoch 45/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2896 - val_loss: 0.6367
# Epoch 46/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3382 - val_loss: 0.6357
# Epoch 47/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2671 - val_loss: 0.6392
# Epoch 48/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2715 - val_loss: 0.6459
# Epoch 49/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2834 - val_loss: 0.6535
# Epoch 50/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2484 - val_loss: 0.6538
# Epoch 51/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2759 - val_loss: 0.6504
# Epoch 52/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2369 - val_loss: 0.6480
# Epoch 53/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2824 - val_loss: 0.6512
# Epoch 54/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2446 - val_loss: 0.6533
# Epoch 55/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2956 - val_loss: 0.6512
# Epoch 56/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2693 - val_loss: 0.6535
# Epoch 57/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3156 - val_loss: 0.6603
# Epoch 58/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2337 - val_loss: 0.6587
# Epoch 59/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2835 - val_loss: 0.6529
# Epoch 60/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2417 - val_loss: 0.6430
# Epoch 61/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2157 - val_loss: 0.6317
# Epoch 62/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2370 - val_loss: 0.6254
# Epoch 63/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2118 - val_loss: 0.6245
# Epoch 64/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3093 - val_loss: 0.6254
# Epoch 65/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2376 - val_loss: 0.6257
# Epoch 66/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2192 - val_loss: 0.6330
# Epoch 67/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2408 - val_loss: 0.6414
# Epoch 68/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2103 - val_loss: 0.6479
# Epoch 69/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2230 - val_loss: 0.6510
# Epoch 70/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2072 - val_loss: 0.6507
# Epoch 71/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2571 - val_loss: 0.6471
# Epoch 72/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2133 - val_loss: 0.6426
# Epoch 73/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2120 - val_loss: 0.6323
# Epoch 74/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2061 - val_loss: 0.6278
# Epoch 75/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1707 - val_loss: 0.6228
# Epoch 76/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2247 - val_loss: 0.6213
# Epoch 77/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2154 - val_loss: 0.6222
# Epoch 78/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2310 - val_loss: 0.6220
# Epoch 79/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1907 - val_loss: 0.6291
# Epoch 80/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2018 - val_loss: 0.6461
# Epoch 81/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1653 - val_loss: 0.6837
# Epoch 82/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2121 - val_loss: 0.7001
# Epoch 83/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1907 - val_loss: 0.6877
# Epoch 84/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1616 - val_loss: 0.6497
# Epoch 85/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1781 - val_loss: 0.6262
# Epoch 86/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1896 - val_loss: 0.6134
# Epoch 87/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1827 - val_loss: 0.6189
# Epoch 88/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1296 - val_loss: 0.6308
# Epoch 89/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1733 - val_loss: 0.6284
# Epoch 90/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1724 - val_loss: 0.6064
# Epoch 91/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1473 - val_loss: 0.5744
# Epoch 92/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1647 - val_loss: 0.5554
# Epoch 93/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1462 - val_loss: 0.5626
# Epoch 94/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1561 - val_loss: 0.5680
# Epoch 95/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1514 - val_loss: 0.5715
# Epoch 96/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1501 - val_loss: 0.5715
# Epoch 97/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1655 - val_loss: 0.5490
# Epoch 98/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1389 - val_loss: 0.5096
# Epoch 99/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1149 - val_loss: 0.4796
# Epoch 100/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1271 - val_loss: 0.4734
# Epoch 101/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1144 - val_loss: 0.4704
# Epoch 102/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1215 - val_loss: 0.4803
# Epoch 103/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1092 - val_loss: 0.5164
# Epoch 104/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1276 - val_loss: 0.5245
# Epoch 105/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1145 - val_loss: 0.5250
# Epoch 106/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1358 - val_loss: 0.5166
# Epoch 107/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1471 - val_loss: 0.4781
# Epoch 108/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1447 - val_loss: 0.4702
# Epoch 109/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0809 - val_loss: 0.4823
# Epoch 110/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1538 - val_loss: 0.4888
# Epoch 111/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1087 - val_loss: 0.5117
# Epoch 112/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0903 - val_loss: 0.5236
# Epoch 113/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1032 - val_loss: 0.5148
# Epoch 114/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1076 - val_loss: 0.5012
# Epoch 115/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1120 - val_loss: 0.4701
# Epoch 116/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1125 - val_loss: 0.4495
# Epoch 117/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0781 - val_loss: 0.4466
# Epoch 118/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0933 - val_loss: 0.4806
# Epoch 119/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0852 - val_loss: 0.5245
# Epoch 120/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1022 - val_loss: 0.5389
# Epoch 121/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0982 - val_loss: 0.5241
# Epoch 122/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0937 - val_loss: 0.4767
# Epoch 123/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1180 - val_loss: 0.4362
# Epoch 124/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1390 - val_loss: 0.4245
# Epoch 125/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0805 - val_loss: 0.4326
# Epoch 126/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0603 - val_loss: 0.4473
# Epoch 127/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0720 - val_loss: 0.4614
# Epoch 128/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1220 - val_loss: 0.4576
# Epoch 129/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1152 - val_loss: 0.4520
# Epoch 130/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0872 - val_loss: 0.4449
# Epoch 131/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1224 - val_loss: 0.4501
# Epoch 132/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1024 - val_loss: 0.4232
# Epoch 133/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0924 - val_loss: 0.4052
# Epoch 134/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0888 - val_loss: 0.4001
# Epoch 135/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0826 - val_loss: 0.4003
# Epoch 136/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1208 - val_loss: 0.4139
# Epoch 137/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0799 - val_loss: 0.4535
# Epoch 138/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0718 - val_loss: 0.5136
# Epoch 139/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1072 - val_loss: 0.5511
# Epoch 140/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1138 - val_loss: 0.4920
# Epoch 141/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0731 - val_loss: 0.4202
# Epoch 142/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0877 - val_loss: 0.3963
# Epoch 143/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1272 - val_loss: 0.4057
# Epoch 144/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0670 - val_loss: 0.4478
# Epoch 145/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0815 - val_loss: 0.4885
# Epoch 146/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0883 - val_loss: 0.5267
# Epoch 147/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0874 - val_loss: 0.5363
# Epoch 148/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0919 - val_loss: 0.5174
# Epoch 149/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0975 - val_loss: 0.4731
# Epoch 150/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0769 - val_loss: 0.4316
# Epoch 151/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0927 - val_loss: 0.4022
# Epoch 152/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0796 - val_loss: 0.3836
# Epoch 153/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0791 - val_loss: 0.3752
# Epoch 154/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0909 - val_loss: 0.3743
# Epoch 155/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0896 - val_loss: 0.3928
# Epoch 156/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0841 - val_loss: 0.4276
# Epoch 157/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0945 - val_loss: 0.4450
# Epoch 158/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0687 - val_loss: 0.4399
# Epoch 159/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0640 - val_loss: 0.4072
# Epoch 160/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0686 - val_loss: 0.3783
# Epoch 161/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0482 - val_loss: 0.3649
# Epoch 162/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0668 - val_loss: 0.3521
# Epoch 163/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0648 - val_loss: 0.3520
# Epoch 164/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0564 - val_loss: 0.3668
# Epoch 165/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0606 - val_loss: 0.3939
# Epoch 166/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0523 - val_loss: 0.4252
# Epoch 167/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0762 - val_loss: 0.4190
# Epoch 168/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0453 - val_loss: 0.4031
# Epoch 169/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0669 - val_loss: 0.3766
# Epoch 170/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0646 - val_loss: 0.3483
# Epoch 171/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0626 - val_loss: 0.3270
# Epoch 172/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0482 - val_loss: 0.3173
# Epoch 173/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0563 - val_loss: 0.3306
# Epoch 174/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0765 - val_loss: 0.3645
# Epoch 175/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0671 - val_loss: 0.4069
# Epoch 176/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0879 - val_loss: 0.3935
# Epoch 177/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0648 - val_loss: 0.3482
# Epoch 178/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0587 - val_loss: 0.3253
# Epoch 179/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0794 - val_loss: 0.3218
# Epoch 180/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0851 - val_loss: 0.3357
# Epoch 181/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0603 - val_loss: 0.3794
# Epoch 182/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0543 - val_loss: 0.4242
# Epoch 183/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1182 - val_loss: 0.4062
# Epoch 184/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0793 - val_loss: 0.3318
# Epoch 185/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0553 - val_loss: 0.2953
# Epoch 186/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0584 - val_loss: 0.2901
# Epoch 187/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0819 - val_loss: 0.2974
# Epoch 188/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0605 - val_loss: 0.3217
# Epoch 189/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0471 - val_loss: 0.3650
# Epoch 190/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0559 - val_loss: 0.3669
# Epoch 191/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0631 - val_loss: 0.3653
# Epoch 192/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0742 - val_loss: 0.3485
# Epoch 193/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0621 - val_loss: 0.3064
# Epoch 194/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0653 - val_loss: 0.2836
# Epoch 195/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0570 - val_loss: 0.2775
# Epoch 196/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0630 - val_loss: 0.2784
# Epoch 197/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0580 - val_loss: 0.2892
# Epoch 198/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0615 - val_loss: 0.3024
# Epoch 199/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0510 - val_loss: 0.3127
# Epoch 200/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0597 - val_loss: 0.3141
# Epoch 201/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0422 - val_loss: 0.3314
# Epoch 202/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0577 - val_loss: 0.3412
# Epoch 203/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0427 - val_loss: 0.3309
# Epoch 204/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0384 - val_loss: 0.2933
# Epoch 205/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0553 - val_loss: 0.2697
# Epoch 206/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0541 - val_loss: 0.2614
# Epoch 207/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0461 - val_loss: 0.2641
# Epoch 208/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0553 - val_loss: 0.2742
# Epoch 209/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0561 - val_loss: 0.2827
# Epoch 210/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0305 - val_loss: 0.2890
# Epoch 211/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0533 - val_loss: 0.2766
# Epoch 212/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0525 - val_loss: 0.2609
# Epoch 213/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0521 - val_loss: 0.2593
# Epoch 214/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0685 - val_loss: 0.2652
# Epoch 215/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0729 - val_loss: 0.2895
# Epoch 216/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0913 - val_loss: 0.2964
# Epoch 217/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0555 - val_loss: 0.2822
# Epoch 218/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0474 - val_loss: 0.2669
# Epoch 219/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0583 - val_loss: 0.2451
# Epoch 220/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0372 - val_loss: 0.2506
# Epoch 221/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0537 - val_loss: 0.2526
# Epoch 222/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0462 - val_loss: 0.2565
# Epoch 223/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0593 - val_loss: 0.2836
# Epoch 224/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0585 - val_loss: 0.2975
# Epoch 225/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0507 - val_loss: 0.2827
# Epoch 226/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0518 - val_loss: 0.2680
# Epoch 227/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0437 - val_loss: 0.2673
# Epoch 228/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0389 - val_loss: 0.2712
# Epoch 229/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0415 - val_loss: 0.2748
# Epoch 230/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0332 - val_loss: 0.2742
# Epoch 231/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0548 - val_loss: 0.2726
# Epoch 232/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0396 - val_loss: 0.2714
# Epoch 233/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0633 - val_loss: 0.2709
# Epoch 234/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0397 - val_loss: 0.2730
# Epoch 235/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0708 - val_loss: 0.2749
# Epoch 236/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0470 - val_loss: 0.2755
# Epoch 237/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0467 - val_loss: 0.2722
# Epoch 238/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0463 - val_loss: 0.2661
# Epoch 239/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0589 - val_loss: 0.2616
# Epoch 240/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0376 - val_loss: 0.2607
# Epoch 241/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0393 - val_loss: 0.2605
# Epoch 242/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0440 - val_loss: 0.2651
# Epoch 243/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0422 - val_loss: 0.2703
# Epoch 244/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0686 - val_loss: 0.2750
# Epoch 245/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0533 - val_loss: 0.2789
# Epoch 246/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0410 - val_loss: 0.2859
# Epoch 247/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0513 - val_loss: 0.2819
# Epoch 248/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0526 - val_loss: 0.2785
# Epoch 249/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0368 - val_loss: 0.2731
# Epoch 250/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0415 - val_loss: 0.2708
# Epoch 251/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0289 - val_loss: 0.2684
# Epoch 252/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0404 - val_loss: 0.2671
# Epoch 253/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0492 - val_loss: 0.2678
# Epoch 254/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0380 - val_loss: 0.2709
# Epoch 255/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0346 - val_loss: 0.2807
# Epoch 256/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0339 - val_loss: 0.2890
# Epoch 257/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0472 - val_loss: 0.2853
# Epoch 258/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0373 - val_loss: 0.2837
# Epoch 259/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0364 - val_loss: 0.2840
# Epoch 260/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0251 - val_loss: 0.2827
# Epoch 261/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0383 - val_loss: 0.2788
# Epoch 262/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0309 - val_loss: 0.2750
# Epoch 263/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0500 - val_loss: 0.2729
# Epoch 264/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0386 - val_loss: 0.2732
# Epoch 265/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0368 - val_loss: 0.2733
# Epoch 266/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0451 - val_loss: 0.2721
# Epoch 267/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0397 - val_loss: 0.2731
# Epoch 268/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0359 - val_loss: 0.2741
# Epoch 269/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0592 - val_loss: 0.2783
# Epoch 270/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0448 - val_loss: 0.2832
# Epoch 271/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0209 - val_loss: 0.2932
# Epoch 272/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0533 - val_loss: 0.3018
# Epoch 273/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0531 - val_loss: 0.2799
# Epoch 274/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0528 - val_loss: 0.2626
# Epoch 275/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0519 - val_loss: 0.2480
# Epoch 276/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0322 - val_loss: 0.2462
# Epoch 277/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0494 - val_loss: 0.2511
# Epoch 278/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0380 - val_loss: 0.2560
# Epoch 279/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0503 - val_loss: 0.2622
# Epoch 280/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0421 - val_loss: 0.2643
# Epoch 281/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0397 - val_loss: 0.2743
# Epoch 282/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0346 - val_loss: 0.2853
# Epoch 283/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0459 - val_loss: 0.2829
# Epoch 284/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0370 - val_loss: 0.2786
# Epoch 285/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0357 - val_loss: 0.2753
# Epoch 286/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0439 - val_loss: 0.2778
# Epoch 287/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0289 - val_loss: 0.2813
# Epoch 288/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0271 - val_loss: 0.2856
# Epoch 289/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0444 - val_loss: 0.2867
# Epoch 290/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0456 - val_loss: 0.2840
# Epoch 291/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0283 - val_loss: 0.2744
# Epoch 292/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0390 - val_loss: 0.2686
# Epoch 293/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0459 - val_loss: 0.2744
# Epoch 294/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0392 - val_loss: 0.2790
# Epoch 295/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0386 - val_loss: 0.2880
# Epoch 296/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0564 - val_loss: 0.2968
# Epoch 297/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0457 - val_loss: 0.2999
# Epoch 298/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0491 - val_loss: 0.2996
# Epoch 299/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0556 - val_loss: 0.2981
# Epoch 300/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0532 - val_loss: 0.2956
# Epoch 301/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0317 - val_loss: 0.2895
# Epoch 302/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0310 - val_loss: 0.2777
# Epoch 303/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0382 - val_loss: 0.2687
# Epoch 304/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0353 - val_loss: 0.2578
# Epoch 305/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0426 - val_loss: 0.2475
# Epoch 306/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0468 - val_loss: 0.2402
# Epoch 307/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0443 - val_loss: 0.2401
# Epoch 308/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0409 - val_loss: 0.2450
# Epoch 309/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0445 - val_loss: 0.2534
# Epoch 310/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0367 - val_loss: 0.2610
# Epoch 311/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0425 - val_loss: 0.2676
# Epoch 312/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0366 - val_loss: 0.2761
# Epoch 313/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0321 - val_loss: 0.2907
# Epoch 314/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0376 - val_loss: 0.3016
# Epoch 315/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0371 - val_loss: 0.3083
# Epoch 316/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0465 - val_loss: 0.3113
# Epoch 317/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0305 - val_loss: 0.3075
# Epoch 318/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0284 - val_loss: 0.3032
# Epoch 319/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0262 - val_loss: 0.2999
# Epoch 320/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0340 - val_loss: 0.2911
# Epoch 321/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0293 - val_loss: 0.2789
# Epoch 322/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0326 - val_loss: 0.2735
# Epoch 323/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0293 - val_loss: 0.2729
# Epoch 324/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0427 - val_loss: 0.2693
# Epoch 325/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0334 - val_loss: 0.2658
# Epoch 326/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0263 - val_loss: 0.2728
# Epoch 327/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0300 - val_loss: 0.2975
# Epoch 328/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0361 - val_loss: 0.2999
# Epoch 329/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0364 - val_loss: 0.2870
# Epoch 330/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0352 - val_loss: 0.2868
# Epoch 331/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0306 - val_loss: 0.2867
# Epoch 332/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0387 - val_loss: 0.2832
# Epoch 333/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0304 - val_loss: 0.2724
# Epoch 334/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0260 - val_loss: 0.2660
# Epoch 335/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0391 - val_loss: 0.2728
# Epoch 336/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0240 - val_loss: 0.2759
# Epoch 337/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0347 - val_loss: 0.2644
# Epoch 338/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0232 - val_loss: 0.2574
# Epoch 339/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0293 - val_loss: 0.2543
# Epoch 340/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0263 - val_loss: 0.2490
# Epoch 341/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0370 - val_loss: 0.2470
# Epoch 342/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0402 - val_loss: 0.2552
# Epoch 343/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0184 - val_loss: 0.2669
# Epoch 344/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0284 - val_loss: 0.2753
# Epoch 345/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0380 - val_loss: 0.2718
# Epoch 346/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0356 - val_loss: 0.2664
# Epoch 347/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0401 - val_loss: 0.2677
# Epoch 348/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0311 - val_loss: 0.2675
# Epoch 349/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0334 - val_loss: 0.2637
# Epoch 350/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0472 - val_loss: 0.2611
# Epoch 351/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0440 - val_loss: 0.2612
# Epoch 352/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0363 - val_loss: 0.2613
# Epoch 353/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0262 - val_loss: 0.2602
# Epoch 354/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0406 - val_loss: 0.2555
# Epoch 355/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0413 - val_loss: 0.2544
# Epoch 356/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0402 - val_loss: 0.2559
# Epoch 357/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0490 - val_loss: 0.2574
# Epoch 358/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0398 - val_loss: 0.2573
# Epoch 359/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0231 - val_loss: 0.2589
# Epoch 360/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0252 - val_loss: 0.2596
# Epoch 361/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0262 - val_loss: 0.2634
# Epoch 362/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0338 - val_loss: 0.2596
# Epoch 363/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0389 - val_loss: 0.2576
# Epoch 364/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0208 - val_loss: 0.2558
# Epoch 365/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0305 - val_loss: 0.2538
# Epoch 366/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0261 - val_loss: 0.2554
# Epoch 367/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0387 - val_loss: 0.2580
# Epoch 368/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0244 - val_loss: 0.2511
# Epoch 369/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0243 - val_loss: 0.2469
# Epoch 370/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0238 - val_loss: 0.2546
# Epoch 371/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0323 - val_loss: 0.2578
# Epoch 372/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0457 - val_loss: 0.2472
# Epoch 373/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0254 - val_loss: 0.2423
# Epoch 374/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0254 - val_loss: 0.2413
# Epoch 375/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0350 - val_loss: 0.2416
# Epoch 376/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0341 - val_loss: 0.2441
# Epoch 377/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0296 - val_loss: 0.2465
# Epoch 378/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0292 - val_loss: 0.2483
# Epoch 379/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0276 - val_loss: 0.2448
# Epoch 380/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0268 - val_loss: 0.2400
# Epoch 381/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0315 - val_loss: 0.2400
# Epoch 382/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0357 - val_loss: 0.2461
# Epoch 383/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0237 - val_loss: 0.2564
# Epoch 384/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0391 - val_loss: 0.2655
# Epoch 385/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0302 - val_loss: 0.2748
# Epoch 386/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0244 - val_loss: 0.2871
# Epoch 387/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0263 - val_loss: 0.2958
# Epoch 388/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0239 - val_loss: 0.2985
# Epoch 389/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0287 - val_loss: 0.2967
# Epoch 390/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0310 - val_loss: 0.2904
# Epoch 391/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0447 - val_loss: 0.2758
# Epoch 392/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0360 - val_loss: 0.2662
# Epoch 393/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0273 - val_loss: 0.2634
# Epoch 394/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0470 - val_loss: 0.2652
# Epoch 395/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0220 - val_loss: 0.2715
# Epoch 396/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0215 - val_loss: 0.2765
# Epoch 397/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0345 - val_loss: 0.2772
# Epoch 398/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0524 - val_loss: 0.2719
# Epoch 399/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0267 - val_loss: 0.2675
# Epoch 400/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0347 - val_loss: 0.2643
# Epoch 401/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0356 - val_loss: 0.2604
# Epoch 402/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0344 - val_loss: 0.2618
# Epoch 403/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0268 - val_loss: 0.2647
# Epoch 404/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0236 - val_loss: 0.2697
# Epoch 405/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0371 - val_loss: 0.2729
# Epoch 406/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0386 - val_loss: 0.2713
# Epoch 407/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0267 - val_loss: 0.2655
# Epoch 408/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0263 - val_loss: 0.2602
# Epoch 409/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0327 - val_loss: 0.2552
# Epoch 410/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0332 - val_loss: 0.2515
# Epoch 411/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0293 - val_loss: 0.2476
# Epoch 412/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0299 - val_loss: 0.2497
# Epoch 413/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0262 - val_loss: 0.2590
# Epoch 414/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0304 - val_loss: 0.2629
# Epoch 415/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0207 - val_loss: 0.2644
# Epoch 416/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0176 - val_loss: 0.2624
# Epoch 417/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0250 - val_loss: 0.2541
# Epoch 418/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0327 - val_loss: 0.2485
# Epoch 419/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0217 - val_loss: 0.2470
# Epoch 420/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0277 - val_loss: 0.2472
# Epoch 421/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0207 - val_loss: 0.2474
# Epoch 422/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0274 - val_loss: 0.2497
# Epoch 423/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0314 - val_loss: 0.2553
# Epoch 424/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0344 - val_loss: 0.2599
# Epoch 425/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0344 - val_loss: 0.2637
# Epoch 426/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0327 - val_loss: 0.2606
# Epoch 427/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0325 - val_loss: 0.2553
# Epoch 428/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0333 - val_loss: 0.2589
# Epoch 429/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0316 - val_loss: 0.2610
# Epoch 430/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0252 - val_loss: 0.2623
# Epoch 431/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0307 - val_loss: 0.2644
# Epoch 432/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0177 - val_loss: 0.2653
# Epoch 433/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0250 - val_loss: 0.2647
# Epoch 434/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0205 - val_loss: 0.2646
# Epoch 435/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0228 - val_loss: 0.2647
# Epoch 436/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0263 - val_loss: 0.2630
# Epoch 437/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0235 - val_loss: 0.2620
# Epoch 438/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0207 - val_loss: 0.2607
# Epoch 439/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0231 - val_loss: 0.2609
# Epoch 440/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0223 - val_loss: 0.2622
# Epoch 441/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0485 - val_loss: 0.2665
# Epoch 442/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0240 - val_loss: 0.2621
# Epoch 443/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0324 - val_loss: 0.2567
# Epoch 444/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0210 - val_loss: 0.2588
# Epoch 445/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0414 - val_loss: 0.2590
# Epoch 446/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0395 - val_loss: 0.2534
# Epoch 447/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0272 - val_loss: 0.2475
# Epoch 448/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0189 - val_loss: 0.2496
# Epoch 449/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0406 - val_loss: 0.2490
# Epoch 450/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0237 - val_loss: 0.2425
# Epoch 451/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0213 - val_loss: 0.2413
# Epoch 452/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187 - val_loss: 0.2454
# Epoch 453/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0311 - val_loss: 0.2454
# Epoch 454/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0303 - val_loss: 0.2436
# Epoch 455/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0337 - val_loss: 0.2396
# Epoch 456/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0321 - val_loss: 0.2385
# Epoch 457/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0230 - val_loss: 0.2424
# Epoch 458/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0240 - val_loss: 0.2457
# Epoch 459/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0323 - val_loss: 0.2505
# Epoch 460/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0261 - val_loss: 0.2563
# Epoch 461/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0217 - val_loss: 0.2563
# Epoch 462/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0234 - val_loss: 0.2521
# Epoch 463/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0255 - val_loss: 0.2483
# Epoch 464/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0260 - val_loss: 0.2444
# Epoch 465/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0224 - val_loss: 0.2415
# Epoch 466/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0280 - val_loss: 0.2475
# Epoch 467/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0282 - val_loss: 0.2482
# Epoch 468/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0212 - val_loss: 0.2478
# Epoch 469/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0260 - val_loss: 0.2529
# Epoch 470/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0216 - val_loss: 0.2580
# Epoch 471/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0186 - val_loss: 0.2603
# Epoch 472/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0266 - val_loss: 0.2585
# Epoch 473/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0268 - val_loss: 0.2551
# Epoch 474/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0224 - val_loss: 0.2523
# Epoch 475/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0269 - val_loss: 0.2562
# Epoch 476/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0287 - val_loss: 0.2576
# Epoch 477/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0240 - val_loss: 0.2514
# Epoch 478/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0385 - val_loss: 0.2427
# Epoch 479/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0205 - val_loss: 0.2412
# Epoch 480/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0207 - val_loss: 0.2399
# Epoch 481/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0214 - val_loss: 0.2373
# Epoch 482/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0220 - val_loss: 0.2320
# Epoch 483/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0227 - val_loss: 0.2272
# Epoch 484/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0264 - val_loss: 0.2319
# Epoch 485/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0235 - val_loss: 0.2468
# Epoch 486/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0304 - val_loss: 0.2537
# Epoch 487/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0260 - val_loss: 0.2554
# Epoch 488/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0230 - val_loss: 0.2613
# Epoch 489/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0196 - val_loss: 0.2712
# Epoch 490/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0252 - val_loss: 0.2848
# Epoch 491/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0191 - val_loss: 0.2844
# Epoch 492/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0321 - val_loss: 0.2678
# Epoch 493/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0209 - val_loss: 0.2570
# Epoch 494/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0240 - val_loss: 0.2511
# Epoch 495/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0249 - val_loss: 0.2370
# Epoch 496/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0264 - val_loss: 0.2232
# Epoch 497/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0217 - val_loss: 0.2114
# Epoch 498/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0249 - val_loss: 0.2048
# Epoch 499/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0215 - val_loss: 0.2039
# Epoch 500/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0271 - val_loss: 0.2077
# Epoch 501/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0213 - val_loss: 0.2168
# Epoch 502/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0234 - val_loss: 0.2342
# Epoch 503/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0364 - val_loss: 0.2409
# Epoch 504/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0255 - val_loss: 0.2469
# Epoch 505/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0267 - val_loss: 0.2539
# Epoch 506/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0223 - val_loss: 0.2576
# Epoch 507/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0222 - val_loss: 0.2611
# Epoch 508/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0296 - val_loss: 0.2684
# Epoch 509/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0322 - val_loss: 0.2673
# Epoch 510/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0275 - val_loss: 0.2581
# Epoch 511/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0248 - val_loss: 0.2537
# Epoch 512/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0151 - val_loss: 0.2541
# Epoch 513/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0285 - val_loss: 0.2569
# Epoch 514/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0212 - val_loss: 0.2620
# Epoch 515/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0229 - val_loss: 0.2642
# Epoch 516/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0192 - val_loss: 0.2685
# Epoch 517/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0343 - val_loss: 0.2759
# Epoch 518/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0198 - val_loss: 0.2796
# Epoch 519/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0204 - val_loss: 0.2752
# Epoch 520/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0225 - val_loss: 0.2671
# Epoch 521/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0206 - val_loss: 0.2572
# Epoch 522/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0206 - val_loss: 0.2355
# Epoch 523/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0333 - val_loss: 0.2266
# Epoch 524/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0320 - val_loss: 0.2243
# Epoch 525/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0241 - val_loss: 0.2317
# Epoch 526/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0262 - val_loss: 0.2434
# Epoch 527/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0351 - val_loss: 0.2479
# Epoch 528/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0212 - val_loss: 0.2531
# Epoch 529/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0170 - val_loss: 0.2699
# Epoch 530/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0357 - val_loss: 0.2704
# Epoch 531/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0276 - val_loss: 0.2662
# Epoch 532/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0339 - val_loss: 0.2607
# Epoch 533/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0198 - val_loss: 0.2546
# Epoch 534/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0320 - val_loss: 0.2500
# Epoch 535/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0166 - val_loss: 0.2417
# Epoch 536/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0174 - val_loss: 0.2412
# Epoch 537/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0223 - val_loss: 0.2455
# Epoch 538/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0239 - val_loss: 0.2423
# Epoch 539/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0221 - val_loss: 0.2380
# Epoch 540/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0205 - val_loss: 0.2418
# Epoch 541/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0231 - val_loss: 0.2502
# Epoch 542/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0241 - val_loss: 0.2537
# Epoch 543/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0199 - val_loss: 0.2530
# Epoch 544/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0262 - val_loss: 0.2575
# Epoch 545/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0212 - val_loss: 0.2622
# Epoch 546/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0223 - val_loss: 0.2647
# Epoch 547/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0157 - val_loss: 0.2655
# Epoch 548/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0229 - val_loss: 0.2668
# Epoch 549/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0249 - val_loss: 0.2662
# Epoch 550/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0472 - val_loss: 0.2651
# Epoch 551/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0236 - val_loss: 0.2613
# Epoch 552/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0193 - val_loss: 0.2564
# Epoch 553/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0178 - val_loss: 0.2550
# Epoch 554/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0320 - val_loss: 0.2540
# Epoch 555/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0192 - val_loss: 0.2539
# Epoch 556/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0266 - val_loss: 0.2549
# ...
# Epoch 616/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0213 - val_loss: 0.2474
# Epoch 617/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0282 - val_loss: 0.2467
# Epoch 618/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0230 - val_loss: 0.2506
# Epoch 619/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0170 - val_loss: 0.2546
# Epoch 620/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0210 - val_loss: 0.2576
# Epoch 621/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0202 - val_loss: 0.2573
# Epoch 622/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0187 - val_loss: 0.2564
# Epoch 623/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0246 - val_loss: 0.2511
# Epoch 624/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0164 - val_loss: 0.2460
# Epoch 625/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0199 - val_loss: 0.2419
# Epoch 626/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0192 - val_loss: 0.2404
# Epoch 627/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0214 - val_loss: 0.2379
# Epoch 628/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0270 - val_loss: 0.2320
# Epoch 629/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0253 - val_loss: 0.2277
# Epoch 630/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0141 - val_loss: 0.2230
# Epoch 631/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0240 - val_loss: 0.2260
# Epoch 632/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0202 - val_loss: 0.2384
# Epoch 633/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0239 - val_loss: 0.2467
# Epoch 634/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0301 - val_loss: 0.2458
# Epoch 635/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0208 - val_loss: 0.2447
# Epoch 636/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0210 - val_loss: 0.2544
# Epoch 637/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0218 - val_loss: 0.2647
# Epoch 638/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0237 - val_loss: 0.2622
# Epoch 639/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0160 - val_loss: 0.2563
# Epoch 640/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0167 - val_loss: 0.2569
# Epoch 641/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0140 - val_loss: 0.2573
# Epoch 642/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0193 - val_loss: 0.2546
# Epoch 643/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0198 - val_loss: 0.2459
# Epoch 644/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0228 - val_loss: 0.2375
# Epoch 645/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0131 - val_loss: 0.2336
# Epoch 646/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0137 - val_loss: 0.2310
# Epoch 647/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0181 - val_loss: 0.2319
# Epoch 648/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0238 - val_loss: 0.2384
# Epoch 649/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0175 - val_loss: 0.2394
# Epoch 650/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0212 - val_loss: 0.2351
# Epoch 651/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0146 - val_loss: 0.2282
# Epoch 652/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0175 - val_loss: 0.2273
# Epoch 653/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0165 - val_loss: 0.2315
# Epoch 654/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0182 - val_loss: 0.2271
# Epoch 655/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0258 - val_loss: 0.2238
# Epoch 656/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0206 - val_loss: 0.2324
# Epoch 657/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0144 - val_loss: 0.2427
# Epoch 658/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0123 - val_loss: 0.2473
# Epoch 659/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0179 - val_loss: 0.2477
# Epoch 660/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0096 - val_loss: 0.2447
# Epoch 661/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0136 - val_loss: 0.2445
# Epoch 662/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0159 - val_loss: 0.2439
# Epoch 663/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0188 - val_loss: 0.2433
# Epoch 664/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0173 - val_loss: 0.2426
# Epoch 665/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0222 - val_loss: 0.2400
# Epoch 666/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0211 - val_loss: 0.2375
# Epoch 667/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0162 - val_loss: 0.2366
# Epoch 668/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0117 - val_loss: 0.2356
# Epoch 669/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0183 - val_loss: 0.2357
# Epoch 670/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0250 - val_loss: 0.2489
# Epoch 671/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0132 - val_loss: 0.2557
# Epoch 672/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0235 - val_loss: 0.2544
# Epoch 673/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0164 - val_loss: 0.2528
# Epoch 674/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0141 - val_loss: 0.2516
# Epoch 675/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0220 - val_loss: 0.2555
# Epoch 676/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0200 - val_loss: 0.2630
# Epoch 677/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0171 - val_loss: 0.2674
# Epoch 678/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0113 - val_loss: 0.2711
# Epoch 679/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0188 - val_loss: 0.2743
# Epoch 680/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0165 - val_loss: 0.2782
# Epoch 681/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0258 - val_loss: 0.2772
# Epoch 682/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187 - val_loss: 0.2748
# Epoch 683/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0144 - val_loss: 0.2751
# Epoch 684/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0153 - val_loss: 0.2742
# Epoch 685/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0188 - val_loss: 0.2704
# Epoch 686/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0171 - val_loss: 0.2634
# Epoch 687/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0181 - val_loss: 0.2601
# Epoch 688/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0198 - val_loss: 0.2589
# Epoch 689/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0158 - val_loss: 0.2585
# Epoch 690/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0193 - val_loss: 0.2587
# Epoch 691/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0101 - val_loss: 0.2591
# Epoch 692/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0254 - val_loss: 0.2661
# Epoch 693/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0118 - val_loss: 0.2723
# Epoch 694/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0160 - val_loss: 0.2743
# Epoch 695/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0171 - val_loss: 0.2815
# Epoch 696/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0138 - val_loss: 0.2881
# Epoch 697/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0166 - val_loss: 0.2902
# Epoch 698/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0171 - val_loss: 0.2911
# Epoch 699/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0269 - val_loss: 0.2916
# Epoch 700/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0226 - val_loss: 0.2888
# Epoch 701/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0158 - val_loss: 0.2822
# Epoch 702/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0161 - val_loss: 0.2766
# Epoch 703/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0179 - val_loss: 0.2719
# Epoch 704/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0199 - val_loss: 0.2693
# Epoch 705/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0166 - val_loss: 0.2659
# Epoch 706/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0193 - val_loss: 0.2579
# Epoch 707/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0162 - val_loss: 0.2533
# Epoch 708/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0160 - val_loss: 0.2498
# Epoch 709/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0164 - val_loss: 0.2457
# Epoch 710/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0161 - val_loss: 0.2403
# Epoch 711/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0155 - val_loss: 0.2351
# Epoch 712/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0171 - val_loss: 0.2289
# Epoch 713/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0173 - val_loss: 0.2254
# Epoch 714/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0243 - val_loss: 0.2288
# Epoch 715/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0200 - val_loss: 0.2388
# Epoch 716/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0193 - val_loss: 0.2467
# Epoch 717/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187 - val_loss: 0.2466
# Epoch 718/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0182 - val_loss: 0.2420
# Epoch 719/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187 - val_loss: 0.2410
# Epoch 720/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0179 - val_loss: 0.2430
# Epoch 721/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0149 - val_loss: 0.2461
# Epoch 722/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0219 - val_loss: 0.2486
# Epoch 723/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0160 - val_loss: 0.2484
# Epoch 724/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0185 - val_loss: 0.2467
# Epoch 725/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0177 - val_loss: 0.2463
# Epoch 726/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0131 - val_loss: 0.2454
# Epoch 727/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0189 - val_loss: 0.2419
# Epoch 728/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0127 - val_loss: 0.2415
# Epoch 729/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0180 - val_loss: 0.2378
# Epoch 730/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0120 - val_loss: 0.2287
# Epoch 731/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0138 - val_loss: 0.2264
# Epoch 732/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0199 - val_loss: 0.2280
# Epoch 733/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0176 - val_loss: 0.2337
# Epoch 734/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0106 - val_loss: 0.2367
# Epoch 735/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0246 - val_loss: 0.2368
# Epoch 736/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0207 - val_loss: 0.2379
# Epoch 737/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0215 - val_loss: 0.2412
# Epoch 738/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0096 - val_loss: 0.2455
# Epoch 739/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0143 - val_loss: 0.2471
# Epoch 740/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0140 - val_loss: 0.2501
# Epoch 741/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0149 - val_loss: 0.2510
# Epoch 742/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0164 - val_loss: 0.2467
# Epoch 743/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0174 - val_loss: 0.2413
# Epoch 744/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0147 - val_loss: 0.2439
# Epoch 745/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0151 - val_loss: 0.2528
# Epoch 746/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0231 - val_loss: 0.2639
# Epoch 747/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0184 - val_loss: 0.2678
# Epoch 748/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0199 - val_loss: 0.2651
# Epoch 749/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0318 - val_loss: 0.2507
# Epoch 750/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0242 - val_loss: 0.2423
# Epoch 751/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0205 - val_loss: 0.2436
# Epoch 752/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0216 - val_loss: 0.2397
# Epoch 753/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0147 - val_loss: 0.2462
# Epoch 754/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0172 - val_loss: 0.2557
# Epoch 755/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0158 - val_loss: 0.2569
# Epoch 756/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0140 - val_loss: 0.2538
# Epoch 757/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0147 - val_loss: 0.2509
# Epoch 758/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0253 - val_loss: 0.2476
# Epoch 759/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0197 - val_loss: 0.2501
# Epoch 760/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0194 - val_loss: 0.2554
# Epoch 761/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0175 - val_loss: 0.2576
# Epoch 762/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0201 - val_loss: 0.2577
# Epoch 763/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0229 - val_loss: 0.2558
# Epoch 764/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0227 - val_loss: 0.2587
# Epoch 765/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0195 - val_loss: 0.2645
# Epoch 766/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0125 - val_loss: 0.2670
# Epoch 767/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0207 - val_loss: 0.2667
# Epoch 768/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0151 - val_loss: 0.2714
# Epoch 769/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0151 - val_loss: 0.2733
# Epoch 770/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0193 - val_loss: 0.2742
# Epoch 771/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0202 - val_loss: 0.2755
# Epoch 772/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187 - val_loss: 0.2732
# Epoch 773/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0144 - val_loss: 0.2720
# Epoch 774/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0530 - val_loss: 0.2643
# Epoch 775/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0176 - val_loss: 0.2535
# Epoch 776/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0118 - val_loss: 0.2474
# Epoch 777/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0156 - val_loss: 0.2449
# Epoch 778/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0245 - val_loss: 0.2464
# Epoch 779/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0195 - val_loss: 0.2462
# Epoch 780/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0173 - val_loss: 0.2474
# Epoch 781/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0144 - val_loss: 0.2477
# Epoch 782/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0142 - val_loss: 0.2461
# Epoch 783/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0136 - val_loss: 0.2434
# Epoch 784/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0129 - val_loss: 0.2428
# Epoch 785/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0185 - val_loss: 0.2405
# Epoch 786/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0203 - val_loss: 0.2359
# Epoch 787/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0146 - val_loss: 0.2319
# Epoch 788/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0196 - val_loss: 0.2237
# Epoch 789/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0181 - val_loss: 0.2222
# Epoch 790/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0159 - val_loss: 0.2218
# Epoch 791/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0192 - val_loss: 0.2253
# Epoch 792/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0135 - val_loss: 0.2295
# Epoch 793/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0185 - val_loss: 0.2399
# Epoch 794/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0153 - val_loss: 0.2503
# Epoch 795/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0155 - val_loss: 0.2545
# Epoch 796/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0141 - val_loss: 0.2521
# Epoch 797/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0116 - val_loss: 0.2468
# Epoch 798/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0359 - val_loss: 0.2417
# Epoch 799/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0194 - val_loss: 0.2348
# Epoch 800/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0159 - val_loss: 0.2308
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step

# %%
################# Datos para stackingregressor #################


# Características temporales enriquecidas

df_o_plus['Rolling_Mean_8_O+'] = df_o_plus['O+'].rolling(8).mean()
df_o_plus['Rolling_STD_4_O+'] = df_o_plus['O+'].rolling(4).std()
df_o_plus['Diff_1_O+'] = df_o_plus['O+'].diff(1)


# Eliminar nulos generados por los lags/rolling
df_o_plus.dropna(inplace=True)
# Definir features y target para stackingregressor
features_stk = [col for col in df_o_plus.columns if col.startswith('Lag_O+') or 'Rolling_Mean_8_O+' in col or 'Rolling_STD_4_O+' in col or 'Diff_1_O+' in col or col in ['Week', 'Month','Quarter']]

X_stk = df_o_plus[features_stk]
y = df_o_plus[target]

scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X_stk)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1)).flatten()
X_scaled = pd.DataFrame(X_scaled, columns=X_stk.columns)
X_train_stk, X_test_stk, y_train_stk, y_test_stk = train_test_split(X_scaled, y_scaled, shuffle=False, test_size=0.2)

# %%
# StackingRegressor

modelo_stk = entrenar_stacking(X_train_stk, y_train_stk)
y_pred_stk = modelo_stk.predict(X_test_stk)
y_pred_stk = scaler_y.inverse_transform(y_pred_stk.reshape(-1, 1))
y_real_stk = scaler_y.inverse_transform(y_test_stk.reshape(-1, 1))

# %%
# ------------------------- MÉTRICAS PARA O+ -------------------------

print("* MÉTRICAS LSTM PARA O+")
print(f"MAE: {mean_absolute_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"RMSE: {mean_squared_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"R²: {r2_score(y_real_lstm, y_pred_lstm):.2f}")

print("\n* MÉTRICAS STACKING PARA O+")
print(f"MAE: {mean_absolute_error(y_real_stk, y_pred_stk):.2f}")
print(f"RMSE: {mean_squared_error(y_real_stk, y_pred_stk):.2f}")
print(f"R²: {r2_score(y_real_stk, y_pred_stk):.2f}")
# Out:
# * MÉTRICAS LSTM PARA O+
# MAE: 8.26
# RMSE: 94.70
# R²: 0.62
#
# * MÉTRICAS STACKING PARA O+
# MAE: 9.00
# RMSE: 130.78
# R²: 0.25

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_real_stk), len(y_pred_stk))

# Convertir todo a 1D por seguridad
y_test_plot = y_test[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_real_plot = y_real_lstm[:min_len].reshape(-1)

# Plot
plt.figure(figsize=(12, 5))
plt.plot(np.arange(min_len), y_real_stk[:min_len], label="Real", color='black')
plt.plot(np.arange(min_len), y_pred_stk[:min_len], label="StackingRegressor", linestyle='--')
plt.plot(np.arange(min_len), y_pred_lstm[:min_len], label="LSTM", linestyle=':')
plt.title("Comparación de Predicciones: LSTM vs StackingRegressor (Demanda O+)")
plt.xlabel("Semanas")
plt.ylabel("Demanda")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_pred_stk))
y_real_plot = y_real_lstm[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
fig.suptitle("Comparación de Series y Análisis ACF/PACF", fontsize=16)

# Serie real
axes[0, 0].plot(y_real_plot, color='black')
axes[0, 0].set_title("Serie real O+ ")
axes[0, 0].grid(True)

# ACF real
plot_acf(y_real_plot, lags=min(20, len(y_real_plot)//2 - 1), ax=axes[0, 1])
axes[0, 1].set_title("ACF O+ - Real")

# LSTM predicción
axes[1, 0].plot(y_pred_lstm_plot, color='blue')
axes[1, 0].set_title("Predicción O+  LSTM")
axes[1, 0].grid(True)

# ACF LSTM
plot_acf(y_pred_lstm_plot, lags=min(20, len(y_pred_lstm_plot)//2 - 1), ax=axes[1, 1])
axes[1, 1].set_title("ACF O+  - LSTM")

# Stacking predicción
axes[2, 0].plot(y_pred_stk_plot, color='green')
axes[2, 0].set_title("Predicción O+  Stacking")
axes[2, 0].grid(True)

# ACF Stacking
plot_acf(y_pred_stk_plot, lags=min(20, len(y_pred_stk_plot)//2 - 1), ax=axes[2, 1])
axes[2, 1].set_title("ACF O+  - Stacking")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig("comparativa_modelos_acf.png", dpi=300)
plt.show()
