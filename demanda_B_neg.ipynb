# %%
# ------------------------- IMPORTACIONES -------------------------
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('HDHI Admission data.csv', sep=',')

# %%
# Fechas convertidas a datetime
df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
df['D.O.A'] = df['D.O.A_manual']
df.drop(columns='D.O.A_manual', inplace=True)

# Verificar cuántas fechas nulas hay en cada una
nulos_doa = df['D.O.A'].isna().sum()

# Rango de fechas disponibles
min_doa = df['D.O.A'].min()
max_doa = df['D.O.A'].max()

duration_col = 'DURATION OF STAY'

# Ver estadísticas generales
duration_stats = df[duration_col].describe()

# Verificar valores negativos o inconsistentes
invalid_duration = df[df[duration_col] < 0]

duration_stats, invalid_duration.shape[0]
# Out:
# /var/folders/tm/_mcsvvpd5ml8xhw8l_7314j80000gn/T/ipykernel_49112/1322510359.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
# (count    15757.000000
#  mean         6.415054
#  std          5.011421
#  min          1.000000
#  25%          3.000000
#  50%          5.000000
#  75%          8.000000
#  max         98.000000
#  Name: DURATION OF STAY, dtype: float64,
#  0)

# %%
df = df.sort_values(by='D.O.A')

# %%
df['HB'] = pd.to_numeric(df['HB'], errors='coerce')
conteo = (df['HB'] < 9).sum()

print(f"Número de registros con HB < 9: {conteo}")
# Out:
# Número de registros con HB < 9: 1339

# %%
# Convertir columnas relevantes a numérico, manejando valores no numéricos
numeric_cols = ['HB', 'DURATION OF STAY', 'duration of intensive unit stay', 'CREATININE', 'UREA', 'PLATELETS', 'BNP', 'EF']
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Crear la variable proxy para transfusión
def create_transfusion_proxy(row):
    # Criterio principal: Hemoglobina baja (<8 g/dL) o anemia severa
    hb_condition = row['HB'] < 8 if pd.notna(row['HB']) else False
    severe_anemia_condition = row['SEVERE ANAEMIA'] == 1 if 'SEVERE ANAEMIA' in row else False
    
    # condiciones de gravedad que podrían requerir transfusión
    cva_bleed = row['CVA BLEED'] == 1 if 'CVA BLEED' in row else False
    stemi = row['STEMI'] == 1 if 'STEMI' in row else False
    cardiogenic_shock = row['CARDIOGENIC SHOCK'] == 1 if 'CARDIOGENIC SHOCK' in row else False
    shock = row['SHOCK'] == 1 if 'SHOCK' in row else False
    pulmonary_embolism = row['PULMONARY EMBOLISM'] == 1 if 'PULMONARY EMBOLISM' in row else False
    ckd = row['CKD'] == 1 if 'CKD' in row else False
    emergencia = row['TYPE OF ADMISSION-EMERGENCY/OPD']=='E' if 'TYPE OF ADMISSION-EMERGENCY/OPD' in row else False
    
    # Duración de la estancia (>7 días) o estancia en UCI (>1 días)
    long_stay = row['DURATION OF STAY'] > 7 if pd.notna(row['DURATION OF STAY']) else False
    icu_stay = row['duration of intensive unit stay'] > 1 if pd.notna(row['duration of intensive unit stay']) else False
    
    # Lógica para la variable proxy:
    # Necesita transfusión si:
    # HB < 9 o SEVERE ANAEMIA == 1
    # si hay condiciones graves (CVA BLEED, STEMI, SHOCK) con HB < 10
    # si hay CKD con HB < 9
    if (hb_condition or severe_anemia_condition or
        (row['HB'] < 10 and pd.notna(row['HB']) and (cva_bleed or stemi or cardiogenic_shock or shock or pulmonary_embolism)) or
        (ckd and row['HB'] < 9 and pd.notna(row['HB'])) or 
        (emergencia) or
        (long_stay and icu_stay and row['HB'] < 10 and pd.notna(row['HB']))):
        return 1
    return 0

# Aplicar la función para crear la columna 'needs_transfusion'
df['needs_transfusion'] = df.apply(create_transfusion_proxy, axis=1)

# %%
# Asignar Blood Type
np.random.seed(42)

# Asignar tipos de sangre con distribución ajustada para India
blood_types = ['A+', 'A-', 'B+', 'B-', 'O+', 'O-', 'AB+', 'AB-']
probabilities = [0.21, 0.02, 0.33, 0.02, 0.32, 0.02, 0.07, 0.01]

         
df['Blood Type'] = np.random.choice(blood_types, size=len(df), p=probabilities)

# Verificar la distribución de los tipos de sangre generados
print("Distribución de tipos de sangre en el dataset (%):")
print(df['Blood Type'].value_counts(normalize=True).sort_index() * 100)
# Out:
# Distribución de tipos de sangre en el dataset (%):
# Blood Type
# A+     21.349242
# A-      1.980072
# AB+     7.044488
# AB-     0.913880
# B+     33.375643
# B-      1.935648
# O+     31.611347
# O-      1.789681
# Name: proportion, dtype: float64

# %%
# Elimino variables para trabajar con un conjunto de datos con los datos relevantes para este trabajo
cols_utiles = ['D.O.A', 'DURATION OF STAY', 'needs_transfusion', 'Blood Type']

# Filtrar el DataFrame conservando solo esas columnas
df = df[cols_utiles].copy()

# %%
# Ahora realizaré un análisis para saber que tipo de comportamiento tiene needs_transfusion en el tiempo
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Función para seleccionar rango denso de fechas
def detectar_rango_denso(df_org, date_col='D.O.A', min_por_semana=10, buffer_semanas=2):
    df_tmp = df_org.copy()
    df_tmp[date_col] = pd.to_datetime(df_tmp[date_col], errors='coerce')
    weekly_counts = df_tmp.groupby(df_tmp[date_col].dt.to_period('W').apply(lambda r: r.start_time)).size()
    weeks_valid = weekly_counts[weekly_counts >= min_por_semana]
    if weeks_valid.empty:
        return None  # No hay rango denso suficiente
    start = weeks_valid.index.min() - pd.Timedelta(weeks=buffer_semanas)
    end = weeks_valid.index.max() + pd.Timedelta(weeks=buffer_semanas)
    return start, end

rango = detectar_rango_denso(df, min_por_semana=20)

# Aplicar filtro al dataframe original si hay rango válido
if rango:
    df_filtrado = df[
        (df['D.O.A'] > rango[0]) &
        (df['D.O.A'] <= rango[1])
    ]
else:
    df_filtrado = pd.DataFrame()  # sin datos útiles

df = df_filtrado.copy()
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Agrupo por semana y tipo de sangre
df = df[df['needs_transfusion'] == 1]
weekly_demand = df.groupby([df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time), 'Blood Type'])['needs_transfusion'].sum().unstack().fillna(0)

# %%
serie = weekly_demand['B-']
adf_result = adfuller(serie)

# Graficar ACF y PACF
fig, axes = plt.subplots(2, 1, figsize=(10, 8))
plot_acf(serie, lags=20, ax=axes[0])
axes[0].set_title("ACF - B-")

plot_pacf(serie, lags=20, ax=axes[1], method='ywm')
axes[1].set_title("PACF - B-")

plt.tight_layout()
plt.show()

# Resultado ADF
adf_output = {
    "ADF Statistic": adf_result[0],
    "p-value": adf_result[1],
    "Lags Used": adf_result[2],
    "Observations": adf_result[3],
    "Critical Values": adf_result[4]
}

adf_output
# Out:
# {'ADF Statistic': -9.439595344340814,
#  'p-value': 4.935638913794884e-16,
#  'Lags Used': 0,
#  'Observations': 117,
#  'Critical Values': {'1%': -3.487517288664615,
#   '5%': -2.8865777180380032,
#   '10%': -2.5801239192052012}}

# %%
# ------------------------- MODELO LSTM -------------------------

    
def entrenar_lstm(X_lstm, y_lstm, epochs=800):
    model = Sequential([
        LSTM(128, activation='tanh', return_sequences=True, input_shape=(X_lstm.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.3),
        
        LSTM(64, activation='tanh', return_sequences=True),
        BatchNormalization(),
        Dropout(0.2),

        LSTM(32, activation='tanh'),
        Dropout(0.3),
        
        Dense(64, activation='relu'),
        Dense(1)  # Última capa sin activación porque es una regresión
        ])
    learning_rate = 0.001 
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=MeanSquaredError(),
        
    )
    
    history = model.fit(
        X_lstm, y_lstm,
        epochs=epochs,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )
  
    return model, history


# ------------------------- STACKING REGRESSOR -------------------------

def entrenar_stacking(X_train, y_train):
    
    estimators = [
        ('xgb', XGBRegressor(max_depth=3, n_estimators=400, learning_rate=0.08, random_state=42, verbosity=0)),
        ('lgb', LGBMRegressor(max_depth=3, n_estimators=400, learning_rate=0.07, random_state=42, verbose=-1)),
        ('cat', CatBoostRegressor(depth=3, iterations=400, learning_rate=0.065, random_state=42, verbose=False))
    ]
    modelo_ensamble = StackingRegressor(
            estimators=estimators,
            final_estimator=Ridge(alpha=1.0),
            n_jobs=-1
        )
    modelo_ensamble.fit(X_train, y_train.ravel())
    return modelo_ensamble

# %%
weekly_demand['Lag_B-_1'] = serie.shift(1)
weekly_demand['Lag_B-_2'] = serie.shift(2)
weekly_demand['Lag_B-_3'] = serie.shift(3)
weekly_demand['Lag_B-_4'] = serie.shift(4)
weekly_demand['Rolling_Mean_4_B-'] = serie.rolling(window=4).mean()
weekly_demand['Rolling_Mean_8_B-'] = serie.rolling(window=8).mean()
weekly_demand['Rolling_STD_4_B-'] = serie.rolling(window=4).std()
weekly_demand['Diff_1_B-'] = serie.diff(1)

df = weekly_demand.copy()
df['Lag_B-_1'] = df['B-'].shift(1)
df['Lag_B-_2'] = df['B-'].shift(2)
df['Lag_B-_3'] = df['B-'].shift(3)
df['Lag_B-_4'] = df['B-'].shift(4)
df['Rolling_Mean_4_B-'] = df['B-'].rolling(window=4).mean()

df.columns.values[0] = 'Date'
df = df.reset_index()
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

df['Week'] = df['Date'].dt.isocalendar().week
df['Month'] = df['Date'].dt.month
df['Quarter'] = df['Date'].dt.quarter
df.dropna(inplace=True)

# %%
################# Datos para LSTM B- ################# 

features = ['Lag_B-_1', 'Lag_B-_2', 'Lag_B-_3', 'Lag_B-_4', 'Rolling_Mean_4_B-']
target = 'B-'
X = df[features]
y = df[[target]]

# Escalado robusto
from sklearn.preprocessing import RobustScaler
scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Separo entrenamiento y test (sin barajar porque es una serie temporal)
split_index = int(len(X_scaled) * 0.8)
X_train = X_scaled[:split_index]
X_test = X_scaled[split_index:]
y_lstm = y_scaled[:split_index]
y_test = y_scaled[split_index:]

# Reformatear para LSTM
X_lstm = X_train.reshape((X_train.shape[0], len(features), 1))
X_test_lstm = X_test.reshape((X_test.shape[0], len(features), 1))

# %%
# LSTM

modelo_lstm, history = entrenar_lstm(X_lstm, y_lstm)
y_pred_lstm = modelo_lstm.predict(X_test_lstm)

# Desescalar
y_pred_lstm = scaler_y.inverse_transform(y_pred_lstm)
y_real_lstm = scaler_y.inverse_transform(y_test)
# Out:
# 2025-07-15 15:28:35.362896: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-07-15 15:28:35.363248: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-07-15 15:28:35.363307: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-07-15 15:28:35.363687: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-15 15:28:35.364182: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/800
# 2025-07-15 15:28:37.251411: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - loss: 0.7944 - val_loss: 0.5894
# Epoch 2/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.6981 - val_loss: 0.5856
# Epoch 3/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.6649 - val_loss: 0.5819
# Epoch 4/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.7651 - val_loss: 0.5782
# Epoch 5/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6446 - val_loss: 0.5759
# Epoch 6/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.7633 - val_loss: 0.5736
# Epoch 7/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6919 - val_loss: 0.5712
# Epoch 8/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6434 - val_loss: 0.5694
# Epoch 9/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6734 - val_loss: 0.5688
# Epoch 10/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.7063 - val_loss: 0.5680
# Epoch 11/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6822 - val_loss: 0.5669
# Epoch 12/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6142 - val_loss: 0.5663
# Epoch 13/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6237 - val_loss: 0.5659
# Epoch 14/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.6400 - val_loss: 0.5659
# Epoch 15/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5792 - val_loss: 0.5665
# Epoch 16/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6999 - val_loss: 0.5677
# Epoch 17/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6722 - val_loss: 0.5691
# Epoch 18/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6921 - val_loss: 0.5707
# Epoch 19/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6369 - val_loss: 0.5728
# Epoch 20/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6965 - val_loss: 0.5752
# Epoch 21/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5470 - val_loss: 0.5761
# Epoch 22/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5711 - val_loss: 0.5763
# Epoch 23/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5962 - val_loss: 0.5748
# Epoch 24/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5225 - val_loss: 0.5737
# Epoch 25/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6379 - val_loss: 0.5747
# Epoch 26/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5918 - val_loss: 0.5758
# Epoch 27/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5704 - val_loss: 0.5770
# Epoch 28/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6594 - val_loss: 0.5769
# Epoch 29/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6219 - val_loss: 0.5765
# Epoch 30/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.5545 - val_loss: 0.5753
# Epoch 31/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4525 - val_loss: 0.5731
# Epoch 32/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5859 - val_loss: 0.5699
# Epoch 33/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4511 - val_loss: 0.5669
# Epoch 34/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5727 - val_loss: 0.5648
# Epoch 35/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6056 - val_loss: 0.5627
# Epoch 36/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5307 - val_loss: 0.5606
# Epoch 37/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6175 - val_loss: 0.5596
# Epoch 38/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4959 - val_loss: 0.5597
# Epoch 39/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5593 - val_loss: 0.5608
# Epoch 40/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5092 - val_loss: 0.5619
# Epoch 41/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5123 - val_loss: 0.5621
# Epoch 42/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4841 - val_loss: 0.5609
# Epoch 43/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4905 - val_loss: 0.5591
# Epoch 44/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4697 - val_loss: 0.5569
# Epoch 45/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4111 - val_loss: 0.5555
# Epoch 46/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6169 - val_loss: 0.5533
# Epoch 47/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5008 - val_loss: 0.5536
# Epoch 48/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4835 - val_loss: 0.5561
# Epoch 49/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4927 - val_loss: 0.5579
# Epoch 50/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4598 - val_loss: 0.5595
# Epoch 51/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4460 - val_loss: 0.5590
# Epoch 52/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4866 - val_loss: 0.5581
# Epoch 53/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3013 - val_loss: 0.5585
# Epoch 54/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4768 - val_loss: 0.5594
# Epoch 55/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3852 - val_loss: 0.5614
# Epoch 56/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5452 - val_loss: 0.5627
# Epoch 57/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4345 - val_loss: 0.5630
# Epoch 58/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4238 - val_loss: 0.5642
# Epoch 59/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4827 - val_loss: 0.5632
# Epoch 60/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3976 - val_loss: 0.5622
# Epoch 61/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3973 - val_loss: 0.5602
# Epoch 62/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3693 - val_loss: 0.5588
# Epoch 63/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3538 - val_loss: 0.5588
# Epoch 64/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3347 - val_loss: 0.5588
# Epoch 65/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3593 - val_loss: 0.5566
# Epoch 66/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3740 - val_loss: 0.5552
# Epoch 67/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2797 - val_loss: 0.5553
# Epoch 68/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3236 - val_loss: 0.5562
# Epoch 69/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3349 - val_loss: 0.5517
# Epoch 70/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3784 - val_loss: 0.5472
# Epoch 71/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3641 - val_loss: 0.5456
# Epoch 72/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4258 - val_loss: 0.5424
# Epoch 73/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2875 - val_loss: 0.5464
# Epoch 74/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3315 - val_loss: 0.5516
# Epoch 75/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3429 - val_loss: 0.5521
# Epoch 76/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3665 - val_loss: 0.5505
# Epoch 77/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2726 - val_loss: 0.5462
# Epoch 78/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2343 - val_loss: 0.5448
# Epoch 79/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2004 - val_loss: 0.5506
# Epoch 80/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2480 - val_loss: 0.5576
# Epoch 81/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2279 - val_loss: 0.5627
# Epoch 82/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2697 - val_loss: 0.5657
# Epoch 83/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2303 - val_loss: 0.5655
# Epoch 84/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2291 - val_loss: 0.5627
# Epoch 85/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2150 - val_loss: 0.5591
# Epoch 86/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2264 - val_loss: 0.5557
# Epoch 87/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2818 - val_loss: 0.5547
# Epoch 88/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2358 - val_loss: 0.5569
# Epoch 89/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1719 - val_loss: 0.5594
# Epoch 90/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2439 - val_loss: 0.5504
# Epoch 91/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2244 - val_loss: 0.5400
# Epoch 92/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2048 - val_loss: 0.5304
# Epoch 93/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1829 - val_loss: 0.5228
# Epoch 94/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1475 - val_loss: 0.5174
# Epoch 95/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1805 - val_loss: 0.5156
# Epoch 96/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2094 - val_loss: 0.5191
# Epoch 97/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1408 - val_loss: 0.5245
# Epoch 98/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1419 - val_loss: 0.5324
# Epoch 99/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1688 - val_loss: 0.5428
# Epoch 100/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1743 - val_loss: 0.5471
# Epoch 101/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2070 - val_loss: 0.5462
# Epoch 102/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2634 - val_loss: 0.5371
# Epoch 103/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1883 - val_loss: 0.5368
# Epoch 104/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2142 - val_loss: 0.5326
# Epoch 105/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1172 - val_loss: 0.5241
# Epoch 106/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1894 - val_loss: 0.5198
# Epoch 107/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1801 - val_loss: 0.5105
# Epoch 108/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1714 - val_loss: 0.5101
# Epoch 109/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1351 - val_loss: 0.5313
# Epoch 110/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1640 - val_loss: 0.5782
# Epoch 111/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1306 - val_loss: 0.6056
# Epoch 112/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1761 - val_loss: 0.5759
# Epoch 113/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1432 - val_loss: 0.5476
# Epoch 114/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1722 - val_loss: 0.5396
# Epoch 115/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1320 - val_loss: 0.5364
# Epoch 116/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1217 - val_loss: 0.5248
# Epoch 117/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1028 - val_loss: 0.5097
# Epoch 118/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1153 - val_loss: 0.4943
# Epoch 119/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0718 - val_loss: 0.4920
# Epoch 120/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1182 - val_loss: 0.4899
# Epoch 121/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0860 - val_loss: 0.4845
# Epoch 122/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1200 - val_loss: 0.4909
# Epoch 123/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1193 - val_loss: 0.4962
# Epoch 124/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1215 - val_loss: 0.5018
# Epoch 125/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1157 - val_loss: 0.4991
# Epoch 126/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1402 - val_loss: 0.4913
# Epoch 127/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0983 - val_loss: 0.4883
# Epoch 128/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1459 - val_loss: 0.4986
# Epoch 129/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1538 - val_loss: 0.4963
# Epoch 130/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1150 - val_loss: 0.4937
# Epoch 131/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1032 - val_loss: 0.4971
# Epoch 132/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1758 - val_loss: 0.4876
# Epoch 133/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1545 - val_loss: 0.4670
# Epoch 134/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1722 - val_loss: 0.4558
# Epoch 135/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1226 - val_loss: 0.4578
# Epoch 136/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1471 - val_loss: 0.4726
# Epoch 137/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0952 - val_loss: 0.4966
# Epoch 138/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1288 - val_loss: 0.4990
# Epoch 139/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1069 - val_loss: 0.4790
# Epoch 140/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1066 - val_loss: 0.4729
# Epoch 141/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1430 - val_loss: 0.4732
# Epoch 142/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1645 - val_loss: 0.4680
# Epoch 143/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1065 - val_loss: 0.4520
# Epoch 144/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1090 - val_loss: 0.4350
# Epoch 145/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1272 - val_loss: 0.4167
# Epoch 146/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0905 - val_loss: 0.4024
# Epoch 147/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1241 - val_loss: 0.4090
# Epoch 148/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1084 - val_loss: 0.4150
# Epoch 149/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1023 - val_loss: 0.4098
# Epoch 150/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0958 - val_loss: 0.3826
# Epoch 151/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0716 - val_loss: 0.3521
# Epoch 152/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0862 - val_loss: 0.3432
# Epoch 153/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1044 - val_loss: 0.3424
# Epoch 154/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0941 - val_loss: 0.3428
# Epoch 155/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0834 - val_loss: 0.3570
# Epoch 156/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1114 - val_loss: 0.3613
# Epoch 157/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0979 - val_loss: 0.3493
# Epoch 158/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0776 - val_loss: 0.3462
# Epoch 159/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1313 - val_loss: 0.3344
# Epoch 160/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1251 - val_loss: 0.3265
# Epoch 161/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0971 - val_loss: 0.3216
# Epoch 162/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0775 - val_loss: 0.3208
# Epoch 163/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1345 - val_loss: 0.3262
# Epoch 164/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0973 - val_loss: 0.3399
# Epoch 165/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0649 - val_loss: 0.3519
# Epoch 166/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0889 - val_loss: 0.3551
# Epoch 167/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0725 - val_loss: 0.3147
# Epoch 168/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1029 - val_loss: 0.2734
# Epoch 169/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1117 - val_loss: 0.2367
# Epoch 170/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0574 - val_loss: 0.2307
# Epoch 171/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0972 - val_loss: 0.2393
# Epoch 172/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1034 - val_loss: 0.2541
# Epoch 173/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0950 - val_loss: 0.2861
# Epoch 174/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0966 - val_loss: 0.3097
# Epoch 175/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0812 - val_loss: 0.3236
# Epoch 176/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0775 - val_loss: 0.3165
# Epoch 177/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1042 - val_loss: 0.3068
# Epoch 178/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0651 - val_loss: 0.2843
# Epoch 179/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0849 - val_loss: 0.2735
# Epoch 180/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0542 - val_loss: 0.2634
# Epoch 181/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0940 - val_loss: 0.2535
# Epoch 182/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1131 - val_loss: 0.2441
# Epoch 183/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0821 - val_loss: 0.2308
# Epoch 184/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0726 - val_loss: 0.2098
# Epoch 185/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0663 - val_loss: 0.1920
# Epoch 186/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0892 - val_loss: 0.1787
# Epoch 187/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0937 - val_loss: 0.1588
# Epoch 188/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0764 - val_loss: 0.1381
# Epoch 189/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0729 - val_loss: 0.1307
# Epoch 190/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1000 - val_loss: 0.1352
# Epoch 191/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0956 - val_loss: 0.1581
# Epoch 192/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0673 - val_loss: 0.1829
# Epoch 193/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0587 - val_loss: 0.2052
# Epoch 194/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1008 - val_loss: 0.2070
# Epoch 195/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0885 - val_loss: 0.1976
# Epoch 196/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0940 - val_loss: 0.1790
# Epoch 197/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0703 - val_loss: 0.1751
# Epoch 198/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0643 - val_loss: 0.1710
# Epoch 199/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0779 - val_loss: 0.1661
# Epoch 200/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0776 - val_loss: 0.1587
# Epoch 201/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1153 - val_loss: 0.1427
# Epoch 202/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0966 - val_loss: 0.1348
# Epoch 203/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0565 - val_loss: 0.1365
# Epoch 204/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0518 - val_loss: 0.1522
# Epoch 205/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0710 - val_loss: 0.1620
# Epoch 206/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0781 - val_loss: 0.1602
# Epoch 207/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0653 - val_loss: 0.1293
# Epoch 208/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0550 - val_loss: 0.1018
# Epoch 209/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0704 - val_loss: 0.0977
# Epoch 210/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0636 - val_loss: 0.1122
# Epoch 211/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0899 - val_loss: 0.1347
# Epoch 212/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0846 - val_loss: 0.1434
# Epoch 213/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0948 - val_loss: 0.1354
# Epoch 214/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0696 - val_loss: 0.1324
# Epoch 215/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0783 - val_loss: 0.1303
# Epoch 216/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0836 - val_loss: 0.1302
# Epoch 217/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1104 - val_loss: 0.1298
# Epoch 218/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0615 - val_loss: 0.1040
# Epoch 219/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0978 - val_loss: 0.0587
# Epoch 220/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0640 - val_loss: 0.0518
# Epoch 221/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1406 - val_loss: 0.0601
# Epoch 222/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0687 - val_loss: 0.0697
# Epoch 223/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0622 - val_loss: 0.0785
# Epoch 224/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0779 - val_loss: 0.0787
# Epoch 225/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0847 - val_loss: 0.0731
# Epoch 226/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0604 - val_loss: 0.0835
# Epoch 227/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0758 - val_loss: 0.1138
# Epoch 228/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0925 - val_loss: 0.1144
# Epoch 229/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0790 - val_loss: 0.0980
# Epoch 230/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0834 - val_loss: 0.0984
# Epoch 231/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0920 - val_loss: 0.0944
# Epoch 232/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0764 - val_loss: 0.0826
# Epoch 233/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0645 - val_loss: 0.0650
# Epoch 234/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0956 - val_loss: 0.0514
# Epoch 235/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0692 - val_loss: 0.0471
# Epoch 236/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0555 - val_loss: 0.0486
# Epoch 237/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0639 - val_loss: 0.0566
# Epoch 238/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0868 - val_loss: 0.0591
# Epoch 239/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0782 - val_loss: 0.0596
# Epoch 240/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0642 - val_loss: 0.0736
# Epoch 241/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0640 - val_loss: 0.1518
# Epoch 242/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0883 - val_loss: 0.1819
# Epoch 243/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1296 - val_loss: 0.1586
# Epoch 244/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1165 - val_loss: 0.1040
# Epoch 245/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1058 - val_loss: 0.0641
# Epoch 246/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0838 - val_loss: 0.0607
# Epoch 247/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0848 - val_loss: 0.0794
# Epoch 248/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0738 - val_loss: 0.0881
# Epoch 249/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1118 - val_loss: 0.0783
# Epoch 250/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0622 - val_loss: 0.0620
# Epoch 251/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1224 - val_loss: 0.0550
# Epoch 252/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0917 - val_loss: 0.0490
# Epoch 253/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0693 - val_loss: 0.0498
# Epoch 254/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0920 - val_loss: 0.0470
# Epoch 255/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0558 - val_loss: 0.0444
# Epoch 256/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0691 - val_loss: 0.0417
# Epoch 257/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1019 - val_loss: 0.0348
# Epoch 258/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0572 - val_loss: 0.0297
# Epoch 259/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0610 - val_loss: 0.0286
# Epoch 260/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0938 - val_loss: 0.0307
# Epoch 261/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0682 - val_loss: 0.0391
# Epoch 262/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0958 - val_loss: 0.0375
# Epoch 263/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0490 - val_loss: 0.0411
# Epoch 264/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0700 - val_loss: 0.0462
# Epoch 265/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0849 - val_loss: 0.0580
# Epoch 266/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0842 - val_loss: 0.0585
# Epoch 267/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0614 - val_loss: 0.0559
# Epoch 268/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0876 - val_loss: 0.0505
# Epoch 269/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0526 - val_loss: 0.0467
# Epoch 270/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0518 - val_loss: 0.0466
# Epoch 271/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0572 - val_loss: 0.0482
# Epoch 272/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0503 - val_loss: 0.0507
# Epoch 273/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0649 - val_loss: 0.0493
# Epoch 274/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0715 - val_loss: 0.0413
# Epoch 275/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0549 - val_loss: 0.0373
# Epoch 276/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0760 - val_loss: 0.0412
# Epoch 277/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0594 - val_loss: 0.0514
# Epoch 278/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0515 - val_loss: 0.0625
# Epoch 279/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0573 - val_loss: 0.0602
# Epoch 280/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0672 - val_loss: 0.0464
# Epoch 281/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0455 - val_loss: 0.0406
# Epoch 282/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0650 - val_loss: 0.0387
# Epoch 283/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0591 - val_loss: 0.0347
# Epoch 284/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0651 - val_loss: 0.0323
# Epoch 285/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0501 - val_loss: 0.0474
# Epoch 286/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0457 - val_loss: 0.0580
# Epoch 287/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0694 - val_loss: 0.0576
# Epoch 288/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0662 - val_loss: 0.0440
# Epoch 289/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0448 - val_loss: 0.0347
# Epoch 290/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0467 - val_loss: 0.0620
# Epoch 291/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0658 - val_loss: 0.1254
# Epoch 292/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0981 - val_loss: 0.1091
# Epoch 293/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0610 - val_loss: 0.0664
# Epoch 294/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0546 - val_loss: 0.0505
# Epoch 295/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0634 - val_loss: 0.0427
# Epoch 296/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0554 - val_loss: 0.0525
# Epoch 297/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0565 - val_loss: 0.0702
# Epoch 298/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0726 - val_loss: 0.0639
# Epoch 299/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0483 - val_loss: 0.0471
# Epoch 300/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0680 - val_loss: 0.0403
# Epoch 301/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0606 - val_loss: 0.0504
# Epoch 302/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0462 - val_loss: 0.0768
# Epoch 303/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0408 - val_loss: 0.1188
# Epoch 304/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0726 - val_loss: 0.1040
# Epoch 305/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0696 - val_loss: 0.0537
# Epoch 306/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0646 - val_loss: 0.0500
# Epoch 307/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0918 - val_loss: 0.0472
# Epoch 308/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0447 - val_loss: 0.0431
# Epoch 309/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0463 - val_loss: 0.0421
# Epoch 310/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0477 - val_loss: 0.0413
# Epoch 311/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0629 - val_loss: 0.0385
# Epoch 312/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0722 - val_loss: 0.0387
# Epoch 313/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0395 - val_loss: 0.0439
# Epoch 314/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0435 - val_loss: 0.0424
# Epoch 315/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0478 - val_loss: 0.0365
# Epoch 316/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0333 - val_loss: 0.0322
# Epoch 317/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0553 - val_loss: 0.0308
# Epoch 318/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0462 - val_loss: 0.0307
# Epoch 319/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0692 - val_loss: 0.0385
# Epoch 320/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0609 - val_loss: 0.0434
# Epoch 321/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0819 - val_loss: 0.0372
# Epoch 322/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0904 - val_loss: 0.0388
# Epoch 323/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0504 - val_loss: 0.0453
# Epoch 324/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0671 - val_loss: 0.0431
# Epoch 325/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0987 - val_loss: 0.0426
# Epoch 326/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0585 - val_loss: 0.0415
# Epoch 327/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0536 - val_loss: 0.0480
# Epoch 328/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0561 - val_loss: 0.0442
# Epoch 329/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0718 - val_loss: 0.0440
# Epoch 330/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0578 - val_loss: 0.0516
# Epoch 331/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0513 - val_loss: 0.0576
# Epoch 332/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0913 - val_loss: 0.0533
# Epoch 333/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0490 - val_loss: 0.0492
# Epoch 334/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0580 - val_loss: 0.0453
# Epoch 335/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0597 - val_loss: 0.0384
# Epoch 336/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0867 - val_loss: 0.0408
# Epoch 337/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0495 - val_loss: 0.0596
# Epoch 338/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0519 - val_loss: 0.0500
# Epoch 339/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0712 - val_loss: 0.0417
# Epoch 340/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0342 - val_loss: 0.0423
# Epoch 341/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0596 - val_loss: 0.0452
# Epoch 342/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0455 - val_loss: 0.0547
# Epoch 343/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0530 - val_loss: 0.0637
# Epoch 344/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0542 - val_loss: 0.0664
# Epoch 345/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0821 - val_loss: 0.0549
# Epoch 346/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0435 - val_loss: 0.0495
# Epoch 347/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0542 - val_loss: 0.0472
# Epoch 348/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0481 - val_loss: 0.0470
# Epoch 349/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0544 - val_loss: 0.0433
# Epoch 350/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0402 - val_loss: 0.0404
# Epoch 351/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0565 - val_loss: 0.0439
# Epoch 352/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0559 - val_loss: 0.0465
# Epoch 353/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0585 - val_loss: 0.0402
# Epoch 354/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0497 - val_loss: 0.0358
# Epoch 355/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0428 - val_loss: 0.0419
# Epoch 356/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0650 - val_loss: 0.0408
# Epoch 357/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0743 - val_loss: 0.0397
# Epoch 358/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0447 - val_loss: 0.0425
# Epoch 359/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0534 - val_loss: 0.0500
# Epoch 360/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0413 - val_loss: 0.0600
# Epoch 361/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0339 - val_loss: 0.0597
# Epoch 362/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0502 - val_loss: 0.0497
# Epoch 363/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0342 - val_loss: 0.0396
# Epoch 364/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0511 - val_loss: 0.0441
# Epoch 365/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0512 - val_loss: 0.0580
# Epoch 366/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0624 - val_loss: 0.0592
# Epoch 367/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0426 - val_loss: 0.0531
# Epoch 368/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0505 - val_loss: 0.0471
# Epoch 369/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0433 - val_loss: 0.0504
# Epoch 370/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0400 - val_loss: 0.0516
# Epoch 371/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0392 - val_loss: 0.0473
# Epoch 372/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0305 - val_loss: 0.0452
# Epoch 373/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0629 - val_loss: 0.0433
# Epoch 374/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0379 - val_loss: 0.0392
# Epoch 375/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0398 - val_loss: 0.0367
# Epoch 376/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0524 - val_loss: 0.0394
# Epoch 377/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0386 - val_loss: 0.0363
# Epoch 378/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0611 - val_loss: 0.0411
# Epoch 379/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0940 - val_loss: 0.0476
# Epoch 380/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0358 - val_loss: 0.0507
# Epoch 381/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0609 - val_loss: 0.0475
# Epoch 382/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0467 - val_loss: 0.0418
# Epoch 383/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0750 - val_loss: 0.0349
# Epoch 384/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0781 - val_loss: 0.0352
# Epoch 385/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0418 - val_loss: 0.0387
# Epoch 386/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0514 - val_loss: 0.0385
# Epoch 387/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0512 - val_loss: 0.0335
# Epoch 388/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0362 - val_loss: 0.0357
# Epoch 389/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0380 - val_loss: 0.0420
# Epoch 390/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0466 - val_loss: 0.0453
# Epoch 391/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0746 - val_loss: 0.0487
# Epoch 392/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0336 - val_loss: 0.0556
# Epoch 393/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0741 - val_loss: 0.0547
# Epoch 394/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0931 - val_loss: 0.0557
# Epoch 395/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0568 - val_loss: 0.0564
# Epoch 396/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0493 - val_loss: 0.0571
# Epoch 397/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0554 - val_loss: 0.0544
# Epoch 398/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0620 - val_loss: 0.0479
# Epoch 399/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0430 - val_loss: 0.0457
# Epoch 400/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0441 - val_loss: 0.0506
# Epoch 401/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0568 - val_loss: 0.0523
# Epoch 402/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0456 - val_loss: 0.0497
# Epoch 403/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0218 - val_loss: 0.0530
# Epoch 404/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0371 - val_loss: 0.0559
# Epoch 405/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0442 - val_loss: 0.0477
# Epoch 406/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0612 - val_loss: 0.0484
# Epoch 407/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0561 - val_loss: 0.0559
# Epoch 408/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0360 - val_loss: 0.0584
# Epoch 409/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0495 - val_loss: 0.0557
# Epoch 410/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0329 - val_loss: 0.0534
# Epoch 411/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0463 - val_loss: 0.0625
# Epoch 412/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0359 - val_loss: 0.0741
# Epoch 413/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0322 - val_loss: 0.0743
# Epoch 414/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0612 - val_loss: 0.0757
# Epoch 415/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0322 - val_loss: 0.0824
# Epoch 416/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0474 - val_loss: 0.0694
# Epoch 417/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0397 - val_loss: 0.0521
# Epoch 418/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0341 - val_loss: 0.0560
# Epoch 419/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0589 - val_loss: 0.0546
# Epoch 420/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0414 - val_loss: 0.0492
# Epoch 421/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0581 - val_loss: 0.0499
# Epoch 422/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0521 - val_loss: 0.0508
# Epoch 423/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0348 - val_loss: 0.0479
# Epoch 424/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0436 - val_loss: 0.0454
# Epoch 425/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0277 - val_loss: 0.0470
# Epoch 426/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0444 - val_loss: 0.0462
# Epoch 427/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0474 - val_loss: 0.0447
# Epoch 428/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0416 - val_loss: 0.0436
# Epoch 429/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0481 - val_loss: 0.0446
# Epoch 430/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0454 - val_loss: 0.0414
# Epoch 431/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0428 - val_loss: 0.0416
# Epoch 432/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0394 - val_loss: 0.0386
# Epoch 433/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0591 - val_loss: 0.0386
# Epoch 434/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0320 - val_loss: 0.0454
# Epoch 435/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0288 - val_loss: 0.0513
# Epoch 436/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0336 - val_loss: 0.0573
# Epoch 437/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0692 - val_loss: 0.0524
# Epoch 438/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0337 - val_loss: 0.0480
# Epoch 439/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0523 - val_loss: 0.0447
# Epoch 440/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0491 - val_loss: 0.0409
# Epoch 441/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0409 - val_loss: 0.0390
# Epoch 442/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0548 - val_loss: 0.0376
# Epoch 443/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0426 - val_loss: 0.0379
# Epoch 444/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0477 - val_loss: 0.0505
# Epoch 445/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0391 - val_loss: 0.0859
# Epoch 446/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.0538 - val_loss: 0.0865
# Epoch 447/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0300 - val_loss: 0.0682
# Epoch 448/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0398 - val_loss: 0.0562
# Epoch 449/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0352 - val_loss: 0.0578
# Epoch 450/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0781 - val_loss: 0.0792
# Epoch 451/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0436 - val_loss: 0.0870
# Epoch 452/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0535 - val_loss: 0.0899
# Epoch 453/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0477 - val_loss: 0.0886
# Epoch 454/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0292 - val_loss: 0.0962
# Epoch 455/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0492 - val_loss: 0.0847
# Epoch 456/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0326 - val_loss: 0.0737
# Epoch 457/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0474 - val_loss: 0.0586
# Epoch 458/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0646 - val_loss: 0.0524
# Epoch 459/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0504 - val_loss: 0.0519
# Epoch 460/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0634 - val_loss: 0.0478
# Epoch 461/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0391 - val_loss: 0.0447
# Epoch 462/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0429 - val_loss: 0.0434
# Epoch 463/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0500 - val_loss: 0.0421
# Epoch 464/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0680 - val_loss: 0.0446
# Epoch 465/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0438 - val_loss: 0.0510
# Epoch 466/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0458 - val_loss: 0.0486
# Epoch 467/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0461 - val_loss: 0.0416
# Epoch 468/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0345 - val_loss: 0.0376
# Epoch 469/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0529 - val_loss: 0.0334
# Epoch 470/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0543 - val_loss: 0.0329
# Epoch 471/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0600 - val_loss: 0.0355
# Epoch 472/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0294 - val_loss: 0.0385
# Epoch 473/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0412 - val_loss: 0.0419
# Epoch 474/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0540 - val_loss: 0.0432
# Epoch 475/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0734 - val_loss: 0.0430
# Epoch 476/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0447 - val_loss: 0.0435
# Epoch 477/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0383 - val_loss: 0.0514
# Epoch 478/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0654 - val_loss: 0.0553
# Epoch 479/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0328 - val_loss: 0.0508
# Epoch 480/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0417 - val_loss: 0.0526
# Epoch 481/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0454 - val_loss: 0.0602
# Epoch 482/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0484 - val_loss: 0.0585
# Epoch 483/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0467 - val_loss: 0.0537
# Epoch 484/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0456 - val_loss: 0.0460
# Epoch 485/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0492 - val_loss: 0.0494
# Epoch 486/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0406 - val_loss: 0.0529
# Epoch 487/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0475 - val_loss: 0.0539
# Epoch 488/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0389 - val_loss: 0.0534
# Epoch 489/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0505 - val_loss: 0.0529
# Epoch 490/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0453 - val_loss: 0.0511
# Epoch 491/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0437 - val_loss: 0.0477
# Epoch 492/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0433 - val_loss: 0.0444
# Epoch 493/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0378 - val_loss: 0.0491
# Epoch 494/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0470 - val_loss: 0.0526
# Epoch 495/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0331 - val_loss: 0.0582
# Epoch 496/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0367 - val_loss: 0.0567
# Epoch 497/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0387 - val_loss: 0.0463
# Epoch 498/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0446 - val_loss: 0.0383
# Epoch 499/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0328 - val_loss: 0.0413
# Epoch 500/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0311 - val_loss: 0.0469
# Epoch 501/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0383 - val_loss: 0.0514
# Epoch 502/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0513 - val_loss: 0.0432
# Epoch 503/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0489 - val_loss: 0.0378
# Epoch 504/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0346 - val_loss: 0.0350
# Epoch 505/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0384 - val_loss: 0.0309
# Epoch 506/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0522 - val_loss: 0.0283
# Epoch 507/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0522 - val_loss: 0.0290
# Epoch 508/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0382 - val_loss: 0.0328
# Epoch 509/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0443 - val_loss: 0.0362
# Epoch 510/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0252 - val_loss: 0.0433
# Epoch 511/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0401 - val_loss: 0.0565
# Epoch 512/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0493 - val_loss: 0.0636
# Epoch 513/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0529 - val_loss: 0.0620
# Epoch 514/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0481 - val_loss: 0.0503
# Epoch 515/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0321 - val_loss: 0.0386
# Epoch 516/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0338 - val_loss: 0.0346
# Epoch 517/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0389 - val_loss: 0.0333
# Epoch 518/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0564 - val_loss: 0.0315
# Epoch 519/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0404 - val_loss: 0.0375
# Epoch 520/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0439 - val_loss: 0.0388
# Epoch 521/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0526 - val_loss: 0.0403
# Epoch 522/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0420 - val_loss: 0.0486
# Epoch 523/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0303 - val_loss: 0.0674
# Epoch 524/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0612 - val_loss: 0.0576
# Epoch 525/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0335 - val_loss: 0.0384
# Epoch 526/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0477 - val_loss: 0.0344
# Epoch 527/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0401 - val_loss: 0.0355
# Epoch 528/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0455 - val_loss: 0.0363
# Epoch 529/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0339 - val_loss: 0.0396
# Epoch 530/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0315 - val_loss: 0.0472
# Epoch 531/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0343 - val_loss: 0.0453
# Epoch 532/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0555 - val_loss: 0.0348
# Epoch 533/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0336 - val_loss: 0.0378
# Epoch 534/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0338 - val_loss: 0.0348
# Epoch 535/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0359 - val_loss: 0.0337
# Epoch 536/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0418 - val_loss: 0.0391
# Epoch 537/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0311 - val_loss: 0.0397
# Epoch 538/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0348 - val_loss: 0.0340
# Epoch 539/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0350 - val_loss: 0.0405
# Epoch 540/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0515 - val_loss: 0.0603
# Epoch 541/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0505 - val_loss: 0.0629
# Epoch 542/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0366 - val_loss: 0.0451
# Epoch 543/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0442 - val_loss: 0.0432
# Epoch 544/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0468 - val_loss: 0.0509
# Epoch 545/800
# ...
# Epoch 616/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0291 - val_loss: 0.0384
# Epoch 617/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0487 - val_loss: 0.0574
# Epoch 618/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0452 - val_loss: 0.0758
# Epoch 619/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0557 - val_loss: 0.0571
# Epoch 620/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0270 - val_loss: 0.0488
# Epoch 621/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0452 - val_loss: 0.0382
# Epoch 622/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0351 - val_loss: 0.0351
# Epoch 623/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0206 - val_loss: 0.0376
# Epoch 624/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0291 - val_loss: 0.0446
# Epoch 625/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0367 - val_loss: 0.0515
# Epoch 626/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0330 - val_loss: 0.0563
# Epoch 627/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0536 - val_loss: 0.0552
# Epoch 628/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0411 - val_loss: 0.0556
# Epoch 629/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0325 - val_loss: 0.0573
# Epoch 630/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0312 - val_loss: 0.0557
# Epoch 631/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0321 - val_loss: 0.0530
# Epoch 632/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0374 - val_loss: 0.0532
# Epoch 633/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0297 - val_loss: 0.0589
# Epoch 634/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0454 - val_loss: 0.0647
# Epoch 635/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0281 - val_loss: 0.0750
# Epoch 636/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0477 - val_loss: 0.0812
# Epoch 637/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0278 - val_loss: 0.0768
# Epoch 638/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0298 - val_loss: 0.0765
# Epoch 639/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0437 - val_loss: 0.0626
# Epoch 640/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0287 - val_loss: 0.0553
# Epoch 641/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0289 - val_loss: 0.0544
# Epoch 642/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0273 - val_loss: 0.0534
# Epoch 643/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0416 - val_loss: 0.0490
# Epoch 644/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0408 - val_loss: 0.0463
# Epoch 645/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0423 - val_loss: 0.0452
# Epoch 646/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0456 - val_loss: 0.0486
# Epoch 647/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0344 - val_loss: 0.0532
# Epoch 648/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0271 - val_loss: 0.0654
# Epoch 649/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0426 - val_loss: 0.0725
# Epoch 650/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0430 - val_loss: 0.0617
# Epoch 651/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0267 - val_loss: 0.0531
# Epoch 652/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0533 - val_loss: 0.0463
# Epoch 653/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0359 - val_loss: 0.0440
# Epoch 654/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0285 - val_loss: 0.0459
# Epoch 655/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0441 - val_loss: 0.0514
# Epoch 656/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0273 - val_loss: 0.0593
# Epoch 657/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0372 - val_loss: 0.0604
# Epoch 658/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0426 - val_loss: 0.0568
# Epoch 659/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0383 - val_loss: 0.0553
# Epoch 660/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0279 - val_loss: 0.0516
# Epoch 661/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0323 - val_loss: 0.0481
# Epoch 662/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0373 - val_loss: 0.0430
# Epoch 663/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0320 - val_loss: 0.0410
# Epoch 664/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0385 - val_loss: 0.0462
# Epoch 665/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0350 - val_loss: 0.0732
# Epoch 666/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0396 - val_loss: 0.0777
# Epoch 667/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0552 - val_loss: 0.0557
# Epoch 668/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0519 - val_loss: 0.0388
# Epoch 669/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0487 - val_loss: 0.0468
# Epoch 670/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0431 - val_loss: 0.0613
# Epoch 671/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0283 - val_loss: 0.0477
# Epoch 672/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0359 - val_loss: 0.0482
# Epoch 673/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0347 - val_loss: 0.0663
# Epoch 674/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0472 - val_loss: 0.0699
# Epoch 675/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0359 - val_loss: 0.0560
# Epoch 676/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0379 - val_loss: 0.0382
# Epoch 677/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0254 - val_loss: 0.0345
# Epoch 678/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0292 - val_loss: 0.0346
# Epoch 679/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0384 - val_loss: 0.0361
# Epoch 680/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0414 - val_loss: 0.0435
# Epoch 681/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0367 - val_loss: 0.0447
# Epoch 682/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0388 - val_loss: 0.0403
# Epoch 683/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0251 - val_loss: 0.0435
# Epoch 684/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0357 - val_loss: 0.0537
# Epoch 685/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0493 - val_loss: 0.0493
# Epoch 686/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0417 - val_loss: 0.0411
# Epoch 687/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0431 - val_loss: 0.0410
# Epoch 688/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0274 - val_loss: 0.0457
# Epoch 689/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0271 - val_loss: 0.0601
# Epoch 690/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0312 - val_loss: 0.0680
# Epoch 691/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0307 - val_loss: 0.0641
# Epoch 692/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0387 - val_loss: 0.0508
# Epoch 693/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0422 - val_loss: 0.0457
# Epoch 694/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0210 - val_loss: 0.0469
# Epoch 695/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0247 - val_loss: 0.0493
# Epoch 696/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0317 - val_loss: 0.0498
# Epoch 697/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0318 - val_loss: 0.0532
# Epoch 698/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0477 - val_loss: 0.0641
# Epoch 699/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0490 - val_loss: 0.0705
# Epoch 700/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0257 - val_loss: 0.0702
# Epoch 701/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0346 - val_loss: 0.0671
# Epoch 702/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0252 - val_loss: 0.0637
# Epoch 703/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0374 - val_loss: 0.0555
# Epoch 704/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0232 - val_loss: 0.0537
# Epoch 705/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0370 - val_loss: 0.0531
# Epoch 706/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0390 - val_loss: 0.0532
# Epoch 707/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0318 - val_loss: 0.0527
# Epoch 708/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0318 - val_loss: 0.0568
# Epoch 709/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0247 - val_loss: 0.0603
# Epoch 710/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0271 - val_loss: 0.0632
# Epoch 711/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0247 - val_loss: 0.0645
# Epoch 712/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0293 - val_loss: 0.0667
# Epoch 713/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0387 - val_loss: 0.0628
# Epoch 714/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0303 - val_loss: 0.0573
# Epoch 715/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0258 - val_loss: 0.0520
# Epoch 716/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0244 - val_loss: 0.0468
# Epoch 717/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0281 - val_loss: 0.0453
# Epoch 718/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0216 - val_loss: 0.0449
# Epoch 719/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0337 - val_loss: 0.0482
# Epoch 720/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0481 - val_loss: 0.0560
# Epoch 721/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0335 - val_loss: 0.0536
# Epoch 722/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0315 - val_loss: 0.0468
# Epoch 723/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0233 - val_loss: 0.0477
# Epoch 724/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0420 - val_loss: 0.0498
# Epoch 725/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0274 - val_loss: 0.0523
# Epoch 726/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0221 - val_loss: 0.0525
# Epoch 727/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0309 - val_loss: 0.0507
# Epoch 728/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0272 - val_loss: 0.0489
# Epoch 729/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0233 - val_loss: 0.0508
# Epoch 730/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0247 - val_loss: 0.0526
# Epoch 731/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0272 - val_loss: 0.0527
# Epoch 732/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0279 - val_loss: 0.0530
# Epoch 733/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0326 - val_loss: 0.0569
# Epoch 734/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0232 - val_loss: 0.0586
# Epoch 735/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0267 - val_loss: 0.0582
# Epoch 736/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0231 - val_loss: 0.0587
# Epoch 737/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0291 - val_loss: 0.0622
# Epoch 738/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0509 - val_loss: 0.0692
# Epoch 739/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0372 - val_loss: 0.0625
# Epoch 740/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0347 - val_loss: 0.0538
# Epoch 741/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0302 - val_loss: 0.0497
# Epoch 742/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0310 - val_loss: 0.0463
# Epoch 743/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0450 - val_loss: 0.0436
# Epoch 744/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0333 - val_loss: 0.0409
# Epoch 745/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0213 - val_loss: 0.0416
# Epoch 746/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0284 - val_loss: 0.0431
# Epoch 747/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0375 - val_loss: 0.0497
# Epoch 748/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0343 - val_loss: 0.0632
# Epoch 749/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0287 - val_loss: 0.0548
# Epoch 750/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0329 - val_loss: 0.0461
# Epoch 751/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0381 - val_loss: 0.0456
# Epoch 752/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0294 - val_loss: 0.0476
# Epoch 753/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0355 - val_loss: 0.0464
# Epoch 754/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0260 - val_loss: 0.0538
# Epoch 755/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0448 - val_loss: 0.0694
# Epoch 756/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0369 - val_loss: 0.0877
# Epoch 757/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0220 - val_loss: 0.0921
# Epoch 758/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0529 - val_loss: 0.0847
# Epoch 759/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0184 - val_loss: 0.0808
# Epoch 760/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0234 - val_loss: 0.0768
# Epoch 761/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0296 - val_loss: 0.0662
# Epoch 762/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0246 - val_loss: 0.0591
# Epoch 763/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0289 - val_loss: 0.0525
# Epoch 764/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0274 - val_loss: 0.0452
# Epoch 765/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0436 - val_loss: 0.0564
# Epoch 766/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0381 - val_loss: 0.0673
# Epoch 767/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0415 - val_loss: 0.0721
# Epoch 768/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0298 - val_loss: 0.0653
# Epoch 769/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0362 - val_loss: 0.0593
# Epoch 770/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0184 - val_loss: 0.0572
# Epoch 771/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0292 - val_loss: 0.0581
# Epoch 772/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0280 - val_loss: 0.0617
# Epoch 773/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0212 - val_loss: 0.0603
# Epoch 774/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0432 - val_loss: 0.0535
# Epoch 775/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0355 - val_loss: 0.0453
# Epoch 776/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0269 - val_loss: 0.0413
# Epoch 777/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0276 - val_loss: 0.0477
# Epoch 778/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0381 - val_loss: 0.0570
# Epoch 779/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0235 - val_loss: 0.0557
# Epoch 780/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0312 - val_loss: 0.0517
# Epoch 781/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0342 - val_loss: 0.0488
# Epoch 782/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0281 - val_loss: 0.0539
# Epoch 783/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0399 - val_loss: 0.0620
# Epoch 784/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0308 - val_loss: 0.0422
# Epoch 785/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0505 - val_loss: 0.0437
# Epoch 786/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0391 - val_loss: 0.0526
# Epoch 787/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0326 - val_loss: 0.0659
# Epoch 788/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0336 - val_loss: 0.0707
# Epoch 789/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0299 - val_loss: 0.0766
# Epoch 790/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0438 - val_loss: 0.0726
# Epoch 791/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0544 - val_loss: 0.0637
# Epoch 792/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0460 - val_loss: 0.0625
# Epoch 793/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0306 - val_loss: 0.0609
# Epoch 794/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0310 - val_loss: 0.0616
# Epoch 795/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0306 - val_loss: 0.0684
# Epoch 796/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0274 - val_loss: 0.0709
# Epoch 797/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0303 - val_loss: 0.0670
# Epoch 798/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0309 - val_loss: 0.0656
# Epoch 799/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0330 - val_loss: 0.0715
# Epoch 800/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0379 - val_loss: 0.0658
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step

# %%
################# Datos para stackingregressor #################


# Características temporales enriquecidas

df['Rolling_Mean_8_B-'] = df['B-'].rolling(8).mean()
df['Rolling_STD_4_B-'] = df['B-'].rolling(4).std()
df['Diff_1_B-'] = df['B-'].diff(1)


# Eliminar nulos generados por los lags/rolling
df.dropna(inplace=True)
# Definir features y target para stackingregressor
features_stk = [col for col in df.columns if col.startswith('Lag_B-') or 'Rolling_Mean_8_B-' in col or 'Rolling_STD_4_B-' in col or 'Diff_1_B-' in col or col in ['Week', 'Month','Quarter']]

X_stk = df[features_stk]
y = df[target]

scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X_stk)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1)).flatten()
X_scaled = pd.DataFrame(X_scaled, columns=X_stk.columns)
X_train_stk, X_test_stk, y_train_stk, y_test_stk = train_test_split(X_scaled, y_scaled, shuffle=False, test_size=0.2)

# %%
# StackingRegressor

modelo_stk = entrenar_stacking(X_train_stk, y_train_stk)
y_pred_stk = modelo_stk.predict(X_test_stk)
y_pred_stk = scaler_y.inverse_transform(y_pred_stk.reshape(-1, 1))
y_real_stk = scaler_y.inverse_transform(y_test_stk.reshape(-1, 1))

# %%
# ------------------------- MÉTRICAS PARA B- -------------------------

print("* MÉTRICAS LSTM PARA B-")
print(f"MAE: {mean_absolute_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"RMSE: {mean_squared_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"R²: {r2_score(y_real_lstm, y_pred_lstm):.2f}")

print("\n* MÉTRICAS STACKING PARA B-")
print(f"MAE: {mean_absolute_error(y_real_stk, y_pred_stk):.2f}")
print(f"RMSE: {mean_squared_error(y_real_stk, y_pred_stk):.2f}")
print(f"R²: {r2_score(y_real_stk, y_pred_stk):.2f}")
# Out:
# * MÉTRICAS LSTM PARA B-
# MAE: 0.46
# RMSE: 0.28
# R²: 0.84
#
# * MÉTRICAS STACKING PARA B-
# MAE: 0.23
# RMSE: 0.08
# R²: 0.94

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_real_stk), len(y_pred_stk))

# Convertir todo a 1D por seguridad
y_test_plot = y_test[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_real_plot = y_real_lstm[:min_len].reshape(-1)

# Plot
plt.figure(figsize=(12, 5))
plt.plot(np.arange(min_len), y_real_stk[:min_len], label="Real", color='black')
plt.plot(np.arange(min_len), y_pred_stk[:min_len], label="StackingRegressor", linestyle='--')
plt.plot(np.arange(min_len), y_pred_lstm[:min_len], label="LSTM", linestyle=':')
plt.title("Comparación de Predicciones: LSTM vs StackingRegressor (Demanda B-)")
plt.xlabel("Semanas")
plt.ylabel("Demanda")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_pred_stk))
y_real_plot = y_real_lstm[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
fig.suptitle("Comparación de Series y Análisis ACF/PACF", fontsize=16)

# Serie real
axes[0, 0].plot(y_real_plot, color='black')
axes[0, 0].set_title("Serie real B- ")
axes[0, 0].grid(True)

# ACF real
plot_acf(y_real_plot, lags=min(20, len(y_real_plot)//2 - 1), ax=axes[0, 1])
axes[0, 1].set_title("ACF B- - Real")

# LSTM predicción
axes[1, 0].plot(y_pred_lstm_plot, color='blue')
axes[1, 0].set_title("Predicción B-  LSTM")
axes[1, 0].grid(True)

# ACF LSTM
plot_acf(y_pred_lstm_plot, lags=min(20, len(y_pred_lstm_plot)//2 - 1), ax=axes[1, 1])
axes[1, 1].set_title("ACF B-  - LSTM")

# Stacking predicción
axes[2, 0].plot(y_pred_stk_plot, color='green')
axes[2, 0].set_title("Predicción B-  Stacking")
axes[2, 0].grid(True)

# ACF Stacking
plot_acf(y_pred_stk_plot, lags=min(20, len(y_pred_stk_plot)//2 - 1), ax=axes[2, 1])
axes[2, 1].set_title("ACF B-  - Stacking")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig("comparativa_modelos_acf.png", dpi=300)
plt.show()
