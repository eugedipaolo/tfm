# %%
# ------------------------- IMPORTACIONES -------------------------
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('HDHI Admission data.csv', sep=',')

# %%
# Fechas convertidas a datetime
df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
df['D.O.A'] = df['D.O.A_manual']
df.drop(columns='D.O.A_manual', inplace=True)

# Verificar cuántas fechas nulas hay en cada una
nulos_doa = df['D.O.A'].isna().sum()

# Rango de fechas disponibles
min_doa = df['D.O.A'].min()
max_doa = df['D.O.A'].max()

duration_col = 'DURATION OF STAY'

# Ver estadísticas generales
duration_stats = df[duration_col].describe()

# Verificar valores negativos o inconsistentes
invalid_duration = df[df[duration_col] < 0]

duration_stats, invalid_duration.shape[0]
# Out:
# /var/folders/tm/_mcsvvpd5ml8xhw8l_7314j80000gn/T/ipykernel_48365/1322510359.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['D.O.A_manual'] = df['D.O.A'].apply(lambda x: pd.to_datetime(x, errors='coerce', dayfirst=False))
# (count    15757.000000
#  mean         6.415054
#  std          5.011421
#  min          1.000000
#  25%          3.000000
#  50%          5.000000
#  75%          8.000000
#  max         98.000000
#  Name: DURATION OF STAY, dtype: float64,
#  0)

# %%
df = df.sort_values(by='D.O.A')

# %%
df['HB'] = pd.to_numeric(df['HB'], errors='coerce')
conteo = (df['HB'] < 9).sum()

print(f"Número de registros con HB < 9: {conteo}")
# Out:
# Número de registros con HB < 9: 1339

# %%
# Convertir columnas relevantes a numérico, manejando valores no numéricos
numeric_cols = ['HB', 'DURATION OF STAY', 'duration of intensive unit stay', 'CREATININE', 'UREA', 'PLATELETS', 'BNP', 'EF']
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Crear la variable proxy para transfusión
def create_transfusion_proxy(row):
    # Criterio principal: Hemoglobina baja (<8 g/dL) o anemia severa
    hb_condition = row['HB'] < 8 if pd.notna(row['HB']) else False
    severe_anemia_condition = row['SEVERE ANAEMIA'] == 1 if 'SEVERE ANAEMIA' in row else False
    
    # condiciones de gravedad que podrían requerir transfusión
    cva_bleed = row['CVA BLEED'] == 1 if 'CVA BLEED' in row else False
    stemi = row['STEMI'] == 1 if 'STEMI' in row else False
    cardiogenic_shock = row['CARDIOGENIC SHOCK'] == 1 if 'CARDIOGENIC SHOCK' in row else False
    shock = row['SHOCK'] == 1 if 'SHOCK' in row else False
    pulmonary_embolism = row['PULMONARY EMBOLISM'] == 1 if 'PULMONARY EMBOLISM' in row else False
    ckd = row['CKD'] == 1 if 'CKD' in row else False
    emergencia = row['TYPE OF ADMISSION-EMERGENCY/OPD']=='E' if 'TYPE OF ADMISSION-EMERGENCY/OPD' in row else False
    
    # Duración de la estancia (>7 días) o estancia en UCI (>1 días)
    long_stay = row['DURATION OF STAY'] > 7 if pd.notna(row['DURATION OF STAY']) else False
    icu_stay = row['duration of intensive unit stay'] > 1 if pd.notna(row['duration of intensive unit stay']) else False
    
    # Lógica para la variable proxy:
    # Necesita transfusión si:
    # HB < 9 o SEVERE ANAEMIA == 1
    # si hay condiciones graves (CVA BLEED, STEMI, SHOCK) con HB < 10
    # si hay CKD con HB < 9
    if (hb_condition or severe_anemia_condition or
        (row['HB'] < 10 and pd.notna(row['HB']) and (cva_bleed or stemi or cardiogenic_shock or shock or pulmonary_embolism)) or
        (ckd and row['HB'] < 9 and pd.notna(row['HB'])) or 
        (emergencia) or
        (long_stay and icu_stay and row['HB'] < 10 and pd.notna(row['HB']))):
        return 1
    return 0

# Aplicar la función para crear la columna 'needs_transfusion'
df['needs_transfusion'] = df.apply(create_transfusion_proxy, axis=1)

# %%
# Asignar Blood Type
np.random.seed(42)

# Asignar tipos de sangre con distribución ajustada para India
blood_types = ['A+', 'A-', 'B+', 'B-', 'O+', 'O-', 'AB+', 'AB-']
probabilities = [0.21, 0.02, 0.33, 0.02, 0.32, 0.02, 0.07, 0.01]

         
df['Blood Type'] = np.random.choice(blood_types, size=len(df), p=probabilities)

# Verificar la distribución de los tipos de sangre generados
print("Distribución de tipos de sangre en el dataset (%):")
print(df['Blood Type'].value_counts(normalize=True).sort_index() * 100)
# Out:
# Distribución de tipos de sangre en el dataset (%):
# Blood Type
# A+     21.349242
# A-      1.980072
# AB+     7.044488
# AB-     0.913880
# B+     33.375643
# B-      1.935648
# O+     31.611347
# O-      1.789681
# Name: proportion, dtype: float64

# %%
# Elimino variables para trabajar con un conjunto de datos con los datos relevantes para este trabajo
cols_utiles = ['D.O.A', 'DURATION OF STAY', 'needs_transfusion', 'Blood Type']

# Filtrar el DataFrame conservando solo esas columnas
df = df[cols_utiles].copy()

# %%
# Ahora realizaré un análisis para saber que tipo de comportamiento tiene needs_transfusion en el tiempo
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Función para seleccionar rango denso de fechas
def detectar_rango_denso(df_org, date_col='D.O.A', min_por_semana=10, buffer_semanas=2):
    df_tmp = df_org.copy()
    df_tmp[date_col] = pd.to_datetime(df_tmp[date_col], errors='coerce')
    weekly_counts = df_tmp.groupby(df_tmp[date_col].dt.to_period('W').apply(lambda r: r.start_time)).size()
    weeks_valid = weekly_counts[weekly_counts >= min_por_semana]
    if weeks_valid.empty:
        return None  # No hay rango denso suficiente
    start = weeks_valid.index.min() - pd.Timedelta(weeks=buffer_semanas)
    end = weeks_valid.index.max() + pd.Timedelta(weeks=buffer_semanas)
    return start, end

rango = detectar_rango_denso(df, min_por_semana=20)

# Aplicar filtro al dataframe original si hay rango válido
if rango:
    df_filtrado = df[
        (df['D.O.A'] > rango[0]) &
        (df['D.O.A'] <= rango[1])
    ]
else:
    df_filtrado = pd.DataFrame()  # sin datos útiles

df = df_filtrado.copy()
weekly_transfusions = (
    df[df['needs_transfusion'] == 1]
    .groupby(df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time))['needs_transfusion']
    .count()
    .reset_index(name='weekly_count')
)

weekly_transfusions['D.O.A'] = pd.to_datetime(weekly_transfusions['D.O.A'])

# %%
# Agrupo por semana y tipo de sangre
df = df[df['needs_transfusion'] == 1]
weekly_demand = df.groupby([df['D.O.A'].dt.to_period('W').apply(lambda r: r.start_time), 'Blood Type'])['needs_transfusion'].sum().unstack().fillna(0)

# %%
serie = weekly_demand['B+']
adf_result = adfuller(serie)

# Graficar ACF y PACF
fig, axes = plt.subplots(2, 1, figsize=(10, 8))
plot_acf(serie, lags=20, ax=axes[0])
axes[0].set_title("ACF - B+")

plot_pacf(serie, lags=20, ax=axes[1], method='ywm')
axes[1].set_title("PACF - B+")

plt.tight_layout()
plt.show()

# Resultado ADF
adf_output = {
    "ADF Statistic": adf_result[0],
    "p-value": adf_result[1],
    "Lags Used": adf_result[2],
    "Observations": adf_result[3],
    "Critical Values": adf_result[4]
}

adf_output
# Out:
# {'ADF Statistic': -2.31662842905409,
#  'p-value': 0.16666104286362532,
#  'Lags Used': 3,
#  'Observations': 114,
#  'Critical Values': {'1%': -3.489057523907491,
#   '5%': -2.887246327182993,
#   '10%': -2.5804808802708528}}

# %%
# ------------------------- MODELO LSTM -------------------------

    
def entrenar_lstm(X_lstm, y_lstm, epochs=800):
    model = Sequential([
        LSTM(128, activation='tanh', return_sequences=True, input_shape=(X_lstm.shape[1], 1)),
        BatchNormalization(),
        Dropout(0.3),
        
        LSTM(64, activation='tanh', return_sequences=True),
        BatchNormalization(),
        Dropout(0.3),

        LSTM(32, activation='tanh'),
        Dropout(0.3),
        
        Dense(64, activation='relu'),
        Dense(1)  # Última capa sin activación porque es una regresión
        ])
    learning_rate = 0.001 
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss=MeanSquaredError(),
      
    )
    
   
    history = model.fit(
        X_lstm, y_lstm,
        epochs=epochs,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )
  
    return model, history


# ------------------------- STACKING REGRESSOR -------------------------

def entrenar_stacking(X_train, y_train):
    
    estimators = [
       ('xgb', XGBRegressor(max_depth=3, n_estimators=300, learning_rate=0.07, random_state=42, verbosity=0)),
        ('lgb', LGBMRegressor(max_depth=3, n_estimators=300, learning_rate=0.06, random_state=42, verbose=-1)),
        ('cat', CatBoostRegressor(depth=3, iterations=300, learning_rate=0.06, random_state=42, verbose=False))
    ]
    modelo_ensamble = StackingRegressor(
            estimators=estimators,
            final_estimator=Ridge(alpha=1.0),
            n_jobs=-1
        )
    modelo_ensamble.fit(X_train, y_train.ravel())
    return modelo_ensamble

# %%
weekly_demand['Lag_B+_1'] = serie.shift(1)
weekly_demand['Lag_B+_2'] = serie.shift(2)
weekly_demand['Lag_B+_3'] = serie.shift(3)
weekly_demand['Lag_B+_4'] = serie.shift(4)
weekly_demand['Rolling_Mean_4_B+'] = serie.rolling(window=4).mean()
weekly_demand['Rolling_Mean_8_B+'] = serie.rolling(window=8).mean()
weekly_demand['Rolling_STD_4_B+'] = serie.rolling(window=4).std()
weekly_demand['Diff_1_B+'] = serie.diff(1)

df = weekly_demand.copy()
df['Lag_B+_1'] = df['B+'].shift(1)
df['Lag_B+_2'] = df['B+'].shift(2)
df['Lag_B+_3'] = df['B+'].shift(3)
df['Lag_B+_4'] = df['B+'].shift(4)
df['Rolling_Mean_4_B+'] = df['B+'].rolling(window=4).mean()

df.columns.values[0] = 'Date'
df = df.reset_index()
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

df['Week'] = df['Date'].dt.isocalendar().week
df['Month'] = df['Date'].dt.month
df['Quarter'] = df['Date'].dt.quarter
df.dropna(inplace=True)

# %%
################# Datos para LSTM B+ ################# 

features = ['Lag_B+_1', 'Lag_B+_2', 'Lag_B+_3', 'Lag_B+_4', 'Rolling_Mean_4_B+']
target = 'B+'
X = df[features]
y = df[[target]]

# Escalado robusto
from sklearn.preprocessing import RobustScaler
scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Separo entrenamiento y test (sin barajar porque es una serie temporal)
split_index = int(len(X_scaled) * 0.8)
X_train = X_scaled[:split_index]
X_test = X_scaled[split_index:]
y_lstm = y_scaled[:split_index]
y_test = y_scaled[split_index:]

# Reformatear para LSTM
X_lstm = X_train.reshape((X_train.shape[0], len(features), 1))
X_test_lstm = X_test.reshape((X_test.shape[0], len(features), 1))

# %%
# LSTM

modelo_lstm, history = entrenar_lstm(X_lstm, y_lstm)
y_pred_lstm = modelo_lstm.predict(X_test_lstm)

# Desescalar
y_pred_lstm = scaler_y.inverse_transform(y_pred_lstm)
y_real_lstm = scaler_y.inverse_transform(y_test)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 379ms/step - loss: 0.4682 - val_loss: 0.4577
# Epoch 2/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3461 - val_loss: 0.4586
# Epoch 3/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4702 - val_loss: 0.4606
# Epoch 4/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4345 - val_loss: 0.4628
# Epoch 5/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3921 - val_loss: 0.4644
# Epoch 6/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3955 - val_loss: 0.4650
# Epoch 7/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3457 - val_loss: 0.4652
# Epoch 8/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3863 - val_loss: 0.4654
# Epoch 9/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3980 - val_loss: 0.4655
# Epoch 10/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3735 - val_loss: 0.4647
# Epoch 11/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3978 - val_loss: 0.4640
# Epoch 12/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3365 - val_loss: 0.4639
# Epoch 13/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3571 - val_loss: 0.4637
# Epoch 14/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3969 - val_loss: 0.4645
# Epoch 15/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3874 - val_loss: 0.4654
# Epoch 16/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3760 - val_loss: 0.4662
# Epoch 17/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3522 - val_loss: 0.4657
# Epoch 18/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3242 - val_loss: 0.4650
# Epoch 19/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3635 - val_loss: 0.4657
# Epoch 20/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3780 - val_loss: 0.4669
# Epoch 21/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3645 - val_loss: 0.4680
# Epoch 22/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3267 - val_loss: 0.4681
# Epoch 23/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3494 - val_loss: 0.4676
# Epoch 24/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3309 - val_loss: 0.4670
# Epoch 25/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2752 - val_loss: 0.4666
# Epoch 26/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2972 - val_loss: 0.4666
# Epoch 27/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3331 - val_loss: 0.4678
# Epoch 28/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2720 - val_loss: 0.4678
# Epoch 29/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3276 - val_loss: 0.4663
# Epoch 30/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2731 - val_loss: 0.4659
# Epoch 31/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2650 - val_loss: 0.4659
# Epoch 32/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3109 - val_loss: 0.4648
# Epoch 33/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2949 - val_loss: 0.4644
# Epoch 34/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3237 - val_loss: 0.4641
# Epoch 35/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2883 - val_loss: 0.4630
# Epoch 36/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2698 - val_loss: 0.4618
# Epoch 37/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2901 - val_loss: 0.4620
# Epoch 38/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3157 - val_loss: 0.4622
# Epoch 39/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2275 - val_loss: 0.4617
# Epoch 40/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2328 - val_loss: 0.4609
# Epoch 41/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2118 - val_loss: 0.4622
# Epoch 42/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2624 - val_loss: 0.4650
# Epoch 43/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2578 - val_loss: 0.4667
# Epoch 44/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2039 - val_loss: 0.4675
# Epoch 45/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2140 - val_loss: 0.4688
# Epoch 46/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1985 - val_loss: 0.4699
# Epoch 47/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2475 - val_loss: 0.4680
# Epoch 48/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2427 - val_loss: 0.4673
# Epoch 49/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2237 - val_loss: 0.4676
# Epoch 50/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1633 - val_loss: 0.4699
# Epoch 51/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2001 - val_loss: 0.4738
# Epoch 52/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1829 - val_loss: 0.4790
# Epoch 53/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2021 - val_loss: 0.4814
# Epoch 54/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1836 - val_loss: 0.4779
# Epoch 55/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2058 - val_loss: 0.4738
# Epoch 56/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1944 - val_loss: 0.4690
# Epoch 57/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1521 - val_loss: 0.4645
# Epoch 58/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1723 - val_loss: 0.4624
# Epoch 59/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1691 - val_loss: 0.4618
# Epoch 60/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1420 - val_loss: 0.4639
# Epoch 61/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1097 - val_loss: 0.4678
# Epoch 62/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1119 - val_loss: 0.4699
# Epoch 63/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1781 - val_loss: 0.4708
# Epoch 64/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1140 - val_loss: 0.4655
# Epoch 65/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1392 - val_loss: 0.4585
# Epoch 66/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1431 - val_loss: 0.4564
# Epoch 67/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1227 - val_loss: 0.4573
# Epoch 68/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1231 - val_loss: 0.4582
# Epoch 69/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1339 - val_loss: 0.4584
# Epoch 70/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1171 - val_loss: 0.4575
# Epoch 71/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1277 - val_loss: 0.4559
# Epoch 72/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1186 - val_loss: 0.4538
# Epoch 73/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1063 - val_loss: 0.4526
# Epoch 74/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0989 - val_loss: 0.4515
# Epoch 75/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1035 - val_loss: 0.4511
# Epoch 76/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0678 - val_loss: 0.4521
# Epoch 77/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1486 - val_loss: 0.4526
# Epoch 78/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1078 - val_loss: 0.4505
# Epoch 79/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0886 - val_loss: 0.4481
# Epoch 80/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0932 - val_loss: 0.4473
# Epoch 81/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0765 - val_loss: 0.4478
# Epoch 82/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0621 - val_loss: 0.4491
# Epoch 83/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1000 - val_loss: 0.4478
# Epoch 84/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0986 - val_loss: 0.4442
# Epoch 85/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0858 - val_loss: 0.4416
# Epoch 86/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0607 - val_loss: 0.4412
# Epoch 87/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0900 - val_loss: 0.4447
# Epoch 88/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0628 - val_loss: 0.4508
# Epoch 89/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0895 - val_loss: 0.4548
# Epoch 90/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0860 - val_loss: 0.4537
# Epoch 91/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1272 - val_loss: 0.4451
# Epoch 92/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0948 - val_loss: 0.4346
# Epoch 93/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0784 - val_loss: 0.4235
# Epoch 94/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0654 - val_loss: 0.4157
# Epoch 95/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1123 - val_loss: 0.4123
# Epoch 96/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1032 - val_loss: 0.4111
# Epoch 97/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0828 - val_loss: 0.4105
# Epoch 98/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0765 - val_loss: 0.4086
# Epoch 99/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0804 - val_loss: 0.4079
# Epoch 100/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0920 - val_loss: 0.4116
# Epoch 101/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0786 - val_loss: 0.4132
# Epoch 102/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0682 - val_loss: 0.4078
# Epoch 103/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0636 - val_loss: 0.4008
# Epoch 104/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0765 - val_loss: 0.3941
# Epoch 105/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0969 - val_loss: 0.3878
# Epoch 106/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0801 - val_loss: 0.3832
# Epoch 107/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1029 - val_loss: 0.3816
# Epoch 108/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0930 - val_loss: 0.3815
# Epoch 109/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0641 - val_loss: 0.3804
# Epoch 110/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0647 - val_loss: 0.3770
# Epoch 111/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1007 - val_loss: 0.3766
# Epoch 112/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0697 - val_loss: 0.3755
# Epoch 113/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0517 - val_loss: 0.3739
# Epoch 114/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0981 - val_loss: 0.3700
# Epoch 115/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0547 - val_loss: 0.3674
# Epoch 116/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0635 - val_loss: 0.3628
# Epoch 117/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0588 - val_loss: 0.3556
# Epoch 118/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0824 - val_loss: 0.3460
# Epoch 119/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0620 - val_loss: 0.3402
# Epoch 120/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0545 - val_loss: 0.3399
# Epoch 121/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0661 - val_loss: 0.3444
# Epoch 122/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0774 - val_loss: 0.3555
# Epoch 123/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0572 - val_loss: 0.3573
# Epoch 124/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0677 - val_loss: 0.3520
# Epoch 125/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0691 - val_loss: 0.3491
# Epoch 126/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0597 - val_loss: 0.3512
# Epoch 127/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0749 - val_loss: 0.3569
# Epoch 128/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0901 - val_loss: 0.3534
# Epoch 129/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0629 - val_loss: 0.3464
# Epoch 130/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0655 - val_loss: 0.3435
# Epoch 131/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0641 - val_loss: 0.3429
# Epoch 132/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0714 - val_loss: 0.3298
# Epoch 133/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0611 - val_loss: 0.3175
# Epoch 134/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0586 - val_loss: 0.3084
# Epoch 135/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0765 - val_loss: 0.3008
# Epoch 136/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0548 - val_loss: 0.2957
# Epoch 137/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0501 - val_loss: 0.2935
# Epoch 138/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0631 - val_loss: 0.2948
# Epoch 139/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0524 - val_loss: 0.3001
# Epoch 140/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0583 - val_loss: 0.3059
# Epoch 141/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0731 - val_loss: 0.3116
# Epoch 142/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0730 - val_loss: 0.3055
# Epoch 143/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0480 - val_loss: 0.2914
# Epoch 144/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0766 - val_loss: 0.2789
# Epoch 145/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0532 - val_loss: 0.2709
# Epoch 146/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0734 - val_loss: 0.2686
# Epoch 147/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0471 - val_loss: 0.2708
# Epoch 148/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0556 - val_loss: 0.2702
# Epoch 149/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0588 - val_loss: 0.2719
# Epoch 150/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0601 - val_loss: 0.2719
# Epoch 151/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0686 - val_loss: 0.2702
# Epoch 152/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0605 - val_loss: 0.2654
# Epoch 153/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0378 - val_loss: 0.2679
# Epoch 154/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0441 - val_loss: 0.2758
# Epoch 155/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0401 - val_loss: 0.2959
# Epoch 156/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0493 - val_loss: 0.3041
# Epoch 157/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0408 - val_loss: 0.2980
# Epoch 158/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0499 - val_loss: 0.2861
# Epoch 159/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0735 - val_loss: 0.2603
# Epoch 160/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0525 - val_loss: 0.2371
# Epoch 161/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0796 - val_loss: 0.2320
# Epoch 162/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0733 - val_loss: 0.2281
# Epoch 163/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0506 - val_loss: 0.2262
# Epoch 164/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0531 - val_loss: 0.2297
# Epoch 165/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0608 - val_loss: 0.2248
# Epoch 166/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0530 - val_loss: 0.2274
# Epoch 167/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0461 - val_loss: 0.2347
# Epoch 168/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0450 - val_loss: 0.2415
# Epoch 169/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0616 - val_loss: 0.2394
# Epoch 170/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0511 - val_loss: 0.2392
# Epoch 171/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0533 - val_loss: 0.2270
# Epoch 172/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0669 - val_loss: 0.2157
# Epoch 173/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0695 - val_loss: 0.2116
# Epoch 174/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0486 - val_loss: 0.2133
# Epoch 175/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0493 - val_loss: 0.2104
# Epoch 176/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0498 - val_loss: 0.2103
# Epoch 177/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0596 - val_loss: 0.2003
# Epoch 178/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0635 - val_loss: 0.1906
# Epoch 179/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0332 - val_loss: 0.1838
# Epoch 180/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0586 - val_loss: 0.1790
# Epoch 181/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0516 - val_loss: 0.1791
# Epoch 182/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0500 - val_loss: 0.1743
# Epoch 183/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0509 - val_loss: 0.1792
# Epoch 184/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0557 - val_loss: 0.1875
# Epoch 185/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0346 - val_loss: 0.1873
# Epoch 186/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0577 - val_loss: 0.1867
# Epoch 187/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0761 - val_loss: 0.1827
# Epoch 188/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0493 - val_loss: 0.1798
# Epoch 189/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0574 - val_loss: 0.1784
# Epoch 190/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0480 - val_loss: 0.1814
# Epoch 191/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0611 - val_loss: 0.1751
# Epoch 192/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0473 - val_loss: 0.1641
# Epoch 193/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0392 - val_loss: 0.1593
# Epoch 194/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0412 - val_loss: 0.1597
# Epoch 195/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0525 - val_loss: 0.1646
# Epoch 196/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0554 - val_loss: 0.1512
# Epoch 197/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0357 - val_loss: 0.1261
# Epoch 198/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0700 - val_loss: 0.1266
# Epoch 199/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0522 - val_loss: 0.1306
# Epoch 200/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0470 - val_loss: 0.1244
# Epoch 201/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0653 - val_loss: 0.1293
# Epoch 202/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0441 - val_loss: 0.1490
# Epoch 203/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0588 - val_loss: 0.1592
# Epoch 204/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0460 - val_loss: 0.1714
# Epoch 205/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0410 - val_loss: 0.1622
# Epoch 206/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0452 - val_loss: 0.1502
# Epoch 207/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0591 - val_loss: 0.1405
# Epoch 208/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0527 - val_loss: 0.1215
# Epoch 209/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0581 - val_loss: 0.1097
# Epoch 210/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0373 - val_loss: 0.1016
# Epoch 211/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0379 - val_loss: 0.0948
# Epoch 212/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0321 - val_loss: 0.0898
# Epoch 213/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0502 - val_loss: 0.0852
# Epoch 214/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0348 - val_loss: 0.0815
# Epoch 215/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0514 - val_loss: 0.0811
# Epoch 216/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0437 - val_loss: 0.0825
# Epoch 217/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0401 - val_loss: 0.0940
# Epoch 218/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0398 - val_loss: 0.1008
# Epoch 219/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0453 - val_loss: 0.0976
# Epoch 220/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0403 - val_loss: 0.0969
# Epoch 221/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0491 - val_loss: 0.0997
# Epoch 222/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0463 - val_loss: 0.1031
# Epoch 223/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0415 - val_loss: 0.1096
# Epoch 224/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0372 - val_loss: 0.1163
# Epoch 225/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0292 - val_loss: 0.1202
# Epoch 226/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0464 - val_loss: 0.1151
# Epoch 227/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0445 - val_loss: 0.1027
# Epoch 228/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0400 - val_loss: 0.0965
# Epoch 229/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0268 - val_loss: 0.0923
# Epoch 230/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0273 - val_loss: 0.0894
# Epoch 231/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0311 - val_loss: 0.0871
# Epoch 232/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0391 - val_loss: 0.0876
# Epoch 233/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0375 - val_loss: 0.0906
# Epoch 234/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0342 - val_loss: 0.0952
# Epoch 235/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0342 - val_loss: 0.0927
# Epoch 236/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0504 - val_loss: 0.0857
# Epoch 237/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0362 - val_loss: 0.0800
# Epoch 238/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0410 - val_loss: 0.0773
# Epoch 239/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0619 - val_loss: 0.0811
# Epoch 240/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0454 - val_loss: 0.0906
# Epoch 241/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0398 - val_loss: 0.0904
# Epoch 242/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0492 - val_loss: 0.0884
# Epoch 243/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0513 - val_loss: 0.0958
# Epoch 244/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0470 - val_loss: 0.1007
# Epoch 245/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0566 - val_loss: 0.0969
# Epoch 246/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0392 - val_loss: 0.0852
# Epoch 247/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0551 - val_loss: 0.0768
# Epoch 248/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0478 - val_loss: 0.0790
# Epoch 249/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0448 - val_loss: 0.0759
# Epoch 250/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0349 - val_loss: 0.0682
# Epoch 251/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0428 - val_loss: 0.0679
# Epoch 252/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0348 - val_loss: 0.0642
# Epoch 253/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0546 - val_loss: 0.0587
# Epoch 254/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0475 - val_loss: 0.0581
# Epoch 255/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0533 - val_loss: 0.0649
# Epoch 256/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0417 - val_loss: 0.0708
# Epoch 257/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0376 - val_loss: 0.0713
# Epoch 258/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0254 - val_loss: 0.0726
# Epoch 259/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0330 - val_loss: 0.0745
# Epoch 260/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0278 - val_loss: 0.0766
# Epoch 261/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0404 - val_loss: 0.0766
# Epoch 262/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0382 - val_loss: 0.0728
# Epoch 263/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0261 - val_loss: 0.0663
# Epoch 264/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0286 - val_loss: 0.0625
# Epoch 265/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0313 - val_loss: 0.0623
# Epoch 266/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0374 - val_loss: 0.0611
# Epoch 267/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0373 - val_loss: 0.0598
# Epoch 268/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0345 - val_loss: 0.1056
# Epoch 269/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0409 - val_loss: 0.1447
# Epoch 270/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0503 - val_loss: 0.1372
# Epoch 271/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0323 - val_loss: 0.0927
# Epoch 272/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0420 - val_loss: 0.0673
# Epoch 273/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0414 - val_loss: 0.0667
# Epoch 274/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0404 - val_loss: 0.0697
# Epoch 275/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0377 - val_loss: 0.0676
# Epoch 276/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0334 - val_loss: 0.0797
# Epoch 277/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0339 - val_loss: 0.0868
# Epoch 278/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0272 - val_loss: 0.0852
# Epoch 279/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0348 - val_loss: 0.0751
# Epoch 280/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0366 - val_loss: 0.0688
# Epoch 281/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0331 - val_loss: 0.0686
# Epoch 282/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0413 - val_loss: 0.0720
# Epoch 283/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0297 - val_loss: 0.0730
# Epoch 284/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0378 - val_loss: 0.0700
# Epoch 285/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0404 - val_loss: 0.0720
# Epoch 286/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0251 - val_loss: 0.0783
# Epoch 287/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0300 - val_loss: 0.0860
# Epoch 288/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0353 - val_loss: 0.0917
# Epoch 289/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0287 - val_loss: 0.0854
# Epoch 290/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0368 - val_loss: 0.0761
# Epoch 291/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0448 - val_loss: 0.0746
# Epoch 292/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0321 - val_loss: 0.0736
# Epoch 293/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0325 - val_loss: 0.0770
# Epoch 294/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0286 - val_loss: 0.0807
# Epoch 295/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0432 - val_loss: 0.0806
# Epoch 296/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0498 - val_loss: 0.0791
# Epoch 297/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0340 - val_loss: 0.0781
# Epoch 298/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0305 - val_loss: 0.0806
# Epoch 299/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0317 - val_loss: 0.0794
# Epoch 300/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0242 - val_loss: 0.0766
# Epoch 301/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0313 - val_loss: 0.0708
# Epoch 302/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0328 - val_loss: 0.0739
# Epoch 303/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0278 - val_loss: 0.0763
# Epoch 304/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0321 - val_loss: 0.0679
# Epoch 305/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0316 - val_loss: 0.0648
# Epoch 306/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0447 - val_loss: 0.0637
# Epoch 307/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0316 - val_loss: 0.0600
# Epoch 308/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0297 - val_loss: 0.0587
# Epoch 309/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0276 - val_loss: 0.0654
# Epoch 310/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0281 - val_loss: 0.0742
# Epoch 311/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0361 - val_loss: 0.0695
# Epoch 312/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0254 - val_loss: 0.0659
# Epoch 313/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0310 - val_loss: 0.0653
# Epoch 314/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0345 - val_loss: 0.0683
# Epoch 315/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0314 - val_loss: 0.0677
# Epoch 316/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0430 - val_loss: 0.0653
# Epoch 317/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0336 - val_loss: 0.0640
# Epoch 318/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0314 - val_loss: 0.0626
# Epoch 319/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0343 - val_loss: 0.0645
# Epoch 320/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0323 - val_loss: 0.0668
# Epoch 321/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0289 - val_loss: 0.0703
# Epoch 322/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0331 - val_loss: 0.0705
# Epoch 323/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0408 - val_loss: 0.0724
# Epoch 324/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0285 - val_loss: 0.0709
# Epoch 325/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0320 - val_loss: 0.0698
# Epoch 326/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0273 - val_loss: 0.0684
# Epoch 327/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0267 - val_loss: 0.0732
# Epoch 328/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0350 - val_loss: 0.0700
# Epoch 329/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0347 - val_loss: 0.0603
# Epoch 330/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0305 - val_loss: 0.0580
# Epoch 331/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0311 - val_loss: 0.0668
# Epoch 332/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0307 - val_loss: 0.0734
# Epoch 333/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0374 - val_loss: 0.0718
# Epoch 334/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0299 - val_loss: 0.0657
# Epoch 335/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0356 - val_loss: 0.0608
# Epoch 336/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0385 - val_loss: 0.0596
# Epoch 337/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0237 - val_loss: 0.0558
# Epoch 338/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0378 - val_loss: 0.0544
# Epoch 339/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0271 - val_loss: 0.0554
# Epoch 340/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0325 - val_loss: 0.0568
# Epoch 341/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0278 - val_loss: 0.0596
# Epoch 342/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0360 - val_loss: 0.0618
# Epoch 343/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0275 - val_loss: 0.0652
# Epoch 344/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0248 - val_loss: 0.0713
# Epoch 345/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0264 - val_loss: 0.0745
# Epoch 346/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0315 - val_loss: 0.0769
# Epoch 347/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0206 - val_loss: 0.0738
# Epoch 348/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0249 - val_loss: 0.0711
# Epoch 349/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0213 - val_loss: 0.0734
# Epoch 350/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0314 - val_loss: 0.0718
# Epoch 351/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0271 - val_loss: 0.0683
# Epoch 352/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0308 - val_loss: 0.0656
# Epoch 353/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0331 - val_loss: 0.0650
# Epoch 354/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0281 - val_loss: 0.0631
# Epoch 355/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0192 - val_loss: 0.0576
# Epoch 356/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0310 - val_loss: 0.0594
# Epoch 357/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0185 - val_loss: 0.0646
# Epoch 358/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0191 - val_loss: 0.0703
# Epoch 359/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0301 - val_loss: 0.0773
# Epoch 360/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0379 - val_loss: 0.0785
# Epoch 361/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0306 - val_loss: 0.0747
# Epoch 362/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0330 - val_loss: 0.0671
# Epoch 363/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0281 - val_loss: 0.0667
# Epoch 364/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0209 - val_loss: 0.0666
# Epoch 365/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0240 - val_loss: 0.0733
# Epoch 366/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0290 - val_loss: 0.0804
# Epoch 367/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0218 - val_loss: 0.0801
# Epoch 368/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0351 - val_loss: 0.0683
# Epoch 369/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0248 - val_loss: 0.0666
# Epoch 370/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0275 - val_loss: 0.0717
# Epoch 371/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0234 - val_loss: 0.0750
# Epoch 372/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0219 - val_loss: 0.0658
# Epoch 373/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0314 - val_loss: 0.0611
# Epoch 374/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0203 - val_loss: 0.0695
# Epoch 375/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0339 - val_loss: 0.0772
# Epoch 376/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0296 - val_loss: 0.0731
# Epoch 377/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0265 - val_loss: 0.0665
# Epoch 378/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0253 - val_loss: 0.0665
# Epoch 379/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0251 - val_loss: 0.0623
# Epoch 380/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0238 - val_loss: 0.0587
# Epoch 381/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0260 - val_loss: 0.0569
# Epoch 382/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0183 - val_loss: 0.0547
# Epoch 383/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0180 - val_loss: 0.0573
# Epoch 384/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0276 - val_loss: 0.0579
# Epoch 385/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0226 - val_loss: 0.0595
# Epoch 386/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0252 - val_loss: 0.0610
# Epoch 387/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0201 - val_loss: 0.0600
# Epoch 388/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0264 - val_loss: 0.0605
# Epoch 389/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0225 - val_loss: 0.0639
# Epoch 390/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0356 - val_loss: 0.0689
# Epoch 391/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0238 - val_loss: 0.0689
# Epoch 392/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0241 - val_loss: 0.0678
# Epoch 393/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0208 - val_loss: 0.0666
# Epoch 394/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0234 - val_loss: 0.0647
# Epoch 395/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0260 - val_loss: 0.0644
# Epoch 396/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0209 - val_loss: 0.0767
# Epoch 397/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0280 - val_loss: 0.0828
# Epoch 398/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0209 - val_loss: 0.0661
# Epoch 399/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0242 - val_loss: 0.0575
# Epoch 400/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0196 - val_loss: 0.0599
# Epoch 401/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0218 - val_loss: 0.0646
# Epoch 402/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0198 - val_loss: 0.0679
# Epoch 403/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0251 - val_loss: 0.0687
# Epoch 404/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0239 - val_loss: 0.0670
# Epoch 405/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0308 - val_loss: 0.0644
# Epoch 406/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0272 - val_loss: 0.0645
# Epoch 407/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0190 - val_loss: 0.0697
# Epoch 408/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0234 - val_loss: 0.0697
# Epoch 409/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0235 - val_loss: 0.0648
# Epoch 410/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0326 - val_loss: 0.0632
# Epoch 411/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0283 - val_loss: 0.0627
# Epoch 412/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0243 - val_loss: 0.0643
# Epoch 413/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0271 - val_loss: 0.0666
# Epoch 414/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0311 - val_loss: 0.0660
# Epoch 415/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0205 - val_loss: 0.0646
# Epoch 416/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0258 - val_loss: 0.0626
# Epoch 417/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0277 - val_loss: 0.0621
# Epoch 418/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0162 - val_loss: 0.0650
# Epoch 419/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0220 - val_loss: 0.0669
# Epoch 420/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0225 - val_loss: 0.0684
# Epoch 421/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0252 - val_loss: 0.0677
# Epoch 422/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0182 - val_loss: 0.0669
# Epoch 423/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0250 - val_loss: 0.0623
# Epoch 424/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0255 - val_loss: 0.0640
# Epoch 425/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0252 - val_loss: 0.0781
# Epoch 426/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0267 - val_loss: 0.1006
# Epoch 427/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0377 - val_loss: 0.0977
# Epoch 428/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0383 - val_loss: 0.0723
# Epoch 429/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0248 - val_loss: 0.0655
# Epoch 430/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0279 - val_loss: 0.0671
# Epoch 431/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0266 - val_loss: 0.0616
# Epoch 432/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0209 - val_loss: 0.0634
# Epoch 433/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0253 - val_loss: 0.0681
# Epoch 434/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0234 - val_loss: 0.0684
# Epoch 435/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0289 - val_loss: 0.0640
# Epoch 436/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0230 - val_loss: 0.0618
# Epoch 437/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0270 - val_loss: 0.0627
# Epoch 438/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0181 - val_loss: 0.0664
# Epoch 439/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0216 - val_loss: 0.0736
# Epoch 440/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0304 - val_loss: 0.0741
# Epoch 441/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0224 - val_loss: 0.0708
# Epoch 442/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0348 - val_loss: 0.0649
# Epoch 443/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0214 - val_loss: 0.0616
# Epoch 444/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0239 - val_loss: 0.0644
# Epoch 445/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0265 - val_loss: 0.0697
# Epoch 446/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0234 - val_loss: 0.0721
# Epoch 447/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0244 - val_loss: 0.0764
# Epoch 448/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0214 - val_loss: 0.0750
# Epoch 449/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0266 - val_loss: 0.0678
# Epoch 450/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0222 - val_loss: 0.0634
# Epoch 451/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0235 - val_loss: 0.0608
# Epoch 452/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0260 - val_loss: 0.0596
# Epoch 453/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0272 - val_loss: 0.0634
# Epoch 454/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0312 - val_loss: 0.0707
# Epoch 455/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0330 - val_loss: 0.0657
# Epoch 456/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0162 - val_loss: 0.0727
# Epoch 457/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0254 - val_loss: 0.0859
# Epoch 458/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0226 - val_loss: 0.0814
# Epoch 459/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0254 - val_loss: 0.0743
# Epoch 460/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0238 - val_loss: 0.1015
# Epoch 461/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0308 - val_loss: 0.1303
# Epoch 462/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0261 - val_loss: 0.1343
# Epoch 463/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0450 - val_loss: 0.0919
# Epoch 464/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0252 - val_loss: 0.0742
# Epoch 465/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0230 - val_loss: 0.0937
# Epoch 466/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0300 - val_loss: 0.1021
# Epoch 467/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0308 - val_loss: 0.0815
# Epoch 468/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0216 - val_loss: 0.0709
# Epoch 469/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0186 - val_loss: 0.0793
# Epoch 470/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0252 - val_loss: 0.0941
# Epoch 471/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0267 - val_loss: 0.1065
# Epoch 472/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0238 - val_loss: 0.1046
# Epoch 473/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0371 - val_loss: 0.0874
# Epoch 474/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0292 - val_loss: 0.0759
# Epoch 475/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0220 - val_loss: 0.0759
# Epoch 476/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0232 - val_loss: 0.0765
# Epoch 477/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0196 - val_loss: 0.0761
# Epoch 478/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0257 - val_loss: 0.0760
# Epoch 479/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0333 - val_loss: 0.0756
# Epoch 480/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0303 - val_loss: 0.0790
# Epoch 481/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0335 - val_loss: 0.0773
# Epoch 482/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0204 - val_loss: 0.0674
# Epoch 483/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0239 - val_loss: 0.0654
# Epoch 484/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0283 - val_loss: 0.0692
# Epoch 485/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0219 - val_loss: 0.0760
# Epoch 486/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0244 - val_loss: 0.0791
# Epoch 487/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0253 - val_loss: 0.0814
# Epoch 488/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0319 - val_loss: 0.0819
# Epoch 489/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0169 - val_loss: 0.0826
# Epoch 490/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0253 - val_loss: 0.0820
# Epoch 491/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0227 - val_loss: 0.0780
# Epoch 492/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0271 - val_loss: 0.0748
# Epoch 493/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0270 - val_loss: 0.0752
# Epoch 494/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0184 - val_loss: 0.0755
# Epoch 495/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0259 - val_loss: 0.0766
# Epoch 496/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0251 - val_loss: 0.0819
# Epoch 497/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0318 - val_loss: 0.0794
# Epoch 498/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0283 - val_loss: 0.0690
# Epoch 499/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0260 - val_loss: 0.0592
# Epoch 500/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0207 - val_loss: 0.0620
# Epoch 501/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0233 - val_loss: 0.0700
# Epoch 502/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0282 - val_loss: 0.0742
# Epoch 503/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0337 - val_loss: 0.0649
# Epoch 504/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0223 - val_loss: 0.0595
# Epoch 505/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0196 - val_loss: 0.0625
# Epoch 506/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0169 - val_loss: 0.0622
# Epoch 507/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0258 - val_loss: 0.0618
# Epoch 508/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0200 - val_loss: 0.0686
# Epoch 509/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0275 - val_loss: 0.0732
# Epoch 510/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0266 - val_loss: 0.0699
# Epoch 511/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0194 - val_loss: 0.0678
# Epoch 512/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0141 - val_loss: 0.0694
# Epoch 513/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0226 - val_loss: 0.0790
# Epoch 514/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0231 - val_loss: 0.0866
# Epoch 515/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0262 - val_loss: 0.0785
# Epoch 516/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0177 - val_loss: 0.0699
# Epoch 517/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0212 - val_loss: 0.0672
# Epoch 518/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0163 - val_loss: 0.0649
# Epoch 519/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0197 - val_loss: 0.0622
# Epoch 520/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0188 - val_loss: 0.0615
# Epoch 521/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0193 - val_loss: 0.0618
# Epoch 522/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0157 - val_loss: 0.0635
# Epoch 523/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0244 - val_loss: 0.0660
# Epoch 524/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0186 - val_loss: 0.0662
# Epoch 525/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0153 - val_loss: 0.0678
# Epoch 526/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0188 - val_loss: 0.0691
# Epoch 527/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0308 - val_loss: 0.0689
# Epoch 528/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0224 - val_loss: 0.0679
# Epoch 529/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0194 - val_loss: 0.0662
# Epoch 530/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0170 - val_loss: 0.0640
# Epoch 531/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0231 - val_loss: 0.0627
# Epoch 532/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0180 - val_loss: 0.0652
# Epoch 533/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0166 - val_loss: 0.0661
# Epoch 534/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0287 - val_loss: 0.0677
# Epoch 535/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0130 - val_loss: 0.0704
# Epoch 536/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0208 - val_loss: 0.0719
# Epoch 537/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0214 - val_loss: 0.0761
# Epoch 538/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0134 - val_loss: 0.0751
# Epoch 539/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0208 - val_loss: 0.0712
# Epoch 540/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0177 - val_loss: 0.0708
# Epoch 541/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0182 - val_loss: 0.0708
# Epoch 542/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0211 - val_loss: 0.0667
# Epoch 543/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0248 - val_loss: 0.0642
# Epoch 544/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0164 - val_loss: 0.0663
# Epoch 545/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0175 - val_loss: 0.0692
# Epoch 546/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0215 - val_loss: 0.0713
# Epoch 547/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0247 - val_loss: 0.0704
# Epoch 548/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0252 - val_loss: 0.0738
# Epoch 549/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0259 - val_loss: 0.0855
# Epoch 550/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0286 - val_loss: 0.0844
# Epoch 551/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0263 - val_loss: 0.0810
# Epoch 552/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0216 - val_loss: 0.0673
# Epoch 553/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0258 - val_loss: 0.0776
# Epoch 554/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0174 - val_loss: 0.0847
# Epoch 555/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0288 - val_loss: 0.0731
# Epoch 556/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0234 - val_loss: 0.0755
# ...
# Epoch 616/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0174 - val_loss: 0.0745
# Epoch 617/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0156 - val_loss: 0.0756
# Epoch 618/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0212 - val_loss: 0.0738
# Epoch 619/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0119 - val_loss: 0.0769
# Epoch 620/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0189 - val_loss: 0.0790
# Epoch 621/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0183 - val_loss: 0.0872
# Epoch 622/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0223 - val_loss: 0.1095
# Epoch 623/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0308 - val_loss: 0.1023
# Epoch 624/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0190 - val_loss: 0.0866
# Epoch 625/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0229 - val_loss: 0.0798
# Epoch 626/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0150 - val_loss: 0.0798
# Epoch 627/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0219 - val_loss: 0.0759
# Epoch 628/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0149 - val_loss: 0.0711
# Epoch 629/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0245 - val_loss: 0.0679
# Epoch 630/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0239 - val_loss: 0.0660
# Epoch 631/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0281 - val_loss: 0.0690
# Epoch 632/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0156 - val_loss: 0.0702
# Epoch 633/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0251 - val_loss: 0.0677
# Epoch 634/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0184 - val_loss: 0.0696
# Epoch 635/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0208 - val_loss: 0.0695
# Epoch 636/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0193 - val_loss: 0.0675
# Epoch 637/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0257 - val_loss: 0.0699
# Epoch 638/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0182 - val_loss: 0.0727
# Epoch 639/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0193 - val_loss: 0.0764
# Epoch 640/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0178 - val_loss: 0.0793
# Epoch 641/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0125 - val_loss: 0.0776
# Epoch 642/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0182 - val_loss: 0.0717
# Epoch 643/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0159 - val_loss: 0.0676
# Epoch 644/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0244 - val_loss: 0.0714
# Epoch 645/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0150 - val_loss: 0.0708
# Epoch 646/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0191 - val_loss: 0.0691
# Epoch 647/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0203 - val_loss: 0.0677
# Epoch 648/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0143 - val_loss: 0.0658
# Epoch 649/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0151 - val_loss: 0.0651
# Epoch 650/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0161 - val_loss: 0.0656
# Epoch 651/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0167 - val_loss: 0.0652
# Epoch 652/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0172 - val_loss: 0.0642
# Epoch 653/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0154 - val_loss: 0.0656
# Epoch 654/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0198 - val_loss: 0.0665
# Epoch 655/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0226 - val_loss: 0.0683
# Epoch 656/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0198 - val_loss: 0.0702
# Epoch 657/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0157 - val_loss: 0.0727
# Epoch 658/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0186 - val_loss: 0.0725
# Epoch 659/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0193 - val_loss: 0.0709
# Epoch 660/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0157 - val_loss: 0.0661
# Epoch 661/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0129 - val_loss: 0.0649
# Epoch 662/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0179 - val_loss: 0.0673
# Epoch 663/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0190 - val_loss: 0.0725
# Epoch 664/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0108 - val_loss: 0.0760
# Epoch 665/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0193 - val_loss: 0.0749
# Epoch 666/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0177 - val_loss: 0.0745
# Epoch 667/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0184 - val_loss: 0.0749
# Epoch 668/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0158 - val_loss: 0.0802
# Epoch 669/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0257 - val_loss: 0.0818
# Epoch 670/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0224 - val_loss: 0.0756
# Epoch 671/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0212 - val_loss: 0.0687
# Epoch 672/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0156 - val_loss: 0.0670
# Epoch 673/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0240 - val_loss: 0.0670
# Epoch 674/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0237 - val_loss: 0.0700
# Epoch 675/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0145 - val_loss: 0.0741
# Epoch 676/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0179 - val_loss: 0.0836
# Epoch 677/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0264 - val_loss: 0.0888
# Epoch 678/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0224 - val_loss: 0.0877
# Epoch 679/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0135 - val_loss: 0.0852
# Epoch 680/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0173 - val_loss: 0.0821
# Epoch 681/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0177 - val_loss: 0.0795
# Epoch 682/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0134 - val_loss: 0.0801
# Epoch 683/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0171 - val_loss: 0.0768
# Epoch 684/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0208 - val_loss: 0.0750
# Epoch 685/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0220 - val_loss: 0.0765
# Epoch 686/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0211 - val_loss: 0.0813
# Epoch 687/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0155 - val_loss: 0.0859
# Epoch 688/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0163 - val_loss: 0.0820
# Epoch 689/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0159 - val_loss: 0.0813
# Epoch 690/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0204 - val_loss: 0.0804
# Epoch 691/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0192 - val_loss: 0.0776
# Epoch 692/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0198 - val_loss: 0.0757
# Epoch 693/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0163 - val_loss: 0.0744
# Epoch 694/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0132 - val_loss: 0.0783
# Epoch 695/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0144 - val_loss: 0.0845
# Epoch 696/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0218 - val_loss: 0.0863
# Epoch 697/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0138 - val_loss: 0.0887
# Epoch 698/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0157 - val_loss: 0.0927
# Epoch 699/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0216 - val_loss: 0.0899
# Epoch 700/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0212 - val_loss: 0.0777
# Epoch 701/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0143 - val_loss: 0.0727
# Epoch 702/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0137 - val_loss: 0.0711
# Epoch 703/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0273 - val_loss: 0.0696
# Epoch 704/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0136 - val_loss: 0.0720
# Epoch 705/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0204 - val_loss: 0.0792
# Epoch 706/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0175 - val_loss: 0.0836
# Epoch 707/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0173 - val_loss: 0.0826
# Epoch 708/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0135 - val_loss: 0.0844
# Epoch 709/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0173 - val_loss: 0.0856
# Epoch 710/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0192 - val_loss: 0.0859
# Epoch 711/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0129 - val_loss: 0.0847
# Epoch 712/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0135 - val_loss: 0.0835
# Epoch 713/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0139 - val_loss: 0.0814
# Epoch 714/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0103 - val_loss: 0.0809
# Epoch 715/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0109 - val_loss: 0.0798
# Epoch 716/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0171 - val_loss: 0.0786
# Epoch 717/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0151 - val_loss: 0.0780
# Epoch 718/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0130 - val_loss: 0.0777
# Epoch 719/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0167 - val_loss: 0.0802
# Epoch 720/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0139 - val_loss: 0.0818
# Epoch 721/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0116 - val_loss: 0.0811
# Epoch 722/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0152 - val_loss: 0.0804
# Epoch 723/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0190 - val_loss: 0.0804
# Epoch 724/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0153 - val_loss: 0.0820
# Epoch 725/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0195 - val_loss: 0.0827
# Epoch 726/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0176 - val_loss: 0.0869
# Epoch 727/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0170 - val_loss: 0.0882
# Epoch 728/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0237 - val_loss: 0.0838
# Epoch 729/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0186 - val_loss: 0.0834
# Epoch 730/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0241 - val_loss: 0.0853
# Epoch 731/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0256 - val_loss: 0.0800
# Epoch 732/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0111 - val_loss: 0.0784
# Epoch 733/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0184 - val_loss: 0.0896
# Epoch 734/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0183 - val_loss: 0.0937
# Epoch 735/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0149 - val_loss: 0.0895
# Epoch 736/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0325 - val_loss: 0.0833
# Epoch 737/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0119 - val_loss: 0.0839
# Epoch 738/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0185 - val_loss: 0.0819
# Epoch 739/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0189 - val_loss: 0.0698
# Epoch 740/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0165 - val_loss: 0.0677
# Epoch 741/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0212 - val_loss: 0.0699
# Epoch 742/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0193 - val_loss: 0.0694
# Epoch 743/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0163 - val_loss: 0.0750
# Epoch 744/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0177 - val_loss: 0.0846
# Epoch 745/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0139 - val_loss: 0.0877
# Epoch 746/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0095 - val_loss: 0.0857
# Epoch 747/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0192 - val_loss: 0.0821
# Epoch 748/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0229 - val_loss: 0.0784
# Epoch 749/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0160 - val_loss: 0.0738
# Epoch 750/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0185 - val_loss: 0.0665
# Epoch 751/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0280 - val_loss: 0.0628
# Epoch 752/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0207 - val_loss: 0.0593
# Epoch 753/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0181 - val_loss: 0.0565
# Epoch 754/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0117 - val_loss: 0.0604
# Epoch 755/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0208 - val_loss: 0.0665
# Epoch 756/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0186 - val_loss: 0.0731
# Epoch 757/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0128 - val_loss: 0.0776
# Epoch 758/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0141 - val_loss: 0.0808
# Epoch 759/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0140 - val_loss: 0.0829
# Epoch 760/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0197 - val_loss: 0.0793
# Epoch 761/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0210 - val_loss: 0.0728
# Epoch 762/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0184 - val_loss: 0.0707
# Epoch 763/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0180 - val_loss: 0.0701
# Epoch 764/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0238 - val_loss: 0.0712
# Epoch 765/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0175 - val_loss: 0.0781
# Epoch 766/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0218 - val_loss: 0.0834
# Epoch 767/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0271 - val_loss: 0.0814
# Epoch 768/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0193 - val_loss: 0.0757
# Epoch 769/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0177 - val_loss: 0.0702
# Epoch 770/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0312 - val_loss: 0.0674
# Epoch 771/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0164 - val_loss: 0.0670
# Epoch 772/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0151 - val_loss: 0.0761
# Epoch 773/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0270 - val_loss: 0.1093
# Epoch 774/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0168 - val_loss: 0.1250
# Epoch 775/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0207 - val_loss: 0.1161
# Epoch 776/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0192 - val_loss: 0.0999
# Epoch 777/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0155 - val_loss: 0.0869
# Epoch 778/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0162 - val_loss: 0.0799
# Epoch 779/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0104 - val_loss: 0.0751
# Epoch 780/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0163 - val_loss: 0.0655
# Epoch 781/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0127 - val_loss: 0.0617
# Epoch 782/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0197 - val_loss: 0.0602
# Epoch 783/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0159 - val_loss: 0.0667
# Epoch 784/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187 - val_loss: 0.0719
# Epoch 785/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0233 - val_loss: 0.0690
# Epoch 786/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0229 - val_loss: 0.0743
# Epoch 787/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0132 - val_loss: 0.1142
# Epoch 788/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0330 - val_loss: 0.1187
# Epoch 789/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0305 - val_loss: 0.0869
# Epoch 790/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0246 - val_loss: 0.0801
# Epoch 791/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0215 - val_loss: 0.0794
# Epoch 792/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0255 - val_loss: 0.0727
# Epoch 793/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0191 - val_loss: 0.0698
# Epoch 794/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0139 - val_loss: 0.0736
# Epoch 795/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0135 - val_loss: 0.0811
# Epoch 796/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0154 - val_loss: 0.0860
# Epoch 797/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0208 - val_loss: 0.0875
# Epoch 798/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0175 - val_loss: 0.0886
# Epoch 799/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0156 - val_loss: 0.0849
# Epoch 800/800
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0170 - val_loss: 0.0808
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step

# %%
################# Datos para stackingregressor #################


# Características temporales enriquecidas

df['Rolling_Mean_8_B+'] = df['B+'].rolling(8).mean()
df['Rolling_STD_4_B+'] = df['B+'].rolling(4).std()
df['Diff_1_B+'] = df['B+'].diff(1)


# Eliminar nulos generados por los lags/rolling
df.dropna(inplace=True)
# Definir features y target para stackingregressor
features_stk = [col for col in df.columns if col.startswith('Lag_B+') or 'Rolling_Mean_8_B+' in col or 'Rolling_STD_4_B+' in col or 'Diff_1_B+' in col or col in ['Week', 'Month','Quarter']]

X_stk = df[features_stk]
y = df[target]

scaler_x = RobustScaler()
scaler_y = RobustScaler()

X_scaled = scaler_x.fit_transform(X_stk)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1)).flatten()
X_scaled = pd.DataFrame(X_scaled, columns=X_stk.columns)
X_train_stk, X_test_stk, y_train_stk, y_test_stk = train_test_split(X_scaled, y_scaled, shuffle=False, test_size=0.2)

# %%
# StackingRegressor

modelo_stk = entrenar_stacking(X_train_stk, y_train_stk)
y_pred_stk = modelo_stk.predict(X_test_stk)
y_pred_stk = scaler_y.inverse_transform(y_pred_stk.reshape(-1, 1))
y_real_stk = scaler_y.inverse_transform(y_test_stk.reshape(-1, 1))

# %%
# ------------------------- MÉTRICAS PARA B+ -------------------------

print("* MÉTRICAS LSTM PARA B+")
print(f"MAE: {mean_absolute_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"RMSE: {mean_squared_error(y_real_lstm, y_pred_lstm):.2f}")
print(f"R²: {r2_score(y_real_lstm, y_pred_lstm):.2f}")

print("\n* MÉTRICAS STACKING PARA B+")
print(f"MAE: {mean_absolute_error(y_real_stk, y_pred_stk):.2f}")
print(f"RMSE: {mean_squared_error(y_real_stk, y_pred_stk):.2f}")
print(f"R²: {r2_score(y_real_stk, y_pred_stk):.2f}")
# Out:
# * MÉTRICAS LSTM PARA B+
# MAE: 9.41
# RMSE: 136.42
# R²: 0.58
#
# * MÉTRICAS STACKING PARA B+
# MAE: 10.75
# RMSE: 159.20
# R²: 0.39

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_real_stk), len(y_pred_stk))

# Convertir todo a 1D por seguridad
y_test_plot = y_test[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_real_plot = y_real_lstm[:min_len].reshape(-1)

# Plot
plt.figure(figsize=(12, 5))
plt.plot(np.arange(min_len), y_real_stk[:min_len], label="Real", color='black')
plt.plot(np.arange(min_len), y_pred_stk[:min_len], label="StackingRegressor", linestyle='--')
plt.plot(np.arange(min_len), y_pred_lstm[:min_len], label="LSTM", linestyle=':')
plt.title("Comparación de Predicciones: LSTM vs StackingRegressor (Demanda B+)")
plt.xlabel("Semanas")
plt.ylabel("Demanda")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
min_len = min(len(y_real_lstm), len(y_pred_lstm), len(y_pred_stk))
y_real_plot = y_real_lstm[:min_len].reshape(-1)
y_pred_lstm_plot = y_pred_lstm[:min_len].reshape(-1)
y_pred_stk_plot = y_pred_stk[:min_len].reshape(-1)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 10))
fig.suptitle("Comparación de Series y Análisis ACF/PACF", fontsize=16)

# Serie real
axes[0, 0].plot(y_real_plot, color='black')
axes[0, 0].set_title("Serie real B+ ")
axes[0, 0].grid(True)

# ACF real
plot_acf(y_real_plot, lags=min(20, len(y_real_plot)//2 - 1), ax=axes[0, 1])
axes[0, 1].set_title("ACF B+ - Real")

# LSTM predicción
axes[1, 0].plot(y_pred_lstm_plot, color='blue')
axes[1, 0].set_title("Predicción B+  LSTM")
axes[1, 0].grid(True)

# ACF LSTM
plot_acf(y_pred_lstm_plot, lags=min(20, len(y_pred_lstm_plot)//2 - 1), ax=axes[1, 1])
axes[1, 1].set_title("ACF B+  - LSTM")

# Stacking predicción
axes[2, 0].plot(y_pred_stk_plot, color='green')
axes[2, 0].set_title("Predicción B+  Stacking")
axes[2, 0].grid(True)

# ACF Stacking
plot_acf(y_pred_stk_plot, lags=min(20, len(y_pred_stk_plot)//2 - 1), ax=axes[2, 1])
axes[2, 1].set_title("ACF B+  - Stacking")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig("comparativa_modelos_acf.png", dpi=300)
plt.show()
